# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_AL_test10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   lr = 0.0001
# *   optimizer= Lamb

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pip install torch_optimizer
# Out:
# Collecting torch_optimizer
#   Downloading torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from torch_optimizer) (2.1.0+cu118)
# Collecting pytorch-ranger>=0.1.1 (from torch_optimizer)
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torch_optimizer) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torch_optimizer) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torch_optimizer) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torch_optimizer) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torch_optimizer) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torch_optimizer) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torch_optimizer) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.5.0->torch_optimizer) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.5.0->torch_optimizer) (1.3.0)
# Installing collected packages: pytorch-ranger, torch_optimizer
# Successfully installed pytorch-ranger-0.1.1 torch_optimizer-0.3.0

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
from torch_optimizer import Lamb

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image
#내가 추가
import re

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = re.sub(r'\([^)]*\)', '', label)
    label = int(label)
    return (img, label)

# %%
### Data Preprocessing ###

'''
# 데이터 정규화 추가
# 정규화 변환 정의
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
'''
transforms_train = transforms.Compose([transforms.Resize((448,448)),
                                       transforms.ToTensor()])
transforms_valtest = transforms.Compose([transforms.Resize((448,448)),
                                         transforms.ToTensor()])

BATCH_SIZE = 32
train_set = CUB2011(mode='train',
                    transform=transforms_train)
# transforms_train을 transforms_valtest로 변경
val_set = CUB2011(mode='valid',
                  transform=transforms_valtest)
test_set = CUB2011(mode='test',
                  transform=transforms_valtest)

print('Num of each dataset: ',len(train_set),len(val_set),len(test_set))

train_loader = DataLoader(train_set,batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")

### Model / Optimizer ###
EPOCH = 30
lr = 0.0001

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
model.to(DEVICE)

optimizer = optim.Lamb(model.parameters(),lr=lr)

print("Created a learning model and optimizer")
# Out:
# Num of each dataset:  2362 296 298
# Loaded dataloader
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    # loss func을 어떤 것을 사용할 것인지?
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/74]	loss: 0.002614
# Train Epoch: 0 [10/74]	loss: 0.002988
# Train Epoch: 0 [20/74]	loss: 0.003443
# Train Epoch: 0 [30/74]	loss: 0.002388
# Train Epoch: 0 [40/74]	loss: 0.002508
# Train Epoch: 0 [50/74]	loss: 0.002270
# Train Epoch: 0 [60/74]	loss: 0.002785
# Train Epoch: 0 [70/74]	loss: 0.002554
# [0]Validation Loss: 0.5196,Accuracy: 88.1757%
# Train Epoch: 1 [0/74]	loss: 0.001937
# Train Epoch: 1 [10/74]	loss: 0.002187
# Train Epoch: 1 [20/74]	loss: 0.004151
# Train Epoch: 1 [30/74]	loss: 0.002746
# Train Epoch: 1 [40/74]	loss: 0.002363
# Train Epoch: 1 [50/74]	loss: 0.002975
# Train Epoch: 1 [60/74]	loss: 0.004380
# Train Epoch: 1 [70/74]	loss: 0.002123
# [1]Validation Loss: 0.5282,Accuracy: 87.8378%
# Train Epoch: 2 [0/74]	loss: 0.002531
# Train Epoch: 2 [10/74]	loss: 0.002113
# Train Epoch: 2 [20/74]	loss: 0.002409
# Train Epoch: 2 [30/74]	loss: 0.003115
# Train Epoch: 2 [40/74]	loss: 0.001718
# Train Epoch: 2 [50/74]	loss: 0.002408
# Train Epoch: 2 [60/74]	loss: 0.001983
# Train Epoch: 2 [70/74]	loss: 0.002125
# [2]Validation Loss: 0.5227,Accuracy: 87.1622%
# Train Epoch: 3 [0/74]	loss: 0.001782
# Train Epoch: 3 [10/74]	loss: 0.003089
# Train Epoch: 3 [20/74]	loss: 0.001656
# Train Epoch: 3 [30/74]	loss: 0.001789
# Train Epoch: 3 [40/74]	loss: 0.001603
# Train Epoch: 3 [50/74]	loss: 0.001652
# Train Epoch: 3 [60/74]	loss: 0.002208
# Train Epoch: 3 [70/74]	loss: 0.002144
# [3]Validation Loss: 0.5200,Accuracy: 88.5135%
# Train Epoch: 4 [0/74]	loss: 0.003410
# Train Epoch: 4 [10/74]	loss: 0.001947
# Train Epoch: 4 [20/74]	loss: 0.002793
# Train Epoch: 4 [30/74]	loss: 0.001695
# Train Epoch: 4 [40/74]	loss: 0.001485
# Train Epoch: 4 [50/74]	loss: 0.001011
# Train Epoch: 4 [60/74]	loss: 0.003113
# Train Epoch: 4 [70/74]	loss: 0.003213
# [4]Validation Loss: 0.5245,Accuracy: 89.1892%
# Train Epoch: 5 [0/74]	loss: 0.001492
# Train Epoch: 5 [10/74]	loss: 0.001314
# Train Epoch: 5 [20/74]	loss: 0.003630
# Train Epoch: 5 [30/74]	loss: 0.001434
# Train Epoch: 5 [40/74]	loss: 0.002912
# Train Epoch: 5 [50/74]	loss: 0.002000
# Train Epoch: 5 [60/74]	loss: 0.001362
# Train Epoch: 5 [70/74]	loss: 0.001590
# [5]Validation Loss: 0.5393,Accuracy: 89.1892%
# Train Epoch: 6 [0/74]	loss: 0.001483
# Train Epoch: 6 [10/74]	loss: 0.001966
# Train Epoch: 6 [20/74]	loss: 0.001641
# Train Epoch: 6 [30/74]	loss: 0.002087
# Train Epoch: 6 [40/74]	loss: 0.001577
# Train Epoch: 6 [50/74]	loss: 0.000937
# Train Epoch: 6 [60/74]	loss: 0.001747
# Train Epoch: 6 [70/74]	loss: 0.001558
# [6]Validation Loss: 0.5151,Accuracy: 89.5270%
# Train Epoch: 7 [0/74]	loss: 0.001440
# Train Epoch: 7 [10/74]	loss: 0.001642
# Train Epoch: 7 [20/74]	loss: 0.001743
# Train Epoch: 7 [30/74]	loss: 0.001967
# Train Epoch: 7 [40/74]	loss: 0.003178
# Train Epoch: 7 [50/74]	loss: 0.001809
# Train Epoch: 7 [60/74]	loss: 0.001388
# Train Epoch: 7 [70/74]	loss: 0.002179
# [7]Validation Loss: 0.5148,Accuracy: 88.1757%
# Train Epoch: 8 [0/74]	loss: 0.001979
# Train Epoch: 8 [10/74]	loss: 0.001489
# Train Epoch: 8 [20/74]	loss: 0.005801
# Train Epoch: 8 [30/74]	loss: 0.001274
# Train Epoch: 8 [40/74]	loss: 0.001210
# Train Epoch: 8 [50/74]	loss: 0.001447
# Train Epoch: 8 [60/74]	loss: 0.001307
# Train Epoch: 8 [70/74]	loss: 0.002151
# [8]Validation Loss: 0.5164,Accuracy: 87.8378%
# Train Epoch: 9 [0/74]	loss: 0.001341
# Train Epoch: 9 [10/74]	loss: 0.001202
# Train Epoch: 9 [20/74]	loss: 0.001849
# Train Epoch: 9 [30/74]	loss: 0.002034
# Train Epoch: 9 [40/74]	loss: 0.001401
# Train Epoch: 9 [50/74]	loss: 0.002130
# Train Epoch: 9 [60/74]	loss: 0.001212
# Train Epoch: 9 [70/74]	loss: 0.001672
# [9]Validation Loss: 0.5133,Accuracy: 87.1622%
# Train Epoch: 10 [0/74]	loss: 0.001316
# Train Epoch: 10 [10/74]	loss: 0.001453
# Train Epoch: 10 [20/74]	loss: 0.001157
# Train Epoch: 10 [30/74]	loss: 0.000997
# Train Epoch: 10 [40/74]	loss: 0.001374
# Train Epoch: 10 [50/74]	loss: 0.001062
# Train Epoch: 10 [60/74]	loss: 0.001537
# Train Epoch: 10 [70/74]	loss: 0.003907
# [10]Validation Loss: 0.5245,Accuracy: 87.8378%
# Train Epoch: 11 [0/74]	loss: 0.001636
# Train Epoch: 11 [10/74]	loss: 0.002240
# Train Epoch: 11 [20/74]	loss: 0.001288
# Train Epoch: 11 [30/74]	loss: 0.001134
# Train Epoch: 11 [40/74]	loss: 0.000832
# Train Epoch: 11 [50/74]	loss: 0.000984
# Train Epoch: 11 [60/74]	loss: 0.001029
# Train Epoch: 11 [70/74]	loss: 0.000961
# [11]Validation Loss: 0.5407,Accuracy: 87.8378%
# Train Epoch: 12 [0/74]	loss: 0.001471
# Train Epoch: 12 [10/74]	loss: 0.001369
# Train Epoch: 12 [20/74]	loss: 0.001039
# Train Epoch: 12 [30/74]	loss: 0.001441
# Train Epoch: 12 [40/74]	loss: 0.001924
# Train Epoch: 12 [50/74]	loss: 0.001060
# Train Epoch: 12 [60/74]	loss: 0.001070
# Train Epoch: 12 [70/74]	loss: 0.001888
# [12]Validation Loss: 0.5157,Accuracy: 89.1892%
# Train Epoch: 13 [0/74]	loss: 0.000760
# Train Epoch: 13 [10/74]	loss: 0.001217
# Train Epoch: 13 [20/74]	loss: 0.001020
# Train Epoch: 13 [30/74]	loss: 0.001733
# Train Epoch: 13 [40/74]	loss: 0.001300
# Train Epoch: 13 [50/74]	loss: 0.000769
# Train Epoch: 13 [60/74]	loss: 0.001300
# Train Epoch: 13 [70/74]	loss: 0.001140
# [13]Validation Loss: 0.5068,Accuracy: 87.5000%
# Train Epoch: 14 [0/74]	loss: 0.001329
# Train Epoch: 14 [10/74]	loss: 0.000971
# Train Epoch: 14 [20/74]	loss: 0.001027
# Train Epoch: 14 [30/74]	loss: 0.001278
# Train Epoch: 14 [40/74]	loss: 0.001129
# Train Epoch: 14 [50/74]	loss: 0.001484
# Train Epoch: 14 [60/74]	loss: 0.002482
# Train Epoch: 14 [70/74]	loss: 0.001133
# [14]Validation Loss: 0.5190,Accuracy: 88.1757%
# Train Epoch: 15 [0/74]	loss: 0.000525
# Train Epoch: 15 [10/74]	loss: 0.000720
# Train Epoch: 15 [20/74]	loss: 0.000982
# Train Epoch: 15 [30/74]	loss: 0.001101
# Train Epoch: 15 [40/74]	loss: 0.001347
# Train Epoch: 15 [50/74]	loss: 0.001280
# Train Epoch: 15 [60/74]	loss: 0.001031
# Train Epoch: 15 [70/74]	loss: 0.002766
# [15]Validation Loss: 0.5224,Accuracy: 88.5135%
# Train Epoch: 16 [0/74]	loss: 0.001174
# Train Epoch: 16 [10/74]	loss: 0.001154
# Train Epoch: 16 [20/74]	loss: 0.000923
# Train Epoch: 16 [30/74]	loss: 0.000995
# Train Epoch: 16 [40/74]	loss: 0.000791
# Train Epoch: 16 [50/74]	loss: 0.001075
# Train Epoch: 16 [60/74]	loss: 0.000934
# Train Epoch: 16 [70/74]	loss: 0.001374
# [16]Validation Loss: 0.5110,Accuracy: 88.1757%
# Train Epoch: 17 [0/74]	loss: 0.001210
# Train Epoch: 17 [10/74]	loss: 0.000914
# Train Epoch: 17 [20/74]	loss: 0.001237
# Train Epoch: 17 [30/74]	loss: 0.001210
# Train Epoch: 17 [40/74]	loss: 0.001083
# Train Epoch: 17 [50/74]	loss: 0.000572
# Train Epoch: 17 [60/74]	loss: 0.000771
# Train Epoch: 17 [70/74]	loss: 0.001286
# [17]Validation Loss: 0.5033,Accuracy: 88.1757%
# Train Epoch: 18 [0/74]	loss: 0.001024
# Train Epoch: 18 [10/74]	loss: 0.000785
# Train Epoch: 18 [20/74]	loss: 0.001519
# Train Epoch: 18 [30/74]	loss: 0.000709
# Train Epoch: 18 [40/74]	loss: 0.001321
# Train Epoch: 18 [50/74]	loss: 0.000882
# Train Epoch: 18 [60/74]	loss: 0.000868
# Train Epoch: 18 [70/74]	loss: 0.000857
# [18]Validation Loss: 0.5113,Accuracy: 87.5000%
# Train Epoch: 19 [0/74]	loss: 0.000986
# Train Epoch: 19 [10/74]	loss: 0.001536
# Train Epoch: 19 [20/74]	loss: 0.000774
# Train Epoch: 19 [30/74]	loss: 0.001100
# Train Epoch: 19 [40/74]	loss: 0.001555
# Train Epoch: 19 [50/74]	loss: 0.000842
# Train Epoch: 19 [60/74]	loss: 0.000563
# Train Epoch: 19 [70/74]	loss: 0.000675
# [19]Validation Loss: 0.5026,Accuracy: 87.5000%
# Train Epoch: 20 [0/74]	loss: 0.001052
# Train Epoch: 20 [10/74]	loss: 0.000860
# Train Epoch: 20 [20/74]	loss: 0.000781
# Train Epoch: 20 [30/74]	loss: 0.001316
# Train Epoch: 20 [40/74]	loss: 0.000698
# Train Epoch: 20 [50/74]	loss: 0.000974
# Train Epoch: 20 [60/74]	loss: 0.001203
# Train Epoch: 20 [70/74]	loss: 0.000967
# [20]Validation Loss: 0.5126,Accuracy: 88.8514%
# Train Epoch: 21 [0/74]	loss: 0.001316
# Train Epoch: 21 [10/74]	loss: 0.000564
# Train Epoch: 21 [20/74]	loss: 0.000714
# Train Epoch: 21 [30/74]	loss: 0.001197
# Train Epoch: 21 [40/74]	loss: 0.000600
# Train Epoch: 21 [50/74]	loss: 0.000554
# Train Epoch: 21 [60/74]	loss: 0.001606
# Train Epoch: 21 [70/74]	loss: 0.000836
# [21]Validation Loss: 0.5126,Accuracy: 89.1892%
# Train Epoch: 22 [0/74]	loss: 0.000883
# Train Epoch: 22 [10/74]	loss: 0.000655
# Train Epoch: 22 [20/74]	loss: 0.000590
# Train Epoch: 22 [30/74]	loss: 0.001233
# Train Epoch: 22 [40/74]	loss: 0.000749
# Train Epoch: 22 [50/74]	loss: 0.000547
# Train Epoch: 22 [60/74]	loss: 0.000731
# Train Epoch: 22 [70/74]	loss: 0.001318
# [22]Validation Loss: 0.5208,Accuracy: 88.1757%
# Train Epoch: 23 [0/74]	loss: 0.001080
# Train Epoch: 23 [10/74]	loss: 0.000634
# Train Epoch: 23 [20/74]	loss: 0.000831
# Train Epoch: 23 [30/74]	loss: 0.000804
# Train Epoch: 23 [40/74]	loss: 0.000558
# Train Epoch: 23 [50/74]	loss: 0.000748
# Train Epoch: 23 [60/74]	loss: 0.000661
# Train Epoch: 23 [70/74]	loss: 0.000421
# [23]Validation Loss: 0.5149,Accuracy: 87.5000%
# Train Epoch: 24 [0/74]	loss: 0.001019
# Train Epoch: 24 [10/74]	loss: 0.000853
# Train Epoch: 24 [20/74]	loss: 0.002591
# Train Epoch: 24 [30/74]	loss: 0.000730
# Train Epoch: 24 [40/74]	loss: 0.000572
# Train Epoch: 24 [50/74]	loss: 0.000627
# Train Epoch: 24 [60/74]	loss: 0.134068
# Train Epoch: 24 [70/74]	loss: 0.037230
# [24]Validation Loss: 1.7328,Accuracy: 57.0946%
# Train Epoch: 25 [0/74]	loss: 0.071164
# Train Epoch: 25 [10/74]	loss: 0.083491
# Train Epoch: 25 [20/74]	loss: 0.445414
# Train Epoch: 25 [30/74]	loss: 0.350010
# Train Epoch: 25 [40/74]	loss: 0.359418
# Train Epoch: 25 [50/74]	loss: 0.233944
# Train Epoch: 25 [60/74]	loss: 0.198867
# Train Epoch: 25 [70/74]	loss: 0.131221
# [25]Validation Loss: 1.0600,Accuracy: 72.2973%
# Train Epoch: 26 [0/74]	loss: 0.134241
# Train Epoch: 26 [10/74]	loss: 0.085704
# Train Epoch: 26 [20/74]	loss: 0.249705
# Train Epoch: 26 [30/74]	loss: 0.036492
# Train Epoch: 26 [40/74]	loss: 0.076958
# Train Epoch: 26 [50/74]	loss: 0.021664
# Train Epoch: 26 [60/74]	loss: 0.050890
# Train Epoch: 26 [70/74]	loss: 0.008861
# [26]Validation Loss: 0.5336,Accuracy: 86.8243%
# Train Epoch: 27 [0/74]	loss: 0.012071
# Train Epoch: 27 [10/74]	loss: 0.009456
# Train Epoch: 27 [20/74]	loss: 0.007021
# Train Epoch: 27 [30/74]	loss: 0.012645
# Train Epoch: 27 [40/74]	loss: 0.012661
# Train Epoch: 27 [50/74]	loss: 0.017528
# Train Epoch: 27 [60/74]	loss: 0.003606
# Train Epoch: 27 [70/74]	loss: 0.007816
# [27]Validation Loss: 0.4345,Accuracy: 90.5405%
# Train Epoch: 28 [0/74]	loss: 0.004755
# Train Epoch: 28 [10/74]	loss: 0.007491
# Train Epoch: 28 [20/74]	loss: 0.003053
# Train Epoch: 28 [30/74]	loss: 0.003669
# Train Epoch: 28 [40/74]	loss: 0.004884
# Train Epoch: 28 [50/74]	loss: 0.003818
# Train Epoch: 28 [60/74]	loss: 0.002120
# Train Epoch: 28 [70/74]	loss: 0.002898
# [28]Validation Loss: 0.4184,Accuracy: 90.2027%
# Train Epoch: 29 [0/74]	loss: 0.002466
# Train Epoch: 29 [10/74]	loss: 0.002170
# Train Epoch: 29 [20/74]	loss: 0.001165
# Train Epoch: 29 [30/74]	loss: 0.002388
# Train Epoch: 29 [40/74]	loss: 0.002588
# Train Epoch: 29 [50/74]	loss: 0.002862
# Train Epoch: 29 [60/74]	loss: 0.001939
# Train Epoch: 29 [70/74]	loss: 0.001423
# [29]Validation Loss: 0.3979,Accuracy: 91.8919%
# [FINAL] Test Loss: 0.3708,Accuracy: 90.9396%
# Best Accuracy:  91.89189189189189
# Elasped Time: 0h, 17m, 10s
# time: 0h, 17m, 10s
