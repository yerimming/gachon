# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_AL_test8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   optimizer로 RAdam 사용
# 2.   lr = 0.0001

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install git+https://github.com/LiyuanLucasLiu/RAdam.git
# Out:
# Collecting git+https://github.com/LiyuanLucasLiu/RAdam.git
#   Cloning https://github.com/LiyuanLucasLiu/RAdam.git to /tmp/pip-req-build-9wbk09dr
#   Running command git clone --filter=blob:none --quiet https://github.com/LiyuanLucasLiu/RAdam.git /tmp/pip-req-build-9wbk09dr
#   Resolved https://github.com/LiyuanLucasLiu/RAdam.git to commit d9fd30a337894c4003768561d45e8730dbd41333
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from RAdam==0.0.1) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->RAdam==0.0.1) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->RAdam==0.0.1) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->RAdam==0.0.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->RAdam==0.0.1) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->RAdam==0.0.1) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->RAdam==0.0.1) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->RAdam==0.0.1) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->RAdam==0.0.1) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->RAdam==0.0.1) (1.3.0)
# Building wheels for collected packages: RAdam
#   Building wheel for RAdam (setup.py) ... done
#   Created wheel for RAdam: filename=RAdam-0.0.1-py3-none-any.whl size=7098 sha256=89161065c25bc162f0934a916fd09ce3f04b1a9e140ba4798437624e26ba2b77
#   Stored in directory: /tmp/pip-ephem-wheel-cache-38e5rncq/wheels/27/dd/f4/a154a2dd1d807820314f09ba2fa30f13f96a0d2830e8bab05e
# Successfully built RAdam
# Installing collected packages: RAdam
# Successfully installed RAdam-0.0.1

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

# radam 사용
from radam import RAdam

from PIL import Image
#내가 추가
import re

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = re.sub(r'\([^)]*\)', '', label)
    label = int(label)
    return (img, label)

# %%
### Data Preprocessing ###

'''
# 데이터 정규화 추가
# 정규화 변환 정의
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
'''
transforms_train = transforms.Compose([transforms.Resize((448,448)),
                                       transforms.ToTensor()])
transforms_valtest = transforms.Compose([transforms.Resize((448,448)),
                                         transforms.ToTensor()])

BATCH_SIZE = 32
train_set = CUB2011(mode='train',
                    transform=transforms_train)
# transforms_train을 transforms_valtest로 변경
val_set = CUB2011(mode='valid',
                  transform=transforms_valtest)
test_set = CUB2011(mode='test',
                  transform=transforms_valtest)

print('Num of each dataset: ',len(train_set),len(val_set),len(test_set))

train_loader = DataLoader(train_set,batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")

### Model / Optimizer ###
EPOCH = 30
lr = 0.001

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
model.to(DEVICE)

optimizer = optim.RAdam(model.parameters(),lr=lr)

print("Created a learning model and optimizer")
# Out:
# Num of each dataset:  2362 296 298
# Loaded dataloader
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    # loss func을 어떤 것을 사용할 것인지?
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/74]	loss: 4.090687
# Train Epoch: 0 [10/74]	loss: 4.057495
# Train Epoch: 0 [20/74]	loss: 3.730631
# Train Epoch: 0 [30/74]	loss: 3.363389
# Train Epoch: 0 [40/74]	loss: 3.176519
# Train Epoch: 0 [50/74]	loss: 2.856124
# Train Epoch: 0 [60/74]	loss: 2.283674
# Train Epoch: 0 [70/74]	loss: 2.457200
# [0]Validation Loss: 1.9708,Accuracy: 63.8514%
# Train Epoch: 1 [0/74]	loss: 1.925718
# Train Epoch: 1 [10/74]	loss: 1.455559
# Train Epoch: 1 [20/74]	loss: 1.510651
# Train Epoch: 1 [30/74]	loss: 1.499170
# Train Epoch: 1 [40/74]	loss: 1.172533
# Train Epoch: 1 [50/74]	loss: 1.379685
# Train Epoch: 1 [60/74]	loss: 1.093722
# Train Epoch: 1 [70/74]	loss: 0.953686
# [1]Validation Loss: 1.0702,Accuracy: 80.4054%
# Train Epoch: 2 [0/74]	loss: 0.602690
# Train Epoch: 2 [10/74]	loss: 0.587345
# Train Epoch: 2 [20/74]	loss: 0.537681
# Train Epoch: 2 [30/74]	loss: 0.384967
# Train Epoch: 2 [40/74]	loss: 0.428245
# Train Epoch: 2 [50/74]	loss: 0.517912
# Train Epoch: 2 [60/74]	loss: 0.442037
# Train Epoch: 2 [70/74]	loss: 0.366259
# [2]Validation Loss: 1.0659,Accuracy: 76.3514%
# Train Epoch: 3 [0/74]	loss: 0.367755
# Train Epoch: 3 [10/74]	loss: 0.272620
# Train Epoch: 3 [20/74]	loss: 0.179979
# Train Epoch: 3 [30/74]	loss: 0.117052
# Train Epoch: 3 [40/74]	loss: 0.127875
# Train Epoch: 3 [50/74]	loss: 0.136786
# Train Epoch: 3 [60/74]	loss: 0.133812
# Train Epoch: 3 [70/74]	loss: 0.156861
# [3]Validation Loss: 0.7757,Accuracy: 81.4189%
# Train Epoch: 4 [0/74]	loss: 0.064612
# Train Epoch: 4 [10/74]	loss: 0.060880
# Train Epoch: 4 [20/74]	loss: 0.047205
# Train Epoch: 4 [30/74]	loss: 0.041069
# Train Epoch: 4 [40/74]	loss: 0.052391
# Train Epoch: 4 [50/74]	loss: 0.057016
# Train Epoch: 4 [60/74]	loss: 0.042830
# Train Epoch: 4 [70/74]	loss: 0.032819
# [4]Validation Loss: 0.6301,Accuracy: 85.4730%
# Train Epoch: 5 [0/74]	loss: 0.071489
# Train Epoch: 5 [10/74]	loss: 0.034189
# Train Epoch: 5 [20/74]	loss: 0.019013
# Train Epoch: 5 [30/74]	loss: 0.024140
# Train Epoch: 5 [40/74]	loss: 0.015757
# Train Epoch: 5 [50/74]	loss: 0.026288
# Train Epoch: 5 [60/74]	loss: 0.011688
# Train Epoch: 5 [70/74]	loss: 0.015597
# [5]Validation Loss: 0.4599,Accuracy: 89.8649%
# Train Epoch: 6 [0/74]	loss: 0.010671
# Train Epoch: 6 [10/74]	loss: 0.015398
# Train Epoch: 6 [20/74]	loss: 0.010662
# Train Epoch: 6 [30/74]	loss: 0.010755
# Train Epoch: 6 [40/74]	loss: 0.009946
# Train Epoch: 6 [50/74]	loss: 0.009172
# Train Epoch: 6 [60/74]	loss: 0.014140
# Train Epoch: 6 [70/74]	loss: 0.006051
# [6]Validation Loss: 0.4320,Accuracy: 90.8784%
# Train Epoch: 7 [0/74]	loss: 0.010391
# Train Epoch: 7 [10/74]	loss: 0.008077
# Train Epoch: 7 [20/74]	loss: 0.008585
# Train Epoch: 7 [30/74]	loss: 0.007278
# Train Epoch: 7 [40/74]	loss: 0.006713
# Train Epoch: 7 [50/74]	loss: 0.006774
# Train Epoch: 7 [60/74]	loss: 0.004729
# Train Epoch: 7 [70/74]	loss: 0.006428
# [7]Validation Loss: 0.4254,Accuracy: 91.8919%
# Train Epoch: 8 [0/74]	loss: 0.006852
# Train Epoch: 8 [10/74]	loss: 0.006072
# Train Epoch: 8 [20/74]	loss: 0.007135
# Train Epoch: 8 [30/74]	loss: 0.003758
# Train Epoch: 8 [40/74]	loss: 0.005720
# Train Epoch: 8 [50/74]	loss: 0.003275
# Train Epoch: 8 [60/74]	loss: 0.003866
# Train Epoch: 8 [70/74]	loss: 0.005995
# [8]Validation Loss: 0.4072,Accuracy: 91.2162%
# Train Epoch: 9 [0/74]	loss: 0.004218
# Train Epoch: 9 [10/74]	loss: 0.002732
# Train Epoch: 9 [20/74]	loss: 0.003246
# Train Epoch: 9 [30/74]	loss: 0.003900
# Train Epoch: 9 [40/74]	loss: 0.002759
# Train Epoch: 9 [50/74]	loss: 0.003407
# Train Epoch: 9 [60/74]	loss: 0.004056
# Train Epoch: 9 [70/74]	loss: 0.002805
# [9]Validation Loss: 0.4141,Accuracy: 90.2027%
# Train Epoch: 10 [0/74]	loss: 0.005483
# Train Epoch: 10 [10/74]	loss: 0.002877
# Train Epoch: 10 [20/74]	loss: 0.002902
# Train Epoch: 10 [30/74]	loss: 0.003320
# Train Epoch: 10 [40/74]	loss: 0.003410
# Train Epoch: 10 [50/74]	loss: 0.002623
# Train Epoch: 10 [60/74]	loss: 0.003113
# Train Epoch: 10 [70/74]	loss: 0.003291
# [10]Validation Loss: 0.4200,Accuracy: 90.5405%
# Train Epoch: 11 [0/74]	loss: 0.001909
# Train Epoch: 11 [10/74]	loss: 0.003098
# Train Epoch: 11 [20/74]	loss: 0.003081
# Train Epoch: 11 [30/74]	loss: 0.004804
# Train Epoch: 11 [40/74]	loss: 0.007888
# Train Epoch: 11 [50/74]	loss: 0.002076
# Train Epoch: 11 [60/74]	loss: 0.003414
# Train Epoch: 11 [70/74]	loss: 0.002784
# [11]Validation Loss: 0.4077,Accuracy: 90.5405%
# Train Epoch: 12 [0/74]	loss: 0.003591
# Train Epoch: 12 [10/74]	loss: 0.002712
# Train Epoch: 12 [20/74]	loss: 0.003922
# Train Epoch: 12 [30/74]	loss: 0.001748
# Train Epoch: 12 [40/74]	loss: 0.002447
# Train Epoch: 12 [50/74]	loss: 0.002726
# Train Epoch: 12 [60/74]	loss: 0.001787
# Train Epoch: 12 [70/74]	loss: 0.002952
# [12]Validation Loss: 0.3904,Accuracy: 90.2027%
# Train Epoch: 13 [0/74]	loss: 0.002544
# Train Epoch: 13 [10/74]	loss: 0.002800
# Train Epoch: 13 [20/74]	loss: 0.002120
# Train Epoch: 13 [30/74]	loss: 0.001950
# Train Epoch: 13 [40/74]	loss: 0.001455
# Train Epoch: 13 [50/74]	loss: 0.001592
# Train Epoch: 13 [60/74]	loss: 0.001613
# Train Epoch: 13 [70/74]	loss: 0.001592
# [13]Validation Loss: 0.4046,Accuracy: 89.8649%
# Train Epoch: 14 [0/74]	loss: 0.001943
# Train Epoch: 14 [10/74]	loss: 0.001803
# Train Epoch: 14 [20/74]	loss: 0.002217
# Train Epoch: 14 [30/74]	loss: 0.001344
# Train Epoch: 14 [40/74]	loss: 0.001527
# Train Epoch: 14 [50/74]	loss: 0.001607
# Train Epoch: 14 [60/74]	loss: 0.001787
# Train Epoch: 14 [70/74]	loss: 0.001271
# [14]Validation Loss: 0.3975,Accuracy: 91.8919%
# Train Epoch: 15 [0/74]	loss: 0.001609
# Train Epoch: 15 [10/74]	loss: 0.001857
# Train Epoch: 15 [20/74]	loss: 0.001242
# Train Epoch: 15 [30/74]	loss: 0.001728
# Train Epoch: 15 [40/74]	loss: 0.001276
# Train Epoch: 15 [50/74]	loss: 0.001466
# Train Epoch: 15 [60/74]	loss: 0.001221
# Train Epoch: 15 [70/74]	loss: 0.001151
# [15]Validation Loss: 0.3927,Accuracy: 91.5541%
# Train Epoch: 16 [0/74]	loss: 0.001486
# Train Epoch: 16 [10/74]	loss: 0.001052
# Train Epoch: 16 [20/74]	loss: 0.001533
# Train Epoch: 16 [30/74]	loss: 0.001760
# Train Epoch: 16 [40/74]	loss: 0.000818
# Train Epoch: 16 [50/74]	loss: 0.000824
# Train Epoch: 16 [60/74]	loss: 0.001506
# Train Epoch: 16 [70/74]	loss: 0.001201
# [16]Validation Loss: 0.4002,Accuracy: 92.2297%
# Train Epoch: 17 [0/74]	loss: 0.000763
# Train Epoch: 17 [10/74]	loss: 0.001032
# Train Epoch: 17 [20/74]	loss: 0.001121
# Train Epoch: 17 [30/74]	loss: 0.001329
# Train Epoch: 17 [40/74]	loss: 0.001059
# Train Epoch: 17 [50/74]	loss: 0.000889
# Train Epoch: 17 [60/74]	loss: 0.001399
# Train Epoch: 17 [70/74]	loss: 0.000680
# [17]Validation Loss: 0.3912,Accuracy: 91.2162%
# Train Epoch: 18 [0/74]	loss: 0.001468
# Train Epoch: 18 [10/74]	loss: 0.000849
# Train Epoch: 18 [20/74]	loss: 0.000519
# Train Epoch: 18 [30/74]	loss: 0.002683
# Train Epoch: 18 [40/74]	loss: 0.001290
# Train Epoch: 18 [50/74]	loss: 0.180066
# Train Epoch: 18 [60/74]	loss: 1.829528
# Train Epoch: 18 [70/74]	loss: 2.764479
# [18]Validation Loss: 128.2267,Accuracy: 3.3784%
# Train Epoch: 19 [0/74]	loss: 3.069058
# Train Epoch: 19 [10/74]	loss: 3.325483
# Train Epoch: 19 [20/74]	loss: 2.731008
# Train Epoch: 19 [30/74]	loss: 3.122207
# Train Epoch: 19 [40/74]	loss: 2.629949
# Train Epoch: 19 [50/74]	loss: 1.850166
# Train Epoch: 19 [60/74]	loss: 2.338675
# Train Epoch: 19 [70/74]	loss: 1.966927
# [19]Validation Loss: 2.4949,Accuracy: 27.7027%
# Train Epoch: 20 [0/74]	loss: 1.513229
# Train Epoch: 20 [10/74]	loss: 1.445486
# Train Epoch: 20 [20/74]	loss: 1.222195
# Train Epoch: 20 [30/74]	loss: 1.105380
# Train Epoch: 20 [40/74]	loss: 1.258151
# Train Epoch: 20 [50/74]	loss: 1.300158
# Train Epoch: 20 [60/74]	loss: 1.391497
# Train Epoch: 20 [70/74]	loss: 0.868031
# [20]Validation Loss: 1.7350,Accuracy: 49.6622%
# Train Epoch: 21 [0/74]	loss: 0.721312
# Train Epoch: 21 [10/74]	loss: 0.747645
# Train Epoch: 21 [20/74]	loss: 0.819357
# Train Epoch: 21 [30/74]	loss: 0.572597
# Train Epoch: 21 [40/74]	loss: 0.579347
# Train Epoch: 21 [50/74]	loss: 0.635335
# Train Epoch: 21 [60/74]	loss: 0.742091
# Train Epoch: 21 [70/74]	loss: 0.692503
# [21]Validation Loss: 1.8284,Accuracy: 54.0541%
# Train Epoch: 22 [0/74]	loss: 0.413714
# Train Epoch: 22 [10/74]	loss: 0.283928
# Train Epoch: 22 [20/74]	loss: 0.239629
# Train Epoch: 22 [30/74]	loss: 0.359618
# Train Epoch: 22 [40/74]	loss: 0.235219
# Train Epoch: 22 [50/74]	loss: 0.375454
# Train Epoch: 22 [60/74]	loss: 0.326237
# Train Epoch: 22 [70/74]	loss: 0.510127
# [22]Validation Loss: 1.0671,Accuracy: 72.6351%
# Train Epoch: 23 [0/74]	loss: 0.233788
# Train Epoch: 23 [10/74]	loss: 0.215964
# Train Epoch: 23 [20/74]	loss: 0.301057
# Train Epoch: 23 [30/74]	loss: 0.318445
# Train Epoch: 23 [40/74]	loss: 0.139917
# Train Epoch: 23 [50/74]	loss: 0.286693
# Train Epoch: 23 [60/74]	loss: 0.344661
# Train Epoch: 23 [70/74]	loss: 0.138665
# [23]Validation Loss: 0.8117,Accuracy: 78.3784%
# Train Epoch: 24 [0/74]	loss: 0.067986
# Train Epoch: 24 [10/74]	loss: 0.107539
# Train Epoch: 24 [20/74]	loss: 0.097201
# Train Epoch: 24 [30/74]	loss: 0.081350
# Train Epoch: 24 [40/74]	loss: 0.093618
# Train Epoch: 24 [50/74]	loss: 0.065222
# Train Epoch: 24 [60/74]	loss: 0.075031
# Train Epoch: 24 [70/74]	loss: 0.094488
# [24]Validation Loss: 0.9138,Accuracy: 74.6622%
# Train Epoch: 25 [0/74]	loss: 0.064507
# Train Epoch: 25 [10/74]	loss: 0.079590
# Train Epoch: 25 [20/74]	loss: 0.121497
# Train Epoch: 25 [30/74]	loss: 0.032329
# Train Epoch: 25 [40/74]	loss: 0.016268
# Train Epoch: 25 [50/74]	loss: 0.020492
# Train Epoch: 25 [60/74]	loss: 0.035268
# Train Epoch: 25 [70/74]	loss: 0.155232
# [25]Validation Loss: 0.7368,Accuracy: 80.7432%
# Train Epoch: 26 [0/74]	loss: 0.083826
# Train Epoch: 26 [10/74]	loss: 0.020205
# Train Epoch: 26 [20/74]	loss: 0.013699
# Train Epoch: 26 [30/74]	loss: 0.008234
# Train Epoch: 26 [40/74]	loss: 0.038311
# Train Epoch: 26 [50/74]	loss: 0.011439
# Train Epoch: 26 [60/74]	loss: 0.026025
# Train Epoch: 26 [70/74]	loss: 0.008620
# [26]Validation Loss: 0.6312,Accuracy: 83.1081%
# Train Epoch: 27 [0/74]	loss: 0.022717
# Train Epoch: 27 [10/74]	loss: 0.019963
# Train Epoch: 27 [20/74]	loss: 0.007826
# Train Epoch: 27 [30/74]	loss: 0.005300
# Train Epoch: 27 [40/74]	loss: 0.015757
# Train Epoch: 27 [50/74]	loss: 0.045828
# Train Epoch: 27 [60/74]	loss: 0.016643
# Train Epoch: 27 [70/74]	loss: 0.017456
# [27]Validation Loss: 0.7703,Accuracy: 80.4054%
# Train Epoch: 28 [0/74]	loss: 0.013152
# Train Epoch: 28 [10/74]	loss: 0.018201
# Train Epoch: 28 [20/74]	loss: 0.007285
# Train Epoch: 28 [30/74]	loss: 0.023332
# Train Epoch: 28 [40/74]	loss: 0.006589
# Train Epoch: 28 [50/74]	loss: 0.007237
# Train Epoch: 28 [60/74]	loss: 0.003947
# Train Epoch: 28 [70/74]	loss: 0.004407
# [28]Validation Loss: 0.5919,Accuracy: 85.1351%
# Train Epoch: 29 [0/74]	loss: 0.011755
# Train Epoch: 29 [10/74]	loss: 0.002701
# Train Epoch: 29 [20/74]	loss: 0.003634
# Train Epoch: 29 [30/74]	loss: 0.002518
# Train Epoch: 29 [40/74]	loss: 0.002568
# Train Epoch: 29 [50/74]	loss: 0.002551
# Train Epoch: 29 [60/74]	loss: 0.002214
# Train Epoch: 29 [70/74]	loss: 0.002402
# [29]Validation Loss: 0.5549,Accuracy: 86.1486%
# [FINAL] Test Loss: 0.6169,Accuracy: 83.8926%
# Best Accuracy:  92.22972972972973
# Elasped Time: 0h, 17m, 14s
# time: 0h, 17m, 14s
