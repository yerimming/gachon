# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_AL2_EfficientNet(9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   AdamP optimizer 사용
# *   Label Smoothing
# *   EfficientNet 모델 사용
# *   get_cosine_schedule_with_warmup 스케줄러 사용

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install efficientnet_pytorch
# Out:
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=7d7093e41cc29143a579d0733ffd55a1df509a280ff8e045a510031c39510ebe
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %%
# !pip3 install adamp
# Out:
# Collecting adamp
#   Downloading adamp-0.3.0.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: adamp
#   Building wheel for adamp (setup.py) ... done
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5982 sha256=aa7bc54a68027189c0fcf94c65c39d8b8c5f08e48b4027920e610e68aa621e94
#   Stored in directory: /root/.cache/pip/wheels/c7/ad/0f/b41b1c45b18c66e5eef5d2254415af8055c7e2b0934145157d
# Successfully built adamp
# Installing collected packages: adamp
# Successfully installed adamp-0.3.0

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image,ImageEnhance

from efficientnet_pytorch import EfficientNet

from torch.utils.data import ConcatDataset
from collections import Counter

from adamp import AdamP

import numpy as np

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = int(label)
    return (img, label)

# %%
# Geomentric transform + Visual corruptions
class AddGaussianNoise(object):
    def __init__(self, mean=0, std=1, p=0.5):
        self.mean = mean
        self.std = std
        self.p = p

    def __call__(self, img):
        if np.random.rand() < self.p:
            img_array = np.array(img)
            noise = np.random.normal(self.mean, self.std, img_array.shape)
            noisy_image = np.clip(img_array + noise, 0, 255)  # Clip values to the range [0, 255]
            return Image.fromarray(noisy_image.astype(np.uint8))
        else:
            return img

    def __repr__(self):
        return self.__class__.__name__ + f'(mean={self.mean}, std={self.std}, p={self.p})'


class AdjustContrast(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

class AdjustBrightness(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Brightness(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

# %%
### Data Preprocessing & Data Augmentation ###
transforms_train_origin = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.ToTensor(),])

transforms_test = transforms.Compose([
    transforms.Resize((448,448)),
    transforms.ToTensor(),])

# Geomentric transform + Visual corruptions
transforms_train_g_v = transforms.Compose([
    transforms.Resize((448, 448)),
    #transforms.RandomResizedCrop(448),
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandomVerticalFlip(0.5),
    transforms.RandomRotation(30),
    AddGaussianNoise(mean=0, std=25, p=0.5),  # 가우시안 노이즈를 추가합니다.
    AdjustContrast(factor=2.0),  # 대비를 조절합니다.
    AdjustBrightness(factor=1.5),  # 밝기를 조절합니다.
    transforms.ToTensor(),
])

BATCH_SIZE = 8

train_set_origin = CUB2011(mode='train',
                    transform=transforms_train_origin)
val_set = CUB2011(mode='valid',
                  transform=transforms_test)
test_set = CUB2011(mode='test',
                  transform=transforms_test)

train_set_augmented2 = CUB2011(mode='train',transform=transforms_train_g_v) # 2)

train_loader = DataLoader(train_set_origin,batch_size=BATCH_SIZE,shuffle=True)

# 다 합친거
train_set_combined = ConcatDataset([train_set_origin,train_set_augmented2])

print('Num of each dataset: ',len(train_set_combined),len(val_set),len(test_set))

# Dataloader class는 bath기반의 딥러닝모델 학습을 위해서 mini batch를 만들어주는 역할을 한다
# dataloader를 통해 dataset의 전체 데이터가 batch size로 나뉘게 된다
train_loader = DataLoader(train_set_combined, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")
# Out:
# Num of each dataset:  4720 296 298
# Loaded dataloader

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 34.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 48.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.35.0

# %%
from transformers import get_cosine_schedule_with_warmup

### Model / Optimizer ###
EPOCH = 15
lr = 0.0001

model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=50)
print(model)

### Tranfer Learning ###
'''
num_features = model.classifier.in_features
model.fc = nn.Linear(num_features,50)
'''
model.to(DEVICE)

optimizer = AdamP(model.parameters(), lr=lr)

scheduler = get_cosine_schedule_with_warmup(optimizer,
                                    num_warmup_steps=len(train_loader)*3,
                                    num_training_steps=len(train_loader)*EPOCH)

print("Created a learning model and optimizer")
# Out:
# Loaded pretrained weights for efficientnet-b0
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d((0, 1, 0, 1))
#   )
#   (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#         (static_padding): ZeroPad2d((0, 1, 0, 1))
#       )
#       (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         96, 4, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         4, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d((1, 2, 1, 2))
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#         (static_padding): ZeroPad2d((0, 1, 0, 1))
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6-7): 2 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9-10): 2 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#         (static_padding): ZeroPad2d((1, 2, 1, 2))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12-14): 3 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_dropout): Dropout(p=0.2, inplace=False)
#   (_fc): Linear(in_features=1280, out_features=50, bias=True)
#   (_swish): MemoryEfficientSwish()
# )
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch, scheduler):
  model.train()
  criterion = nn.CrossEntropyLoss(label_smoothing=0.11)
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    train_loss = criterion(output,target)

    train_loss.backward()
    optimizer.step()

    if scheduler != None:
      scheduler.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
train_losses = []  # 훈련 손실을 저장할 목록
val_losses = []    # 검증 손실을 저장할 목록
val_accuracys = []

for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch, scheduler)
  val_loss,val_accuracy = evaluate(model,val_loader)

# 훈련 및 검증 손실을 목록에 추가
  train_losses.append(train_loss)
  val_losses.append(val_loss)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  val_accuracys.append(val_accuracy)
  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/590]	loss: 3.939034
# Train Epoch: 0 [10/590]	loss: 3.932552
# Train Epoch: 0 [20/590]	loss: 3.937899
# Train Epoch: 0 [30/590]	loss: 3.940319
# Train Epoch: 0 [40/590]	loss: 3.860931
# Train Epoch: 0 [50/590]	loss: 3.989677
# Train Epoch: 0 [60/590]	loss: 3.920141
# Train Epoch: 0 [70/590]	loss: 3.895114
# Train Epoch: 0 [80/590]	loss: 3.927165
# Train Epoch: 0 [90/590]	loss: 3.918870
# Train Epoch: 0 [100/590]	loss: 3.909942
# Train Epoch: 0 [110/590]	loss: 3.901790
# Train Epoch: 0 [120/590]	loss: 3.982776
# Train Epoch: 0 [130/590]	loss: 3.842686
# Train Epoch: 0 [140/590]	loss: 3.914956
# Train Epoch: 0 [150/590]	loss: 3.900828
# Train Epoch: 0 [160/590]	loss: 3.878488
# Train Epoch: 0 [170/590]	loss: 3.867015
# Train Epoch: 0 [180/590]	loss: 3.932301
# Train Epoch: 0 [190/590]	loss: 3.935895
# Train Epoch: 0 [200/590]	loss: 3.930704
# Train Epoch: 0 [210/590]	loss: 3.882570
# Train Epoch: 0 [220/590]	loss: 3.926811
# Train Epoch: 0 [230/590]	loss: 3.889421
# Train Epoch: 0 [240/590]	loss: 3.899808
# Train Epoch: 0 [250/590]	loss: 3.886352
# Train Epoch: 0 [260/590]	loss: 3.932714
# Train Epoch: 0 [270/590]	loss: 3.867184
# Train Epoch: 0 [280/590]	loss: 3.855674
# Train Epoch: 0 [290/590]	loss: 3.867843
# Train Epoch: 0 [300/590]	loss: 3.929232
# Train Epoch: 0 [310/590]	loss: 3.929656
# Train Epoch: 0 [320/590]	loss: 3.875846
# Train Epoch: 0 [330/590]	loss: 3.934964
# Train Epoch: 0 [340/590]	loss: 3.897274
# Train Epoch: 0 [350/590]	loss: 3.833987
# Train Epoch: 0 [360/590]	loss: 3.850612
# Train Epoch: 0 [370/590]	loss: 3.879666
# Train Epoch: 0 [380/590]	loss: 3.860855
# Train Epoch: 0 [390/590]	loss: 3.848158
# Train Epoch: 0 [400/590]	loss: 3.843665
# Train Epoch: 0 [410/590]	loss: 3.882605
# Train Epoch: 0 [420/590]	loss: 3.913891
# Train Epoch: 0 [430/590]	loss: 3.855968
# Train Epoch: 0 [440/590]	loss: 3.929128
# Train Epoch: 0 [450/590]	loss: 3.852681
# Train Epoch: 0 [460/590]	loss: 3.910089
# Train Epoch: 0 [470/590]	loss: 3.881099
# Train Epoch: 0 [480/590]	loss: 3.843031
# Train Epoch: 0 [490/590]	loss: 3.819535
# Train Epoch: 0 [500/590]	loss: 3.808941
# Train Epoch: 0 [510/590]	loss: 3.838720
# Train Epoch: 0 [520/590]	loss: 3.810583
# Train Epoch: 0 [530/590]	loss: 3.833872
# Train Epoch: 0 [540/590]	loss: 3.776242
# Train Epoch: 0 [550/590]	loss: 3.880558
# Train Epoch: 0 [560/590]	loss: 3.807865
# Train Epoch: 0 [570/590]	loss: 3.784993
# Train Epoch: 0 [580/590]	loss: 3.805021
# [0]Validation Loss: 3.7157,Accuracy: 24.6622%
# Train Epoch: 1 [0/590]	loss: 3.764218
# Train Epoch: 1 [10/590]	loss: 3.787344
# Train Epoch: 1 [20/590]	loss: 3.763283
# Train Epoch: 1 [30/590]	loss: 3.764327
# Train Epoch: 1 [40/590]	loss: 3.747356
# Train Epoch: 1 [50/590]	loss: 3.840220
# Train Epoch: 1 [60/590]	loss: 3.782388
# Train Epoch: 1 [70/590]	loss: 3.751840
# Train Epoch: 1 [80/590]	loss: 3.743273
# Train Epoch: 1 [90/590]	loss: 3.728716
# Train Epoch: 1 [100/590]	loss: 3.802881
# Train Epoch: 1 [110/590]	loss: 3.783645
# Train Epoch: 1 [120/590]	loss: 3.787286
# Train Epoch: 1 [130/590]	loss: 3.681779
# Train Epoch: 1 [140/590]	loss: 3.636796
# Train Epoch: 1 [150/590]	loss: 3.711936
# Train Epoch: 1 [160/590]	loss: 3.582381
# Train Epoch: 1 [170/590]	loss: 3.749374
# Train Epoch: 1 [180/590]	loss: 3.685873
# Train Epoch: 1 [190/590]	loss: 3.809191
# Train Epoch: 1 [200/590]	loss: 3.693408
# Train Epoch: 1 [210/590]	loss: 3.702827
# Train Epoch: 1 [220/590]	loss: 3.614971
# Train Epoch: 1 [230/590]	loss: 3.645639
# Train Epoch: 1 [240/590]	loss: 3.687702
# Train Epoch: 1 [250/590]	loss: 3.489441
# Train Epoch: 1 [260/590]	loss: 3.623863
# Train Epoch: 1 [270/590]	loss: 3.694494
# Train Epoch: 1 [280/590]	loss: 3.503958
# Train Epoch: 1 [290/590]	loss: 3.591969
# Train Epoch: 1 [300/590]	loss: 3.527344
# Train Epoch: 1 [310/590]	loss: 3.516140
# Train Epoch: 1 [320/590]	loss: 3.302907
# Train Epoch: 1 [330/590]	loss: 3.356583
# Train Epoch: 1 [340/590]	loss: 3.336873
# Train Epoch: 1 [350/590]	loss: 3.295560
# Train Epoch: 1 [360/590]	loss: 2.971076
# Train Epoch: 1 [370/590]	loss: 3.420199
# Train Epoch: 1 [380/590]	loss: 3.206651
# Train Epoch: 1 [390/590]	loss: 3.426667
# Train Epoch: 1 [400/590]	loss: 3.571337
# Train Epoch: 1 [410/590]	loss: 3.408350
# Train Epoch: 1 [420/590]	loss: 3.304901
# Train Epoch: 1 [430/590]	loss: 3.245821
# Train Epoch: 1 [440/590]	loss: 3.083697
# Train Epoch: 1 [450/590]	loss: 3.167785
# Train Epoch: 1 [460/590]	loss: 3.385534
# Train Epoch: 1 [470/590]	loss: 3.078602
# Train Epoch: 1 [480/590]	loss: 2.893098
# Train Epoch: 1 [490/590]	loss: 3.174562
# Train Epoch: 1 [500/590]	loss: 2.881665
# Train Epoch: 1 [510/590]	loss: 3.046397
# Train Epoch: 1 [520/590]	loss: 2.639472
# Train Epoch: 1 [530/590]	loss: 3.041171
# Train Epoch: 1 [540/590]	loss: 3.156142
# Train Epoch: 1 [550/590]	loss: 3.056715
# Train Epoch: 1 [560/590]	loss: 3.123725
# Train Epoch: 1 [570/590]	loss: 2.879999
# Train Epoch: 1 [580/590]	loss: 2.690918
# [1]Validation Loss: 1.9596,Accuracy: 63.8514%
# Train Epoch: 2 [0/590]	loss: 3.070508
# Train Epoch: 2 [10/590]	loss: 2.821280
# Train Epoch: 2 [20/590]	loss: 2.648918
# Train Epoch: 2 [30/590]	loss: 3.109633
# Train Epoch: 2 [40/590]	loss: 2.369327
# Train Epoch: 2 [50/590]	loss: 2.740681
# Train Epoch: 2 [60/590]	loss: 2.721668
# Train Epoch: 2 [70/590]	loss: 2.364301
# Train Epoch: 2 [80/590]	loss: 2.378307
# Train Epoch: 2 [90/590]	loss: 2.635959
# Train Epoch: 2 [100/590]	loss: 2.799042
# Train Epoch: 2 [110/590]	loss: 2.390324
# Train Epoch: 2 [120/590]	loss: 2.113168
# Train Epoch: 2 [130/590]	loss: 2.717991
# Train Epoch: 2 [140/590]	loss: 2.622284
# Train Epoch: 2 [150/590]	loss: 2.873393
# Train Epoch: 2 [160/590]	loss: 2.391686
# Train Epoch: 2 [170/590]	loss: 2.164368
# Train Epoch: 2 [180/590]	loss: 2.305485
# Train Epoch: 2 [190/590]	loss: 2.388686
# Train Epoch: 2 [200/590]	loss: 2.217594
# Train Epoch: 2 [210/590]	loss: 2.416032
# Train Epoch: 2 [220/590]	loss: 2.165255
# Train Epoch: 2 [230/590]	loss: 2.384309
# Train Epoch: 2 [240/590]	loss: 1.915963
# Train Epoch: 2 [250/590]	loss: 2.356697
# Train Epoch: 2 [260/590]	loss: 2.188584
# Train Epoch: 2 [270/590]	loss: 2.288746
# Train Epoch: 2 [280/590]	loss: 2.107495
# Train Epoch: 2 [290/590]	loss: 1.936741
# Train Epoch: 2 [300/590]	loss: 2.103201
# Train Epoch: 2 [310/590]	loss: 2.046492
# Train Epoch: 2 [320/590]	loss: 2.050435
# Train Epoch: 2 [330/590]	loss: 2.280879
# Train Epoch: 2 [340/590]	loss: 2.635392
# Train Epoch: 2 [350/590]	loss: 2.213353
# Train Epoch: 2 [360/590]	loss: 1.708521
# Train Epoch: 2 [370/590]	loss: 2.100443
# Train Epoch: 2 [380/590]	loss: 2.360068
# Train Epoch: 2 [390/590]	loss: 1.783972
# Train Epoch: 2 [400/590]	loss: 1.822484
# Train Epoch: 2 [410/590]	loss: 1.580319
# Train Epoch: 2 [420/590]	loss: 1.691009
# Train Epoch: 2 [430/590]	loss: 1.941448
# Train Epoch: 2 [440/590]	loss: 1.952451
# Train Epoch: 2 [450/590]	loss: 1.853237
# Train Epoch: 2 [460/590]	loss: 2.143391
# Train Epoch: 2 [470/590]	loss: 1.701325
# Train Epoch: 2 [480/590]	loss: 2.432620
# Train Epoch: 2 [490/590]	loss: 2.182732
# Train Epoch: 2 [500/590]	loss: 1.891953
# Train Epoch: 2 [510/590]	loss: 2.315694
# Train Epoch: 2 [520/590]	loss: 2.545548
# Train Epoch: 2 [530/590]	loss: 1.336717
# Train Epoch: 2 [540/590]	loss: 1.852164
# Train Epoch: 2 [550/590]	loss: 1.654321
# Train Epoch: 2 [560/590]	loss: 1.417998
# Train Epoch: 2 [570/590]	loss: 2.628378
# Train Epoch: 2 [580/590]	loss: 1.682233
# [2]Validation Loss: 0.8347,Accuracy: 79.7297%
# Train Epoch: 3 [0/590]	loss: 1.685010
# Train Epoch: 3 [10/590]	loss: 1.897763
# Train Epoch: 3 [20/590]	loss: 1.289916
# Train Epoch: 3 [30/590]	loss: 2.152912
# Train Epoch: 3 [40/590]	loss: 1.411673
# Train Epoch: 3 [50/590]	loss: 1.365354
# Train Epoch: 3 [60/590]	loss: 1.465891
# Train Epoch: 3 [70/590]	loss: 1.754923
# Train Epoch: 3 [80/590]	loss: 1.628469
# Train Epoch: 3 [90/590]	loss: 1.683203
# Train Epoch: 3 [100/590]	loss: 1.405125
# Train Epoch: 3 [110/590]	loss: 1.795144
# Train Epoch: 3 [120/590]	loss: 1.512195
# Train Epoch: 3 [130/590]	loss: 1.809224
# Train Epoch: 3 [140/590]	loss: 1.638895
# Train Epoch: 3 [150/590]	loss: 1.429209
# Train Epoch: 3 [160/590]	loss: 2.322551
# Train Epoch: 3 [170/590]	loss: 1.453574
# Train Epoch: 3 [180/590]	loss: 1.793646
# Train Epoch: 3 [190/590]	loss: 1.968270
# Train Epoch: 3 [200/590]	loss: 1.437721
# Train Epoch: 3 [210/590]	loss: 1.768239
# Train Epoch: 3 [220/590]	loss: 1.531487
# Train Epoch: 3 [230/590]	loss: 1.274684
# Train Epoch: 3 [240/590]	loss: 1.415950
# Train Epoch: 3 [250/590]	loss: 1.389863
# Train Epoch: 3 [260/590]	loss: 1.590849
# Train Epoch: 3 [270/590]	loss: 1.710268
# Train Epoch: 3 [280/590]	loss: 1.448504
# Train Epoch: 3 [290/590]	loss: 1.658707
# Train Epoch: 3 [300/590]	loss: 1.686760
# Train Epoch: 3 [310/590]	loss: 1.376825
# Train Epoch: 3 [320/590]	loss: 1.078288
# Train Epoch: 3 [330/590]	loss: 1.415117
# Train Epoch: 3 [340/590]	loss: 1.382198
# Train Epoch: 3 [350/590]	loss: 1.517416
# Train Epoch: 3 [360/590]	loss: 1.043513
# Train Epoch: 3 [370/590]	loss: 1.241539
# Train Epoch: 3 [380/590]	loss: 1.134641
# Train Epoch: 3 [390/590]	loss: 1.148622
# Train Epoch: 3 [400/590]	loss: 1.231368
# Train Epoch: 3 [410/590]	loss: 2.218779
# Train Epoch: 3 [420/590]	loss: 1.137591
# Train Epoch: 3 [430/590]	loss: 1.357030
# Train Epoch: 3 [440/590]	loss: 1.347741
# Train Epoch: 3 [450/590]	loss: 1.187162
# Train Epoch: 3 [460/590]	loss: 1.136772
# Train Epoch: 3 [470/590]	loss: 1.293897
# Train Epoch: 3 [480/590]	loss: 1.438738
# Train Epoch: 3 [490/590]	loss: 1.594692
# Train Epoch: 3 [500/590]	loss: 1.190024
# Train Epoch: 3 [510/590]	loss: 1.552129
# Train Epoch: 3 [520/590]	loss: 1.547025
# Train Epoch: 3 [530/590]	loss: 1.519136
# Train Epoch: 3 [540/590]	loss: 1.268451
# Train Epoch: 3 [550/590]	loss: 1.332099
# Train Epoch: 3 [560/590]	loss: 1.270782
# Train Epoch: 3 [570/590]	loss: 2.184080
# Train Epoch: 3 [580/590]	loss: 1.123235
# [3]Validation Loss: 0.4497,Accuracy: 89.1892%
# Train Epoch: 4 [0/590]	loss: 1.238451
# Train Epoch: 4 [10/590]	loss: 1.172321
# Train Epoch: 4 [20/590]	loss: 1.137410
# Train Epoch: 4 [30/590]	loss: 1.109526
# Train Epoch: 4 [40/590]	loss: 1.659350
# Train Epoch: 4 [50/590]	loss: 1.579905
# Train Epoch: 4 [60/590]	loss: 1.402930
# Train Epoch: 4 [70/590]	loss: 1.267003
# Train Epoch: 4 [80/590]	loss: 1.393739
# Train Epoch: 4 [90/590]	loss: 1.189679
# Train Epoch: 4 [100/590]	loss: 1.120901
# Train Epoch: 4 [110/590]	loss: 1.001038
# Train Epoch: 4 [120/590]	loss: 1.211200
# Train Epoch: 4 [130/590]	loss: 1.193770
# Train Epoch: 4 [140/590]	loss: 1.160472
# Train Epoch: 4 [150/590]	loss: 1.292062
# Train Epoch: 4 [160/590]	loss: 1.261487
# Train Epoch: 4 [170/590]	loss: 1.633103
# Train Epoch: 4 [180/590]	loss: 1.352955
# Train Epoch: 4 [190/590]	loss: 1.374402
# Train Epoch: 4 [200/590]	loss: 1.508306
# Train Epoch: 4 [210/590]	loss: 1.193747
# Train Epoch: 4 [220/590]	loss: 1.114271
# Train Epoch: 4 [230/590]	loss: 1.634713
# Train Epoch: 4 [240/590]	loss: 1.259738
# Train Epoch: 4 [250/590]	loss: 1.905971
# Train Epoch: 4 [260/590]	loss: 1.372755
# Train Epoch: 4 [270/590]	loss: 1.889210
# Train Epoch: 4 [280/590]	loss: 1.248740
# Train Epoch: 4 [290/590]	loss: 1.102700
# Train Epoch: 4 [300/590]	loss: 1.520694
# Train Epoch: 4 [310/590]	loss: 1.677284
# Train Epoch: 4 [320/590]	loss: 1.291596
# Train Epoch: 4 [330/590]	loss: 1.294593
# Train Epoch: 4 [340/590]	loss: 1.174683
# Train Epoch: 4 [350/590]	loss: 1.294202
# Train Epoch: 4 [360/590]	loss: 1.459541
# Train Epoch: 4 [370/590]	loss: 1.310566
# Train Epoch: 4 [380/590]	loss: 1.011493
# Train Epoch: 4 [390/590]	loss: 1.549850
# Train Epoch: 4 [400/590]	loss: 1.648428
# Train Epoch: 4 [410/590]	loss: 1.273409
# Train Epoch: 4 [420/590]	loss: 1.149632
# Train Epoch: 4 [430/590]	loss: 1.259809
# Train Epoch: 4 [440/590]	loss: 1.494233
# Train Epoch: 4 [450/590]	loss: 1.061923
# Train Epoch: 4 [460/590]	loss: 1.028121
# Train Epoch: 4 [470/590]	loss: 0.968053
# Train Epoch: 4 [480/590]	loss: 1.172458
# Train Epoch: 4 [490/590]	loss: 1.453564
# Train Epoch: 4 [500/590]	loss: 1.380921
# Train Epoch: 4 [510/590]	loss: 1.209999
# Train Epoch: 4 [520/590]	loss: 1.191363
# Train Epoch: 4 [530/590]	loss: 1.178724
# Train Epoch: 4 [540/590]	loss: 1.018816
# Train Epoch: 4 [550/590]	loss: 1.185995
# Train Epoch: 4 [560/590]	loss: 1.348424
# Train Epoch: 4 [570/590]	loss: 1.440557
# Train Epoch: 4 [580/590]	loss: 1.012496
# [4]Validation Loss: 0.3561,Accuracy: 91.5541%
# Train Epoch: 5 [0/590]	loss: 1.122570
# Train Epoch: 5 [10/590]	loss: 0.948747
# Train Epoch: 5 [20/590]	loss: 0.934592
# Train Epoch: 5 [30/590]	loss: 1.426351
# Train Epoch: 5 [40/590]	loss: 1.370454
# Train Epoch: 5 [50/590]	loss: 1.001145
# Train Epoch: 5 [60/590]	loss: 1.021202
# Train Epoch: 5 [70/590]	loss: 1.470135
# Train Epoch: 5 [80/590]	loss: 1.123499
# Train Epoch: 5 [90/590]	loss: 1.299691
# Train Epoch: 5 [100/590]	loss: 1.065351
# Train Epoch: 5 [110/590]	loss: 0.999590
# Train Epoch: 5 [120/590]	loss: 1.179358
# Train Epoch: 5 [130/590]	loss: 1.438823
# Train Epoch: 5 [140/590]	loss: 1.290930
# Train Epoch: 5 [150/590]	loss: 1.117545
# Train Epoch: 5 [160/590]	loss: 0.906845
# Train Epoch: 5 [170/590]	loss: 0.975862
# Train Epoch: 5 [180/590]	loss: 1.162979
# Train Epoch: 5 [190/590]	loss: 0.995118
# Train Epoch: 5 [200/590]	loss: 1.079359
# Train Epoch: 5 [210/590]	loss: 1.245198
# Train Epoch: 5 [220/590]	loss: 1.050082
# Train Epoch: 5 [230/590]	loss: 1.121031
# Train Epoch: 5 [240/590]	loss: 0.976479
# Train Epoch: 5 [250/590]	loss: 1.264394
# Train Epoch: 5 [260/590]	loss: 1.097661
# Train Epoch: 5 [270/590]	loss: 1.096059
# Train Epoch: 5 [280/590]	loss: 1.312489
# Train Epoch: 5 [290/590]	loss: 1.537895
# Train Epoch: 5 [300/590]	loss: 1.004314
# Train Epoch: 5 [310/590]	loss: 1.367870
# Train Epoch: 5 [320/590]	loss: 1.151052
# Train Epoch: 5 [330/590]	loss: 0.959231
# Train Epoch: 5 [340/590]	loss: 0.980559
# Train Epoch: 5 [350/590]	loss: 1.248925
# Train Epoch: 5 [360/590]	loss: 1.773897
# Train Epoch: 5 [370/590]	loss: 1.015409
# Train Epoch: 5 [380/590]	loss: 1.129771
# Train Epoch: 5 [390/590]	loss: 0.985382
# Train Epoch: 5 [400/590]	loss: 0.976653
# Train Epoch: 5 [410/590]	loss: 1.282078
# Train Epoch: 5 [420/590]	loss: 1.025652
# Train Epoch: 5 [430/590]	loss: 0.967877
# Train Epoch: 5 [440/590]	loss: 1.078368
# Train Epoch: 5 [450/590]	loss: 0.941183
# Train Epoch: 5 [460/590]	loss: 0.997338
# Train Epoch: 5 [470/590]	loss: 1.085132
# Train Epoch: 5 [480/590]	loss: 1.050404
# Train Epoch: 5 [490/590]	loss: 1.111213
# Train Epoch: 5 [500/590]	loss: 1.116172
# Train Epoch: 5 [510/590]	loss: 1.342000
# Train Epoch: 5 [520/590]	loss: 1.380532
# Train Epoch: 5 [530/590]	loss: 1.171638
# Train Epoch: 5 [540/590]	loss: 1.079628
# Train Epoch: 5 [550/590]	loss: 0.913405
# Train Epoch: 5 [560/590]	loss: 1.517737
# Train Epoch: 5 [570/590]	loss: 1.276962
# Train Epoch: 5 [580/590]	loss: 0.959058
# [5]Validation Loss: 0.3257,Accuracy: 93.5811%
# Train Epoch: 6 [0/590]	loss: 0.991496
# Train Epoch: 6 [10/590]	loss: 1.199957
# Train Epoch: 6 [20/590]	loss: 1.264362
# Train Epoch: 6 [30/590]	loss: 1.760660
# Train Epoch: 6 [40/590]	loss: 1.021197
# Train Epoch: 6 [50/590]	loss: 1.049735
# Train Epoch: 6 [60/590]	loss: 0.988956
# Train Epoch: 6 [70/590]	loss: 0.948160
# Train Epoch: 6 [80/590]	loss: 1.105994
# Train Epoch: 6 [90/590]	loss: 0.930365
# Train Epoch: 6 [100/590]	loss: 1.042601
# Train Epoch: 6 [110/590]	loss: 1.081943
# Train Epoch: 6 [120/590]	loss: 1.047142
# Train Epoch: 6 [130/590]	loss: 1.439294
# Train Epoch: 6 [140/590]	loss: 1.261358
# Train Epoch: 6 [150/590]	loss: 1.458546
# Train Epoch: 6 [160/590]	loss: 1.089013
# Train Epoch: 6 [170/590]	loss: 1.019155
# Train Epoch: 6 [180/590]	loss: 0.981363
# Train Epoch: 6 [190/590]	loss: 0.995838
# Train Epoch: 6 [200/590]	loss: 1.100513
# Train Epoch: 6 [210/590]	loss: 1.149753
# Train Epoch: 6 [220/590]	loss: 1.018689
# Train Epoch: 6 [230/590]	loss: 0.968296
# Train Epoch: 6 [240/590]	loss: 0.999229
# Train Epoch: 6 [250/590]	loss: 0.939123
# Train Epoch: 6 [260/590]	loss: 1.089199
# Train Epoch: 6 [270/590]	loss: 0.898862
# Train Epoch: 6 [280/590]	loss: 1.000844
# Train Epoch: 6 [290/590]	loss: 1.309444
# Train Epoch: 6 [300/590]	loss: 1.103218
# Train Epoch: 6 [310/590]	loss: 1.025738
# Train Epoch: 6 [320/590]	loss: 1.124516
# Train Epoch: 6 [330/590]	loss: 1.198079
# Train Epoch: 6 [340/590]	loss: 1.196863
# Train Epoch: 6 [350/590]	loss: 1.820108
# Train Epoch: 6 [360/590]	loss: 1.354546
# Train Epoch: 6 [370/590]	loss: 0.892537
# Train Epoch: 6 [380/590]	loss: 0.957369
# Train Epoch: 6 [390/590]	loss: 1.021393
# Train Epoch: 6 [400/590]	loss: 0.924873
# Train Epoch: 6 [410/590]	loss: 1.282007
# Train Epoch: 6 [420/590]	loss: 0.972808
# Train Epoch: 6 [430/590]	loss: 1.009224
# Train Epoch: 6 [440/590]	loss: 1.410862
# Train Epoch: 6 [450/590]	loss: 1.263207
# Train Epoch: 6 [460/590]	loss: 0.945498
# Train Epoch: 6 [470/590]	loss: 1.643766
# Train Epoch: 6 [480/590]	loss: 1.500928
# Train Epoch: 6 [490/590]	loss: 1.104746
# Train Epoch: 6 [500/590]	loss: 1.275534
# Train Epoch: 6 [510/590]	loss: 1.177070
# Train Epoch: 6 [520/590]	loss: 0.892682
# Train Epoch: 6 [530/590]	loss: 0.872165
# Train Epoch: 6 [540/590]	loss: 0.938521
# Train Epoch: 6 [550/590]	loss: 1.106304
# Train Epoch: 6 [560/590]	loss: 0.971741
# Train Epoch: 6 [570/590]	loss: 1.134353
# Train Epoch: 6 [580/590]	loss: 0.954426
# [6]Validation Loss: 0.3064,Accuracy: 92.5676%
# Train Epoch: 7 [0/590]	loss: 1.250317
# Train Epoch: 7 [10/590]	loss: 0.983245
# Train Epoch: 7 [20/590]	loss: 0.924579
# Train Epoch: 7 [30/590]	loss: 1.033801
# Train Epoch: 7 [40/590]	loss: 0.979996
# Train Epoch: 7 [50/590]	loss: 0.954002
# Train Epoch: 7 [60/590]	loss: 0.877744
# Train Epoch: 7 [70/590]	loss: 1.148984
# Train Epoch: 7 [80/590]	loss: 1.040721
# Train Epoch: 7 [90/590]	loss: 1.085495
# Train Epoch: 7 [100/590]	loss: 0.884953
# Train Epoch: 7 [110/590]	loss: 0.904974
# Train Epoch: 7 [120/590]	loss: 1.310600
# Train Epoch: 7 [130/590]	loss: 0.972129
# Train Epoch: 7 [140/590]	loss: 1.047291
# Train Epoch: 7 [150/590]	loss: 0.899824
# Train Epoch: 7 [160/590]	loss: 1.025279
# Train Epoch: 7 [170/590]	loss: 1.023886
# Train Epoch: 7 [180/590]	loss: 0.971321
# Train Epoch: 7 [190/590]	loss: 1.024796
# Train Epoch: 7 [200/590]	loss: 1.090000
# Train Epoch: 7 [210/590]	loss: 0.904590
# Train Epoch: 7 [220/590]	loss: 1.047433
# Train Epoch: 7 [230/590]	loss: 0.920068
# Train Epoch: 7 [240/590]	loss: 1.026488
# Train Epoch: 7 [250/590]	loss: 0.939646
# Train Epoch: 7 [260/590]	loss: 0.860806
# Train Epoch: 7 [270/590]	loss: 1.010111
# Train Epoch: 7 [280/590]	loss: 1.109210
# Train Epoch: 7 [290/590]	loss: 1.188952
# Train Epoch: 7 [300/590]	loss: 0.889247
# Train Epoch: 7 [310/590]	loss: 1.208577
# Train Epoch: 7 [320/590]	loss: 0.946769
# Train Epoch: 7 [330/590]	loss: 0.981279
# Train Epoch: 7 [340/590]	loss: 0.994461
# Train Epoch: 7 [350/590]	loss: 0.940600
# Train Epoch: 7 [360/590]	loss: 0.954130
# Train Epoch: 7 [370/590]	loss: 0.866587
# Train Epoch: 7 [380/590]	loss: 0.963766
# Train Epoch: 7 [390/590]	loss: 0.947234
# Train Epoch: 7 [400/590]	loss: 0.910223
# Train Epoch: 7 [410/590]	loss: 0.966060
# Train Epoch: 7 [420/590]	loss: 0.992551
# Train Epoch: 7 [430/590]	loss: 0.992864
# Train Epoch: 7 [440/590]	loss: 1.382201
# Train Epoch: 7 [450/590]	loss: 0.863281
# Train Epoch: 7 [460/590]	loss: 1.012848
# Train Epoch: 7 [470/590]	loss: 0.935015
# Train Epoch: 7 [480/590]	loss: 0.886092
# Train Epoch: 7 [490/590]	loss: 0.848725
# Train Epoch: 7 [500/590]	loss: 1.051004
# Train Epoch: 7 [510/590]	loss: 1.049755
# Train Epoch: 7 [520/590]	loss: 0.979774
# Train Epoch: 7 [530/590]	loss: 0.971077
# Train Epoch: 7 [540/590]	loss: 0.952027
# Train Epoch: 7 [550/590]	loss: 1.399725
# Train Epoch: 7 [560/590]	loss: 0.941544
# Train Epoch: 7 [570/590]	loss: 1.003125
# Train Epoch: 7 [580/590]	loss: 0.886966
# [7]Validation Loss: 0.2759,Accuracy: 93.5811%
# Train Epoch: 8 [0/590]	loss: 1.369298
# Train Epoch: 8 [10/590]	loss: 0.868117
# Train Epoch: 8 [20/590]	loss: 0.860045
# Train Epoch: 8 [30/590]	loss: 0.925171
# Train Epoch: 8 [40/590]	loss: 0.876610
# Train Epoch: 8 [50/590]	loss: 0.919613
# Train Epoch: 8 [60/590]	loss: 0.911912
# Train Epoch: 8 [70/590]	loss: 1.125896
# Train Epoch: 8 [80/590]	loss: 0.948871
# Train Epoch: 8 [90/590]	loss: 1.060017
# Train Epoch: 8 [100/590]	loss: 0.877120
# Train Epoch: 8 [110/590]	loss: 0.987422
# Train Epoch: 8 [120/590]	loss: 1.118657
# Train Epoch: 8 [130/590]	loss: 1.037231
# Train Epoch: 8 [140/590]	loss: 1.016987
# Train Epoch: 8 [150/590]	loss: 1.857558
# Train Epoch: 8 [160/590]	loss: 1.030368
# Train Epoch: 8 [170/590]	loss: 0.963509
# Train Epoch: 8 [180/590]	loss: 0.866036
# Train Epoch: 8 [190/590]	loss: 1.115011
# Train Epoch: 8 [200/590]	loss: 0.882160
# Train Epoch: 8 [210/590]	loss: 1.068270
# Train Epoch: 8 [220/590]	loss: 0.986346
# Train Epoch: 8 [230/590]	loss: 0.873401
# Train Epoch: 8 [240/590]	loss: 0.919323
# Train Epoch: 8 [250/590]	loss: 0.889221
# Train Epoch: 8 [260/590]	loss: 1.073864
# Train Epoch: 8 [270/590]	loss: 0.850526
# Train Epoch: 8 [280/590]	loss: 1.036122
# Train Epoch: 8 [290/590]	loss: 1.295588
# Train Epoch: 8 [300/590]	loss: 0.871293
# Train Epoch: 8 [310/590]	loss: 0.949359
# Train Epoch: 8 [320/590]	loss: 1.031183
# Train Epoch: 8 [330/590]	loss: 0.983014
# Train Epoch: 8 [340/590]	loss: 1.361020
# Train Epoch: 8 [350/590]	loss: 0.954695
# Train Epoch: 8 [360/590]	loss: 1.055836
# Train Epoch: 8 [370/590]	loss: 1.047588
# Train Epoch: 8 [380/590]	loss: 1.393415
# Train Epoch: 8 [390/590]	loss: 0.983311
# Train Epoch: 8 [400/590]	loss: 0.891121
# Train Epoch: 8 [410/590]	loss: 1.226447
# Train Epoch: 8 [420/590]	loss: 0.858512
# Train Epoch: 8 [430/590]	loss: 1.437644
# Train Epoch: 8 [440/590]	loss: 0.954990
# Train Epoch: 8 [450/590]	loss: 1.026233
# Train Epoch: 8 [460/590]	loss: 0.924627
# Train Epoch: 8 [470/590]	loss: 1.058785
# Train Epoch: 8 [480/590]	loss: 0.912823
# Train Epoch: 8 [490/590]	loss: 0.885615
# Train Epoch: 8 [500/590]	loss: 0.858426
# Train Epoch: 8 [510/590]	loss: 0.839415
# Train Epoch: 8 [520/590]	loss: 1.034854
# Train Epoch: 8 [530/590]	loss: 1.056372
# Train Epoch: 8 [540/590]	loss: 0.968271
# Train Epoch: 8 [550/590]	loss: 0.865023
# Train Epoch: 8 [560/590]	loss: 0.892817
# Train Epoch: 8 [570/590]	loss: 0.955043
# Train Epoch: 8 [580/590]	loss: 0.881557
# [8]Validation Loss: 0.3195,Accuracy: 92.9054%
# Train Epoch: 9 [0/590]	loss: 1.269215
# Train Epoch: 9 [10/590]	loss: 1.077393
# Train Epoch: 9 [20/590]	loss: 0.886548
# Train Epoch: 9 [30/590]	loss: 1.120994
# Train Epoch: 9 [40/590]	loss: 0.864728
# Train Epoch: 9 [50/590]	loss: 0.843359
# Train Epoch: 9 [60/590]	loss: 0.953997
# Train Epoch: 9 [70/590]	loss: 0.848745
# Train Epoch: 9 [80/590]	loss: 0.951220
# Train Epoch: 9 [90/590]	loss: 1.091897
# Train Epoch: 9 [100/590]	loss: 1.422360
# Train Epoch: 9 [110/590]	loss: 0.984685
# Train Epoch: 9 [120/590]	loss: 0.903018
# Train Epoch: 9 [130/590]	loss: 0.862004
# Train Epoch: 9 [140/590]	loss: 1.007793
# Train Epoch: 9 [150/590]	loss: 1.000375
# Train Epoch: 9 [160/590]	loss: 0.892741
# Train Epoch: 9 [170/590]	loss: 0.953022
# Train Epoch: 9 [180/590]	loss: 0.847573
# Train Epoch: 9 [190/590]	loss: 0.890617
# Train Epoch: 9 [200/590]	loss: 0.974154
# Train Epoch: 9 [210/590]	loss: 0.858476
# Train Epoch: 9 [220/590]	loss: 0.886215
# Train Epoch: 9 [230/590]	loss: 1.149495
# Train Epoch: 9 [240/590]	loss: 0.887970
# Train Epoch: 9 [250/590]	loss: 0.847921
# Train Epoch: 9 [260/590]	loss: 0.977193
# Train Epoch: 9 [270/590]	loss: 1.083843
# Train Epoch: 9 [280/590]	loss: 0.960726
# Train Epoch: 9 [290/590]	loss: 0.874432
# Train Epoch: 9 [300/590]	loss: 0.840538
# Train Epoch: 9 [310/590]	loss: 0.878380
# Train Epoch: 9 [320/590]	loss: 0.856038
# Train Epoch: 9 [330/590]	loss: 0.904007
# Train Epoch: 9 [340/590]	loss: 1.074784
# Train Epoch: 9 [350/590]	loss: 0.855762
# Train Epoch: 9 [360/590]	loss: 0.927432
# Train Epoch: 9 [370/590]	loss: 0.874124
# Train Epoch: 9 [380/590]	loss: 0.856901
# Train Epoch: 9 [390/590]	loss: 1.044533
# Train Epoch: 9 [400/590]	loss: 1.081792
# Train Epoch: 9 [410/590]	loss: 0.934947
# Train Epoch: 9 [420/590]	loss: 1.134917
# Train Epoch: 9 [430/590]	loss: 0.908352
# Train Epoch: 9 [440/590]	loss: 0.926249
# Train Epoch: 9 [450/590]	loss: 0.985089
# Train Epoch: 9 [460/590]	loss: 0.906389
# Train Epoch: 9 [470/590]	loss: 0.929346
# Train Epoch: 9 [480/590]	loss: 0.862749
# Train Epoch: 9 [490/590]	loss: 0.849616
# Train Epoch: 9 [500/590]	loss: 0.893374
# Train Epoch: 9 [510/590]	loss: 1.061535
# Train Epoch: 9 [520/590]	loss: 1.009230
# Train Epoch: 9 [530/590]	loss: 0.827068
# Train Epoch: 9 [540/590]	loss: 1.312122
# Train Epoch: 9 [550/590]	loss: 0.943532
# Train Epoch: 9 [560/590]	loss: 0.857231
# Train Epoch: 9 [570/590]	loss: 0.974915
# Train Epoch: 9 [580/590]	loss: 0.841317
# [9]Validation Loss: 0.2727,Accuracy: 93.5811%
# Train Epoch: 10 [0/590]	loss: 0.920069
# Train Epoch: 10 [10/590]	loss: 0.920908
# Train Epoch: 10 [20/590]	loss: 0.859900
# Train Epoch: 10 [30/590]	loss: 1.062651
# Train Epoch: 10 [40/590]	loss: 0.876074
# Train Epoch: 10 [50/590]	loss: 0.891421
# Train Epoch: 10 [60/590]	loss: 0.955875
# Train Epoch: 10 [70/590]	loss: 0.947088
# Train Epoch: 10 [80/590]	loss: 0.988067
# Train Epoch: 10 [90/590]	loss: 0.913682
# Train Epoch: 10 [100/590]	loss: 1.040838
# Train Epoch: 10 [110/590]	loss: 0.907674
# Train Epoch: 10 [120/590]	loss: 0.864920
# Train Epoch: 10 [130/590]	loss: 1.064302
# Train Epoch: 10 [140/590]	loss: 1.121678
# Train Epoch: 10 [150/590]	loss: 0.881771
# Train Epoch: 10 [160/590]	loss: 1.075254
# Train Epoch: 10 [170/590]	loss: 0.838248
# Train Epoch: 10 [180/590]	loss: 0.897423
# Train Epoch: 10 [190/590]	loss: 1.018294
# Train Epoch: 10 [200/590]	loss: 0.862905
# Train Epoch: 10 [210/590]	loss: 1.006593
# Train Epoch: 10 [220/590]	loss: 0.862102
# Train Epoch: 10 [230/590]	loss: 1.049854
# Train Epoch: 10 [240/590]	loss: 0.868998
# Train Epoch: 10 [250/590]	loss: 0.871177
# Train Epoch: 10 [260/590]	loss: 0.901079
# Train Epoch: 10 [270/590]	loss: 0.946558
# Train Epoch: 10 [280/590]	loss: 0.869374
# Train Epoch: 10 [290/590]	loss: 1.234886
# Train Epoch: 10 [300/590]	loss: 1.150370
# Train Epoch: 10 [310/590]	loss: 0.907138
# Train Epoch: 10 [320/590]	loss: 0.861493
# Train Epoch: 10 [330/590]	loss: 0.854466
# Train Epoch: 10 [340/590]	loss: 0.923840
# Train Epoch: 10 [350/590]	loss: 0.967887
# Train Epoch: 10 [360/590]	loss: 1.190783
# Train Epoch: 10 [370/590]	loss: 0.844759
# Train Epoch: 10 [380/590]	loss: 0.957823
# Train Epoch: 10 [390/590]	loss: 0.834097
# Train Epoch: 10 [400/590]	loss: 0.849544
# Train Epoch: 10 [410/590]	loss: 0.868587
# Train Epoch: 10 [420/590]	loss: 0.879585
# Train Epoch: 10 [430/590]	loss: 0.986561
# Train Epoch: 10 [440/590]	loss: 0.872138
# Train Epoch: 10 [450/590]	loss: 0.907740
# Train Epoch: 10 [460/590]	loss: 0.871362
# Train Epoch: 10 [470/590]	loss: 0.897510
# Train Epoch: 10 [480/590]	loss: 0.843515
# Train Epoch: 10 [490/590]	loss: 1.122812
# Train Epoch: 10 [500/590]	loss: 0.989843
# Train Epoch: 10 [510/590]	loss: 0.848459
# Train Epoch: 10 [520/590]	loss: 1.022697
# Train Epoch: 10 [530/590]	loss: 0.862670
# Train Epoch: 10 [540/590]	loss: 0.891793
# Train Epoch: 10 [550/590]	loss: 1.023693
# Train Epoch: 10 [560/590]	loss: 0.853061
# Train Epoch: 10 [570/590]	loss: 0.844452
# Train Epoch: 10 [580/590]	loss: 1.089829
# [10]Validation Loss: 0.2838,Accuracy: 94.2568%
# Train Epoch: 11 [0/590]	loss: 0.860274
# Train Epoch: 11 [10/590]	loss: 0.917699
# Train Epoch: 11 [20/590]	loss: 0.839099
# Train Epoch: 11 [30/590]	loss: 1.091108
# Train Epoch: 11 [40/590]	loss: 1.224757
# Train Epoch: 11 [50/590]	loss: 0.855764
# Train Epoch: 11 [60/590]	loss: 0.861460
# Train Epoch: 11 [70/590]	loss: 0.874380
# Train Epoch: 11 [80/590]	loss: 0.879879
# Train Epoch: 11 [90/590]	loss: 0.893177
# Train Epoch: 11 [100/590]	loss: 0.972252
# Train Epoch: 11 [110/590]	loss: 0.846523
# Train Epoch: 11 [120/590]	loss: 0.845804
# Train Epoch: 11 [130/590]	loss: 0.920021
# Train Epoch: 11 [140/590]	loss: 0.932786
# Train Epoch: 11 [150/590]	loss: 0.853498
# Train Epoch: 11 [160/590]	loss: 0.877573
# Train Epoch: 11 [170/590]	loss: 0.962213
# Train Epoch: 11 [180/590]	loss: 0.869367
# Train Epoch: 11 [190/590]	loss: 0.976542
# Train Epoch: 11 [200/590]	loss: 0.860781
# Train Epoch: 11 [210/590]	loss: 0.823555
# Train Epoch: 11 [220/590]	loss: 0.936358
# Train Epoch: 11 [230/590]	loss: 0.896864
# Train Epoch: 11 [240/590]	loss: 0.903585
# Train Epoch: 11 [250/590]	loss: 0.843085
# Train Epoch: 11 [260/590]	loss: 1.207355
# Train Epoch: 11 [270/590]	loss: 0.878528
# Train Epoch: 11 [280/590]	loss: 0.976374
# Train Epoch: 11 [290/590]	loss: 0.906324
# Train Epoch: 11 [300/590]	loss: 0.897125
# Train Epoch: 11 [310/590]	loss: 0.866030
# Train Epoch: 11 [320/590]	loss: 1.040161
# Train Epoch: 11 [330/590]	loss: 0.835083
# Train Epoch: 11 [340/590]	loss: 1.177451
# Train Epoch: 11 [350/590]	loss: 0.897673
# Train Epoch: 11 [360/590]	loss: 0.889210
# Train Epoch: 11 [370/590]	loss: 0.961439
# Train Epoch: 11 [380/590]	loss: 0.871392
# Train Epoch: 11 [390/590]	loss: 1.045083
# Train Epoch: 11 [400/590]	loss: 0.866934
# Train Epoch: 11 [410/590]	loss: 0.931820
# Train Epoch: 11 [420/590]	loss: 0.962819
# Train Epoch: 11 [430/590]	loss: 0.954979
# Train Epoch: 11 [440/590]	loss: 0.862751
# Train Epoch: 11 [450/590]	loss: 1.030942
# Train Epoch: 11 [460/590]	loss: 0.919770
# Train Epoch: 11 [470/590]	loss: 1.162517
# Train Epoch: 11 [480/590]	loss: 0.955848
# Train Epoch: 11 [490/590]	loss: 0.927343
# Train Epoch: 11 [500/590]	loss: 1.030580
# Train Epoch: 11 [510/590]	loss: 0.996304
# Train Epoch: 11 [520/590]	loss: 0.938211
# Train Epoch: 11 [530/590]	loss: 0.847078
# Train Epoch: 11 [540/590]	loss: 1.032282
# Train Epoch: 11 [550/590]	loss: 0.861900
# Train Epoch: 11 [560/590]	loss: 0.917313
# Train Epoch: 11 [570/590]	loss: 0.917141
# Train Epoch: 11 [580/590]	loss: 0.909319
# [11]Validation Loss: 0.2749,Accuracy: 93.9189%
# Train Epoch: 12 [0/590]	loss: 0.859403
# Train Epoch: 12 [10/590]	loss: 0.885867
# Train Epoch: 12 [20/590]	loss: 0.835783
# Train Epoch: 12 [30/590]	loss: 0.939531
# Train Epoch: 12 [40/590]	loss: 0.881705
# Train Epoch: 12 [50/590]	loss: 0.894033
# Train Epoch: 12 [60/590]	loss: 0.962395
# Train Epoch: 12 [70/590]	loss: 0.861884
# Train Epoch: 12 [80/590]	loss: 0.965602
# Train Epoch: 12 [90/590]	loss: 0.847677
# Train Epoch: 12 [100/590]	loss: 0.845133
# Train Epoch: 12 [110/590]	loss: 0.892330
# Train Epoch: 12 [120/590]	loss: 0.942316
# Train Epoch: 12 [130/590]	loss: 0.898659
# Train Epoch: 12 [140/590]	loss: 1.076680
# Train Epoch: 12 [150/590]	loss: 0.833380
# Train Epoch: 12 [160/590]	loss: 1.189002
# Train Epoch: 12 [170/590]	loss: 0.970811
# Train Epoch: 12 [180/590]	loss: 0.859205
# Train Epoch: 12 [190/590]	loss: 0.942799
# Train Epoch: 12 [200/590]	loss: 0.872337
# Train Epoch: 12 [210/590]	loss: 0.860823
# Train Epoch: 12 [220/590]	loss: 0.925534
# Train Epoch: 12 [230/590]	loss: 0.857581
# Train Epoch: 12 [240/590]	loss: 0.975848
# Train Epoch: 12 [250/590]	loss: 0.955076
# Train Epoch: 12 [260/590]	loss: 0.862168
# Train Epoch: 12 [270/590]	loss: 0.826566
# Train Epoch: 12 [280/590]	loss: 0.859669
# Train Epoch: 12 [290/590]	loss: 0.881592
# Train Epoch: 12 [300/590]	loss: 0.848759
# Train Epoch: 12 [310/590]	loss: 0.891114
# Train Epoch: 12 [320/590]	loss: 0.825437
# Train Epoch: 12 [330/590]	loss: 0.938346
# Train Epoch: 12 [340/590]	loss: 0.902971
# Train Epoch: 12 [350/590]	loss: 0.857837
# Train Epoch: 12 [360/590]	loss: 0.894141
# Train Epoch: 12 [370/590]	loss: 0.869038
# Train Epoch: 12 [380/590]	loss: 0.872428
# Train Epoch: 12 [390/590]	loss: 0.851771
# Train Epoch: 12 [400/590]	loss: 0.964274
# Train Epoch: 12 [410/590]	loss: 0.902886
# Train Epoch: 12 [420/590]	loss: 0.845210
# Train Epoch: 12 [430/590]	loss: 0.883942
# Train Epoch: 12 [440/590]	loss: 0.853713
# Train Epoch: 12 [450/590]	loss: 0.823744
# Train Epoch: 12 [460/590]	loss: 1.051301
# Train Epoch: 12 [470/590]	loss: 0.851229
# Train Epoch: 12 [480/590]	loss: 0.858696
# Train Epoch: 12 [490/590]	loss: 0.859002
# Train Epoch: 12 [500/590]	loss: 0.835175
# Train Epoch: 12 [510/590]	loss: 0.841856
# Train Epoch: 12 [520/590]	loss: 0.903353
# Train Epoch: 12 [530/590]	loss: 0.893061
# Train Epoch: 12 [540/590]	loss: 0.840597
# Train Epoch: 12 [550/590]	loss: 0.840401
# Train Epoch: 12 [560/590]	loss: 0.940123
# Train Epoch: 12 [570/590]	loss: 1.160722
# Train Epoch: 12 [580/590]	loss: 0.851973
# [12]Validation Loss: 0.2701,Accuracy: 94.5946%
# Train Epoch: 13 [0/590]	loss: 0.879075
# Train Epoch: 13 [10/590]	loss: 0.836832
# Train Epoch: 13 [20/590]	loss: 0.848943
# Train Epoch: 13 [30/590]	loss: 0.962493
# Train Epoch: 13 [40/590]	loss: 0.851439
# Train Epoch: 13 [50/590]	loss: 0.833415
# Train Epoch: 13 [60/590]	loss: 0.958116
# Train Epoch: 13 [70/590]	loss: 0.849113
# Train Epoch: 13 [80/590]	loss: 1.123037
# Train Epoch: 13 [90/590]	loss: 0.932744
# Train Epoch: 13 [100/590]	loss: 0.834465
# Train Epoch: 13 [110/590]	loss: 0.867028
# Train Epoch: 13 [120/590]	loss: 0.860899
# Train Epoch: 13 [130/590]	loss: 0.988913
# Train Epoch: 13 [140/590]	loss: 0.845212
# Train Epoch: 13 [150/590]	loss: 0.991068
# Train Epoch: 13 [160/590]	loss: 0.853059
# Train Epoch: 13 [170/590]	loss: 0.852655
# Train Epoch: 13 [180/590]	loss: 0.833966
# Train Epoch: 13 [190/590]	loss: 0.935225
# Train Epoch: 13 [200/590]	loss: 0.857943
# Train Epoch: 13 [210/590]	loss: 1.148200
# Train Epoch: 13 [220/590]	loss: 0.851076
# Train Epoch: 13 [230/590]	loss: 0.828150
# Train Epoch: 13 [240/590]	loss: 0.936229
# Train Epoch: 13 [250/590]	loss: 0.834376
# Train Epoch: 13 [260/590]	loss: 0.837966
# Train Epoch: 13 [270/590]	loss: 0.879333
# Train Epoch: 13 [280/590]	loss: 1.028142
# Train Epoch: 13 [290/590]	loss: 0.838566
# Train Epoch: 13 [300/590]	loss: 1.037333
# Train Epoch: 13 [310/590]	loss: 0.828451
# Train Epoch: 13 [320/590]	loss: 1.288182
# Train Epoch: 13 [330/590]	loss: 0.971109
# Train Epoch: 13 [340/590]	loss: 0.842531
# Train Epoch: 13 [350/590]	loss: 0.845820
# Train Epoch: 13 [360/590]	loss: 0.972431
# Train Epoch: 13 [370/590]	loss: 1.022979
# Train Epoch: 13 [380/590]	loss: 1.040916
# Train Epoch: 13 [390/590]	loss: 0.859921
# Train Epoch: 13 [400/590]	loss: 0.870737
# Train Epoch: 13 [410/590]	loss: 0.935761
# Train Epoch: 13 [420/590]	loss: 0.831380
# Train Epoch: 13 [430/590]	loss: 0.871119
# Train Epoch: 13 [440/590]	loss: 0.835321
# Train Epoch: 13 [450/590]	loss: 0.833329
# Train Epoch: 13 [460/590]	loss: 1.007857
# Train Epoch: 13 [470/590]	loss: 0.907814
# Train Epoch: 13 [480/590]	loss: 0.892799
# Train Epoch: 13 [490/590]	loss: 0.848389
# Train Epoch: 13 [500/590]	loss: 0.959068
# Train Epoch: 13 [510/590]	loss: 0.971087
# Train Epoch: 13 [520/590]	loss: 0.900960
# Train Epoch: 13 [530/590]	loss: 0.932665
# Train Epoch: 13 [540/590]	loss: 0.874049
# Train Epoch: 13 [550/590]	loss: 0.877123
# Train Epoch: 13 [560/590]	loss: 0.925130
# Train Epoch: 13 [570/590]	loss: 0.932190
# Train Epoch: 13 [580/590]	loss: 0.889269
# [13]Validation Loss: 0.2698,Accuracy: 94.9324%
# Train Epoch: 14 [0/590]	loss: 0.926965
# Train Epoch: 14 [10/590]	loss: 0.876046
# Train Epoch: 14 [20/590]	loss: 0.888842
# Train Epoch: 14 [30/590]	loss: 0.826956
# Train Epoch: 14 [40/590]	loss: 0.856123
# Train Epoch: 14 [50/590]	loss: 0.846283
# Train Epoch: 14 [60/590]	loss: 0.858755
# Train Epoch: 14 [70/590]	loss: 0.895827
# Train Epoch: 14 [80/590]	loss: 0.867002
# Train Epoch: 14 [90/590]	loss: 0.924142
# Train Epoch: 14 [100/590]	loss: 0.944225
# Train Epoch: 14 [110/590]	loss: 0.865421
# Train Epoch: 14 [120/590]	loss: 0.906606
# Train Epoch: 14 [130/590]	loss: 0.880755
# Train Epoch: 14 [140/590]	loss: 0.966347
# Train Epoch: 14 [150/590]	loss: 0.935990
# Train Epoch: 14 [160/590]	loss: 0.847265
# Train Epoch: 14 [170/590]	loss: 0.958392
# Train Epoch: 14 [180/590]	loss: 1.286711
# Train Epoch: 14 [190/590]	loss: 0.891458
# Train Epoch: 14 [200/590]	loss: 0.892907
# Train Epoch: 14 [210/590]	loss: 0.859186
# Train Epoch: 14 [220/590]	loss: 0.861059
# Train Epoch: 14 [230/590]	loss: 0.875647
# Train Epoch: 14 [240/590]	loss: 1.014978
# Train Epoch: 14 [250/590]	loss: 0.839444
# Train Epoch: 14 [260/590]	loss: 1.022214
# Train Epoch: 14 [270/590]	loss: 0.930844
# Train Epoch: 14 [280/590]	loss: 1.033088
# Train Epoch: 14 [290/590]	loss: 0.847603
# Train Epoch: 14 [300/590]	loss: 0.955091
# Train Epoch: 14 [310/590]	loss: 0.999641
# Train Epoch: 14 [320/590]	loss: 0.861380
# Train Epoch: 14 [330/590]	loss: 0.840446
# Train Epoch: 14 [340/590]	loss: 0.834898
# Train Epoch: 14 [350/590]	loss: 0.866536
# Train Epoch: 14 [360/590]	loss: 0.905847
# Train Epoch: 14 [370/590]	loss: 0.995995
# Train Epoch: 14 [380/590]	loss: 0.829400
# Train Epoch: 14 [390/590]	loss: 0.877807
# Train Epoch: 14 [400/590]	loss: 0.872422
# Train Epoch: 14 [410/590]	loss: 0.895160
# Train Epoch: 14 [420/590]	loss: 0.931059
# Train Epoch: 14 [430/590]	loss: 0.865923
# Train Epoch: 14 [440/590]	loss: 0.828678
# Train Epoch: 14 [450/590]	loss: 0.955670
# Train Epoch: 14 [460/590]	loss: 1.037658
# Train Epoch: 14 [470/590]	loss: 0.920013
# Train Epoch: 14 [480/590]	loss: 1.014837
# Train Epoch: 14 [490/590]	loss: 0.884741
# Train Epoch: 14 [500/590]	loss: 0.852404
# Train Epoch: 14 [510/590]	loss: 1.188765
# Train Epoch: 14 [520/590]	loss: 1.053877
# Train Epoch: 14 [530/590]	loss: 0.895910
# Train Epoch: 14 [540/590]	loss: 1.146109
# Train Epoch: 14 [550/590]	loss: 0.885115
# Train Epoch: 14 [560/590]	loss: 0.845788
# Train Epoch: 14 [570/590]	loss: 0.884387
# Train Epoch: 14 [580/590]	loss: 1.030041
# [14]Validation Loss: 0.2653,Accuracy: 94.2568%
# [FINAL] Test Loss: 0.2839,Accuracy: 93.2886%
# Best Accuracy:  94.93243243243244
# Elasped Time: 1h, 63m, 25s
# time: 1h, 63m, 25s

# %%
# 이제 손실 값을 플로팅합니다.
import matplotlib.pyplot as plt

# train_loss와 val_loss 텐서를 CPU로 이동하고 NumPy 배열로 변환
train_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in train_losses]
val_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), train_losses, label='train_loss', marker='o')
plt.plot(range(1, EPOCH + 1), val_losses, label='val_loss', marker='o')
plt.title('Training and Validation Loss Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()


val_accuracys = [acc.cpu().detach().numpy() if isinstance(acc, torch.Tensor) else acc for acc in val_accuracys]
plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), val_accuracys, label='val_accuracy', marker='o')
plt.title('Validation Accuracy Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
