# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_AL_test6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# lr 0.1에서 0.0001로 수정, weight_decay 0.1 설정
# -> weight_decay 안 건드리는 게 성능 가장 좋음

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image
#내가 추가
import re

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = re.sub(r'\([^)]*\)', '', label)
    label = int(label)
    return (img, label)

# %%
### Data Preprocessing ###

'''
# 데이터 정규화 추가
# 정규화 변환 정의
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
'''
transforms_train = transforms.Compose([transforms.Resize((448,448)),
                                       transforms.ToTensor()])
transforms_valtest = transforms.Compose([transforms.Resize((448,448)),
                                         transforms.ToTensor()])

BATCH_SIZE = 32
train_set = CUB2011(mode='train',
                    transform=transforms_train)
# transforms_train을 transforms_valtest로 변경
val_set = CUB2011(mode='valid',
                  transform=transforms_valtest)
test_set = CUB2011(mode='test',
                  transform=transforms_valtest)

print('Num of each dataset: ',len(train_set),len(val_set),len(test_set))

train_loader = DataLoader(train_set,batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")

### Model / Optimizer ###
EPOCH = 30
lr = 0.0001

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(),lr=lr, weight_decay=0.1)

print("Created a learning model and optimizer")
# Out:
# Num of each dataset:  2362 296 298
# Loaded dataloader
# Created a learning model and optimizer
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    # loss func을 어떤 것을 사용할 것인지?
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/74]	loss: 4.110435
# Train Epoch: 0 [10/74]	loss: 3.847384
# Train Epoch: 0 [20/74]	loss: 3.681404
# Train Epoch: 0 [30/74]	loss: 3.765543
# Train Epoch: 0 [40/74]	loss: 3.418708
# Train Epoch: 0 [50/74]	loss: 3.127125
# Train Epoch: 0 [60/74]	loss: 3.095695
# Train Epoch: 0 [70/74]	loss: 2.825428
# [0]Validation Loss: 2.6490,Accuracy: 50.0000%
# Train Epoch: 1 [0/74]	loss: 2.723567
# Train Epoch: 1 [10/74]	loss: 2.349339
# Train Epoch: 1 [20/74]	loss: 2.250516
# Train Epoch: 1 [30/74]	loss: 2.334528
# Train Epoch: 1 [40/74]	loss: 1.808614
# Train Epoch: 1 [50/74]	loss: 2.004613
# Train Epoch: 1 [60/74]	loss: 1.698346
# Train Epoch: 1 [70/74]	loss: 1.624506
# [1]Validation Loss: 1.8071,Accuracy: 72.2973%
# Train Epoch: 2 [0/74]	loss: 1.258783
# Train Epoch: 2 [10/74]	loss: 1.499424
# Train Epoch: 2 [20/74]	loss: 1.370089
# Train Epoch: 2 [30/74]	loss: 1.168971
# Train Epoch: 2 [40/74]	loss: 1.308310
# Train Epoch: 2 [50/74]	loss: 1.313212
# Train Epoch: 2 [60/74]	loss: 1.239677
# Train Epoch: 2 [70/74]	loss: 1.220636
# [2]Validation Loss: 1.4070,Accuracy: 80.0676%
# Train Epoch: 3 [0/74]	loss: 0.938454
# Train Epoch: 3 [10/74]	loss: 0.611359
# Train Epoch: 3 [20/74]	loss: 0.653980
# Train Epoch: 3 [30/74]	loss: 0.673284
# Train Epoch: 3 [40/74]	loss: 0.714303
# Train Epoch: 3 [50/74]	loss: 0.831472
# Train Epoch: 3 [60/74]	loss: 0.803422
# Train Epoch: 3 [70/74]	loss: 0.748784
# [3]Validation Loss: 1.3277,Accuracy: 80.4054%
# Train Epoch: 4 [0/74]	loss: 0.561430
# Train Epoch: 4 [10/74]	loss: 0.737149
# Train Epoch: 4 [20/74]	loss: 0.358755
# Train Epoch: 4 [30/74]	loss: 0.565054
# Train Epoch: 4 [40/74]	loss: 0.460584
# Train Epoch: 4 [50/74]	loss: 0.574925
# Train Epoch: 4 [60/74]	loss: 0.518571
# Train Epoch: 4 [70/74]	loss: 0.546145
# [4]Validation Loss: 1.1250,Accuracy: 75.0000%
# Train Epoch: 5 [0/74]	loss: 0.374806
# Train Epoch: 5 [10/74]	loss: 0.472024
# Train Epoch: 5 [20/74]	loss: 0.457289
# Train Epoch: 5 [30/74]	loss: 0.416663
# Train Epoch: 5 [40/74]	loss: 0.389070
# Train Epoch: 5 [50/74]	loss: 0.525541
# Train Epoch: 5 [60/74]	loss: 0.489389
# Train Epoch: 5 [70/74]	loss: 0.509364
# [5]Validation Loss: 1.2155,Accuracy: 75.3378%
# Train Epoch: 6 [0/74]	loss: 0.342457
# Train Epoch: 6 [10/74]	loss: 0.422391
# Train Epoch: 6 [20/74]	loss: 0.387375
# Train Epoch: 6 [30/74]	loss: 0.414039
# Train Epoch: 6 [40/74]	loss: 0.420595
# Train Epoch: 6 [50/74]	loss: 0.592387
# Train Epoch: 6 [60/74]	loss: 0.559944
# Train Epoch: 6 [70/74]	loss: 0.554077
# [6]Validation Loss: 1.1271,Accuracy: 76.6892%
# Train Epoch: 7 [0/74]	loss: 0.293242
# Train Epoch: 7 [10/74]	loss: 0.289818
# Train Epoch: 7 [20/74]	loss: 0.385704
# Train Epoch: 7 [30/74]	loss: 0.446666
# Train Epoch: 7 [40/74]	loss: 0.352344
# Train Epoch: 7 [50/74]	loss: 0.535183
# Train Epoch: 7 [60/74]	loss: 0.276498
# Train Epoch: 7 [70/74]	loss: 0.486158
# [7]Validation Loss: 1.9838,Accuracy: 47.6351%
# Train Epoch: 8 [0/74]	loss: 0.365571
# Train Epoch: 8 [10/74]	loss: 0.442279
# Train Epoch: 8 [20/74]	loss: 0.341801
# Train Epoch: 8 [30/74]	loss: 0.384429
# Train Epoch: 8 [40/74]	loss: 0.452617
# Train Epoch: 8 [50/74]	loss: 0.427807
# Train Epoch: 8 [60/74]	loss: 0.448550
# Train Epoch: 8 [70/74]	loss: 0.475559
# [8]Validation Loss: 1.2533,Accuracy: 73.3108%
# Train Epoch: 9 [0/74]	loss: 0.211333
# Train Epoch: 9 [10/74]	loss: 0.498011
# Train Epoch: 9 [20/74]	loss: 0.257839
# Train Epoch: 9 [30/74]	loss: 0.326322
# Train Epoch: 9 [40/74]	loss: 0.344418
# Train Epoch: 9 [50/74]	loss: 0.301110
# Train Epoch: 9 [60/74]	loss: 0.332272
# Train Epoch: 9 [70/74]	loss: 0.505860
# [9]Validation Loss: 1.7130,Accuracy: 60.1351%
# Train Epoch: 10 [0/74]	loss: 0.243887
# Train Epoch: 10 [10/74]	loss: 0.338325
# Train Epoch: 10 [20/74]	loss: 0.508964
# Train Epoch: 10 [30/74]	loss: 0.311000
# Train Epoch: 10 [40/74]	loss: 0.376718
# Train Epoch: 10 [50/74]	loss: 0.344193
# Train Epoch: 10 [60/74]	loss: 0.554372
# Train Epoch: 10 [70/74]	loss: 0.806577
# [10]Validation Loss: 1.2530,Accuracy: 72.6351%
# Train Epoch: 11 [0/74]	loss: 0.279009
# Train Epoch: 11 [10/74]	loss: 0.388268
# Train Epoch: 11 [20/74]	loss: 0.338158
# Train Epoch: 11 [30/74]	loss: 0.203441
# Train Epoch: 11 [40/74]	loss: 0.300733
# Train Epoch: 11 [50/74]	loss: 0.516024
# Train Epoch: 11 [60/74]	loss: 0.289617
# Train Epoch: 11 [70/74]	loss: 0.414677
# [11]Validation Loss: 1.5233,Accuracy: 68.5811%
# Train Epoch: 12 [0/74]	loss: 0.168054
# Train Epoch: 12 [10/74]	loss: 0.273051
# Train Epoch: 12 [20/74]	loss: 0.382332
# Train Epoch: 12 [30/74]	loss: 0.288049
# Train Epoch: 12 [40/74]	loss: 0.422736
# Train Epoch: 12 [50/74]	loss: 0.226193
# Train Epoch: 12 [60/74]	loss: 0.470248
# Train Epoch: 12 [70/74]	loss: 0.425757
# [12]Validation Loss: 1.2371,Accuracy: 71.6216%
# Train Epoch: 13 [0/74]	loss: 0.300381
# Train Epoch: 13 [10/74]	loss: 0.361138
# Train Epoch: 13 [20/74]	loss: 0.358922
# Train Epoch: 13 [30/74]	loss: 0.519318
# Train Epoch: 13 [40/74]	loss: 0.595394
# Train Epoch: 13 [50/74]	loss: 0.481189
# Train Epoch: 13 [60/74]	loss: 0.337837
# Train Epoch: 13 [70/74]	loss: 0.508343
# [13]Validation Loss: 1.4740,Accuracy: 63.8514%
# Train Epoch: 14 [0/74]	loss: 0.272662
# Train Epoch: 14 [10/74]	loss: 0.474166
# Train Epoch: 14 [20/74]	loss: 0.500470
# Train Epoch: 14 [30/74]	loss: 0.358514
# Train Epoch: 14 [40/74]	loss: 0.445862
# Train Epoch: 14 [50/74]	loss: 0.264325
# Train Epoch: 14 [60/74]	loss: 0.446013
# Train Epoch: 14 [70/74]	loss: 0.372418
# [14]Validation Loss: 1.2202,Accuracy: 72.9730%
# Train Epoch: 15 [0/74]	loss: 0.362852
# Train Epoch: 15 [10/74]	loss: 0.375371
# Train Epoch: 15 [20/74]	loss: 0.401910
# Train Epoch: 15 [30/74]	loss: 0.372341
# Train Epoch: 15 [40/74]	loss: 0.274021
# Train Epoch: 15 [50/74]	loss: 0.377837
# Train Epoch: 15 [60/74]	loss: 0.377772
# Train Epoch: 15 [70/74]	loss: 0.408784
# [15]Validation Loss: 1.6456,Accuracy: 64.8649%
# Train Epoch: 16 [0/74]	loss: 0.299785
# Train Epoch: 16 [10/74]	loss: 0.414272
# Train Epoch: 16 [20/74]	loss: 0.384863
# Train Epoch: 16 [30/74]	loss: 0.353986
# Train Epoch: 16 [40/74]	loss: 0.372583
# Train Epoch: 16 [50/74]	loss: 0.348441
# Train Epoch: 16 [60/74]	loss: 0.351829
# Train Epoch: 16 [70/74]	loss: 0.348723
# [16]Validation Loss: 1.5112,Accuracy: 64.8649%
# Train Epoch: 17 [0/74]	loss: 0.399924
# Train Epoch: 17 [10/74]	loss: 0.347182
# Train Epoch: 17 [20/74]	loss: 0.254866
# Train Epoch: 17 [30/74]	loss: 0.303896
# Train Epoch: 17 [40/74]	loss: 0.204581
# Train Epoch: 17 [50/74]	loss: 0.344685
# Train Epoch: 17 [60/74]	loss: 0.262940
# Train Epoch: 17 [70/74]	loss: 0.295439
# [17]Validation Loss: 1.5900,Accuracy: 64.8649%
# Train Epoch: 18 [0/74]	loss: 0.330881
# Train Epoch: 18 [10/74]	loss: 0.437645
# Train Epoch: 18 [20/74]	loss: 0.258733
# Train Epoch: 18 [30/74]	loss: 0.365962
# Train Epoch: 18 [40/74]	loss: 0.253682
# Train Epoch: 18 [50/74]	loss: 0.359856
# Train Epoch: 18 [60/74]	loss: 0.260355
# Train Epoch: 18 [70/74]	loss: 0.288942
# [18]Validation Loss: 1.1847,Accuracy: 73.6486%
# Train Epoch: 19 [0/74]	loss: 0.307576
# Train Epoch: 19 [10/74]	loss: 0.398619
# Train Epoch: 19 [20/74]	loss: 0.185076
# Train Epoch: 19 [30/74]	loss: 0.487920
# Train Epoch: 19 [40/74]	loss: 0.428529
# Train Epoch: 19 [50/74]	loss: 0.364107
# Train Epoch: 19 [60/74]	loss: 0.307712
# Train Epoch: 19 [70/74]	loss: 0.297049
# [19]Validation Loss: 1.3996,Accuracy: 66.5541%
# Train Epoch: 20 [0/74]	loss: 0.259690
# Train Epoch: 20 [10/74]	loss: 0.408561
# Train Epoch: 20 [20/74]	loss: 0.236657
# Train Epoch: 20 [30/74]	loss: 0.321284
# Train Epoch: 20 [40/74]	loss: 0.364277
# Train Epoch: 20 [50/74]	loss: 0.306458
# Train Epoch: 20 [60/74]	loss: 0.443564
# Train Epoch: 20 [70/74]	loss: 0.490375
# [20]Validation Loss: 1.4090,Accuracy: 71.2838%
# Train Epoch: 21 [0/74]	loss: 0.355722
# Train Epoch: 21 [10/74]	loss: 0.275104
# Train Epoch: 21 [20/74]	loss: 0.255239
# Train Epoch: 21 [30/74]	loss: 0.457905
# Train Epoch: 21 [40/74]	loss: 0.498953
# Train Epoch: 21 [50/74]	loss: 0.463263
# Train Epoch: 21 [60/74]	loss: 0.352728
# Train Epoch: 21 [70/74]	loss: 0.499256
# [21]Validation Loss: 1.8504,Accuracy: 56.4189%
# Train Epoch: 22 [0/74]	loss: 0.315969
# Train Epoch: 22 [10/74]	loss: 0.393058
# Train Epoch: 22 [20/74]	loss: 0.274079
# Train Epoch: 22 [30/74]	loss: 0.246353
# Train Epoch: 22 [40/74]	loss: 0.321424
# Train Epoch: 22 [50/74]	loss: 0.247370
# Train Epoch: 22 [60/74]	loss: 0.304542
# Train Epoch: 22 [70/74]	loss: 0.440612
# [22]Validation Loss: 1.5624,Accuracy: 66.5541%
# Train Epoch: 23 [0/74]	loss: 0.392227
# Train Epoch: 23 [10/74]	loss: 0.355718
# Train Epoch: 23 [20/74]	loss: 0.602759
# Train Epoch: 23 [30/74]	loss: 0.299073
# Train Epoch: 23 [40/74]	loss: 0.338073
# Train Epoch: 23 [50/74]	loss: 0.407688
# Train Epoch: 23 [60/74]	loss: 0.382532
# Train Epoch: 23 [70/74]	loss: 0.266028
# [23]Validation Loss: 1.5136,Accuracy: 61.8243%
# Train Epoch: 24 [0/74]	loss: 0.298093
# Train Epoch: 24 [10/74]	loss: 0.491300
# Train Epoch: 24 [20/74]	loss: 0.237005
# Train Epoch: 24 [30/74]	loss: 0.365341
# Train Epoch: 24 [40/74]	loss: 0.373746
# Train Epoch: 24 [50/74]	loss: 0.277324
# Train Epoch: 24 [60/74]	loss: 0.330984
# Train Epoch: 24 [70/74]	loss: 0.377085
# [24]Validation Loss: 1.2870,Accuracy: 72.9730%
# Train Epoch: 25 [0/74]	loss: 0.312082
# Train Epoch: 25 [10/74]	loss: 0.211953
# Train Epoch: 25 [20/74]	loss: 0.303493
# Train Epoch: 25 [30/74]	loss: 0.245913
# Train Epoch: 25 [40/74]	loss: 0.253662
# Train Epoch: 25 [50/74]	loss: 0.236927
# Train Epoch: 25 [60/74]	loss: 0.455152
# Train Epoch: 25 [70/74]	loss: 0.311626
# [25]Validation Loss: 1.2742,Accuracy: 75.3378%
# Train Epoch: 26 [0/74]	loss: 0.221464
# Train Epoch: 26 [10/74]	loss: 0.238273
# Train Epoch: 26 [20/74]	loss: 0.227804
# Train Epoch: 26 [30/74]	loss: 0.173458
# Train Epoch: 26 [40/74]	loss: 0.232618
# Train Epoch: 26 [50/74]	loss: 0.334153
# Train Epoch: 26 [60/74]	loss: 0.428646
# Train Epoch: 26 [70/74]	loss: 0.214694
# [26]Validation Loss: 1.9940,Accuracy: 51.3514%
# Train Epoch: 27 [0/74]	loss: 0.235579
# Train Epoch: 27 [10/74]	loss: 0.406707
# Train Epoch: 27 [20/74]	loss: 0.279914
# Train Epoch: 27 [30/74]	loss: 0.265721
# Train Epoch: 27 [40/74]	loss: 0.260291
# Train Epoch: 27 [50/74]	loss: 0.282217
# Train Epoch: 27 [60/74]	loss: 0.378521
# Train Epoch: 27 [70/74]	loss: 0.328128
# [27]Validation Loss: 1.8171,Accuracy: 55.4054%
# Train Epoch: 28 [0/74]	loss: 0.184249
# Train Epoch: 28 [10/74]	loss: 0.306932
# Train Epoch: 28 [20/74]	loss: 0.276476
# Train Epoch: 28 [30/74]	loss: 0.479291
# Train Epoch: 28 [40/74]	loss: 0.355354
# Train Epoch: 28 [50/74]	loss: 0.468955
# Train Epoch: 28 [60/74]	loss: 0.396970
# Train Epoch: 28 [70/74]	loss: 0.521083
# [28]Validation Loss: 1.6724,Accuracy: 67.2297%
# Train Epoch: 29 [0/74]	loss: 0.417232
# Train Epoch: 29 [10/74]	loss: 0.283415
# Train Epoch: 29 [20/74]	loss: 0.259456
# Train Epoch: 29 [30/74]	loss: 0.252333
# Train Epoch: 29 [40/74]	loss: 0.290588
# Train Epoch: 29 [50/74]	loss: 0.295442
# Train Epoch: 29 [60/74]	loss: 0.429219
# Train Epoch: 29 [70/74]	loss: 0.286474
# [29]Validation Loss: 1.7231,Accuracy: 60.1351%
# [FINAL] Test Loss: 1.7399,Accuracy: 60.4027%
# Best Accuracy:  80.4054054054054
# Elasped Time: 0h, 16m, 46s
# time: 0h, 16m, 46s
