# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_AL_test5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# lr 0.1에서 0.0001로 수정, weight_decay 1e-5 설정

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image
#내가 추가
import re

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = re.sub(r'\([^)]*\)', '', label)
    label = int(label)
    return (img, label)

# %%
### Data Preprocessing ###

'''
# 데이터 정규화 추가
# 정규화 변환 정의
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
'''
transforms_train = transforms.Compose([transforms.Resize((448,448)),
                                       transforms.ToTensor()])
transforms_valtest = transforms.Compose([transforms.Resize((448,448)),
                                         transforms.ToTensor()])

BATCH_SIZE = 32
train_set = CUB2011(mode='train',
                    transform=transforms_train)
# transforms_train을 transforms_valtest로 변경
val_set = CUB2011(mode='valid',
                  transform=transforms_valtest)
test_set = CUB2011(mode='test',
                  transform=transforms_valtest)

print('Num of each dataset: ',len(train_set),len(val_set),len(test_set))

train_loader = DataLoader(train_set,batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")

### Model / Optimizer ###
EPOCH = 30
lr = 0.0001

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(),lr=lr, weight_decay=1e-5)

print("Created a learning model and optimizer")
# Out:
# Num of each dataset:  2362 296 298
# Loaded dataloader
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    # loss func을 어떤 것을 사용할 것인지?
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/74]	loss: 4.072159
# Train Epoch: 0 [10/74]	loss: 3.695137
# Train Epoch: 0 [20/74]	loss: 3.312493
# Train Epoch: 0 [30/74]	loss: 3.210846
# Train Epoch: 0 [40/74]	loss: 2.991260
# Train Epoch: 0 [50/74]	loss: 2.753297
# Train Epoch: 0 [60/74]	loss: 2.344062
# Train Epoch: 0 [70/74]	loss: 2.340042
# [0]Validation Loss: 2.0349,Accuracy: 63.1757%
# Train Epoch: 1 [0/74]	loss: 1.958503
# Train Epoch: 1 [10/74]	loss: 1.688022
# Train Epoch: 1 [20/74]	loss: 1.675760
# Train Epoch: 1 [30/74]	loss: 1.471491
# Train Epoch: 1 [40/74]	loss: 1.603213
# Train Epoch: 1 [50/74]	loss: 1.542952
# Train Epoch: 1 [60/74]	loss: 1.415194
# Train Epoch: 1 [70/74]	loss: 1.385860
# [1]Validation Loss: 1.4832,Accuracy: 76.3514%
# Train Epoch: 2 [0/74]	loss: 1.026178
# Train Epoch: 2 [10/74]	loss: 0.960873
# Train Epoch: 2 [20/74]	loss: 0.916540
# Train Epoch: 2 [30/74]	loss: 0.725605
# Train Epoch: 2 [40/74]	loss: 0.977618
# Train Epoch: 2 [50/74]	loss: 0.849197
# Train Epoch: 2 [60/74]	loss: 0.706852
# Train Epoch: 2 [70/74]	loss: 0.716108
# [2]Validation Loss: 0.9525,Accuracy: 84.4595%
# Train Epoch: 3 [0/74]	loss: 0.524408
# Train Epoch: 3 [10/74]	loss: 0.425235
# Train Epoch: 3 [20/74]	loss: 0.394892
# Train Epoch: 3 [30/74]	loss: 0.374055
# Train Epoch: 3 [40/74]	loss: 0.349140
# Train Epoch: 3 [50/74]	loss: 0.434263
# Train Epoch: 3 [60/74]	loss: 0.418194
# Train Epoch: 3 [70/74]	loss: 0.533703
# [3]Validation Loss: 0.9035,Accuracy: 85.8108%
# Train Epoch: 4 [0/74]	loss: 0.182853
# Train Epoch: 4 [10/74]	loss: 0.191237
# Train Epoch: 4 [20/74]	loss: 0.223586
# Train Epoch: 4 [30/74]	loss: 0.214958
# Train Epoch: 4 [40/74]	loss: 0.196833
# Train Epoch: 4 [50/74]	loss: 0.177521
# Train Epoch: 4 [60/74]	loss: 0.171831
# Train Epoch: 4 [70/74]	loss: 0.157578
# [4]Validation Loss: 0.7313,Accuracy: 87.5000%
# Train Epoch: 5 [0/74]	loss: 0.118347
# Train Epoch: 5 [10/74]	loss: 0.098261
# Train Epoch: 5 [20/74]	loss: 0.106661
# Train Epoch: 5 [30/74]	loss: 0.088911
# Train Epoch: 5 [40/74]	loss: 0.113404
# Train Epoch: 5 [50/74]	loss: 0.124729
# Train Epoch: 5 [60/74]	loss: 0.126491
# Train Epoch: 5 [70/74]	loss: 0.077835
# [5]Validation Loss: 0.6757,Accuracy: 88.1757%
# Train Epoch: 6 [0/74]	loss: 0.093332
# Train Epoch: 6 [10/74]	loss: 0.089812
# Train Epoch: 6 [20/74]	loss: 0.091460
# Train Epoch: 6 [30/74]	loss: 0.093318
# Train Epoch: 6 [40/74]	loss: 0.071255
# Train Epoch: 6 [50/74]	loss: 0.077997
# Train Epoch: 6 [60/74]	loss: 0.064559
# Train Epoch: 6 [70/74]	loss: 0.059629
# [6]Validation Loss: 0.6739,Accuracy: 87.8378%
# Train Epoch: 7 [0/74]	loss: 0.052307
# Train Epoch: 7 [10/74]	loss: 0.050393
# Train Epoch: 7 [20/74]	loss: 0.049833
# Train Epoch: 7 [30/74]	loss: 0.057957
# Train Epoch: 7 [40/74]	loss: 0.060599
# Train Epoch: 7 [50/74]	loss: 0.035833
# Train Epoch: 7 [60/74]	loss: 0.034398
# Train Epoch: 7 [70/74]	loss: 0.051524
# [7]Validation Loss: 0.6404,Accuracy: 88.1757%
# Train Epoch: 8 [0/74]	loss: 0.026056
# Train Epoch: 8 [10/74]	loss: 0.032323
# Train Epoch: 8 [20/74]	loss: 0.036379
# Train Epoch: 8 [30/74]	loss: 0.032670
# Train Epoch: 8 [40/74]	loss: 0.047044
# Train Epoch: 8 [50/74]	loss: 0.038298
# Train Epoch: 8 [60/74]	loss: 0.031217
# Train Epoch: 8 [70/74]	loss: 0.024851
# [8]Validation Loss: 0.6229,Accuracy: 89.1892%
# Train Epoch: 9 [0/74]	loss: 0.029330
# Train Epoch: 9 [10/74]	loss: 0.034576
# Train Epoch: 9 [20/74]	loss: 0.021403
# Train Epoch: 9 [30/74]	loss: 0.026790
# Train Epoch: 9 [40/74]	loss: 0.029823
# Train Epoch: 9 [50/74]	loss: 0.030117
# Train Epoch: 9 [60/74]	loss: 0.030889
# Train Epoch: 9 [70/74]	loss: 0.037106
# [9]Validation Loss: 0.6107,Accuracy: 88.8514%
# Train Epoch: 10 [0/74]	loss: 0.022768
# Train Epoch: 10 [10/74]	loss: 0.020679
# Train Epoch: 10 [20/74]	loss: 0.016827
# Train Epoch: 10 [30/74]	loss: 0.031069
# Train Epoch: 10 [40/74]	loss: 0.022971
# Train Epoch: 10 [50/74]	loss: 0.022770
# Train Epoch: 10 [60/74]	loss: 0.015171
# Train Epoch: 10 [70/74]	loss: 0.021228
# [10]Validation Loss: 0.5988,Accuracy: 89.8649%
# Train Epoch: 11 [0/74]	loss: 0.017660
# Train Epoch: 11 [10/74]	loss: 0.018531
# Train Epoch: 11 [20/74]	loss: 0.021856
# Train Epoch: 11 [30/74]	loss: 0.017192
# Train Epoch: 11 [40/74]	loss: 0.018038
# Train Epoch: 11 [50/74]	loss: 0.018325
# Train Epoch: 11 [60/74]	loss: 0.015477
# Train Epoch: 11 [70/74]	loss: 0.027170
# [11]Validation Loss: 0.5928,Accuracy: 89.8649%
# Train Epoch: 12 [0/74]	loss: 0.017248
# Train Epoch: 12 [10/74]	loss: 0.015483
# Train Epoch: 12 [20/74]	loss: 0.013596
# Train Epoch: 12 [30/74]	loss: 0.014308
# Train Epoch: 12 [40/74]	loss: 0.013949
# Train Epoch: 12 [50/74]	loss: 0.022786
# Train Epoch: 12 [60/74]	loss: 0.017074
# Train Epoch: 12 [70/74]	loss: 0.014627
# [12]Validation Loss: 0.5787,Accuracy: 89.1892%
# Train Epoch: 13 [0/74]	loss: 0.013144
# Train Epoch: 13 [10/74]	loss: 0.012187
# Train Epoch: 13 [20/74]	loss: 0.015098
# Train Epoch: 13 [30/74]	loss: 0.017178
# Train Epoch: 13 [40/74]	loss: 0.011099
# Train Epoch: 13 [50/74]	loss: 0.012261
# Train Epoch: 13 [60/74]	loss: 0.013434
# Train Epoch: 13 [70/74]	loss: 0.016201
# [13]Validation Loss: 0.5704,Accuracy: 88.8514%
# Train Epoch: 14 [0/74]	loss: 0.008477
# Train Epoch: 14 [10/74]	loss: 0.028064
# Train Epoch: 14 [20/74]	loss: 0.010118
# Train Epoch: 14 [30/74]	loss: 0.009962
# Train Epoch: 14 [40/74]	loss: 0.012932
# Train Epoch: 14 [50/74]	loss: 0.011172
# Train Epoch: 14 [60/74]	loss: 0.011280
# Train Epoch: 14 [70/74]	loss: 0.009695
# [14]Validation Loss: 0.5555,Accuracy: 89.5270%
# Train Epoch: 15 [0/74]	loss: 0.009322
# Train Epoch: 15 [10/74]	loss: 0.011455
# Train Epoch: 15 [20/74]	loss: 0.010721
# Train Epoch: 15 [30/74]	loss: 0.010514
# Train Epoch: 15 [40/74]	loss: 0.013860
# Train Epoch: 15 [50/74]	loss: 0.012355
# Train Epoch: 15 [60/74]	loss: 0.009493
# Train Epoch: 15 [70/74]	loss: 0.007553
# [15]Validation Loss: 0.5478,Accuracy: 89.1892%
# Train Epoch: 16 [0/74]	loss: 0.008209
# Train Epoch: 16 [10/74]	loss: 0.010061
# Train Epoch: 16 [20/74]	loss: 0.008423
# Train Epoch: 16 [30/74]	loss: 0.008784
# Train Epoch: 16 [40/74]	loss: 0.010181
# Train Epoch: 16 [50/74]	loss: 0.007427
# Train Epoch: 16 [60/74]	loss: 0.012315
# Train Epoch: 16 [70/74]	loss: 0.006704
# [16]Validation Loss: 0.5481,Accuracy: 90.2027%
# Train Epoch: 17 [0/74]	loss: 0.008895
# Train Epoch: 17 [10/74]	loss: 0.011879
# Train Epoch: 17 [20/74]	loss: 0.010931
# Train Epoch: 17 [30/74]	loss: 0.008124
# Train Epoch: 17 [40/74]	loss: 0.007076
# Train Epoch: 17 [50/74]	loss: 0.007811
# Train Epoch: 17 [60/74]	loss: 0.012419
# Train Epoch: 17 [70/74]	loss: 0.007300
# [17]Validation Loss: 0.5529,Accuracy: 89.5270%
# Train Epoch: 18 [0/74]	loss: 0.006427
# Train Epoch: 18 [10/74]	loss: 0.008663
# Train Epoch: 18 [20/74]	loss: 0.008176
# Train Epoch: 18 [30/74]	loss: 0.006426
# Train Epoch: 18 [40/74]	loss: 0.005222
# Train Epoch: 18 [50/74]	loss: 0.006871
# Train Epoch: 18 [60/74]	loss: 0.006400
# Train Epoch: 18 [70/74]	loss: 0.006778
# [18]Validation Loss: 0.5495,Accuracy: 89.5270%
# Train Epoch: 19 [0/74]	loss: 0.007535
# Train Epoch: 19 [10/74]	loss: 0.008494
# Train Epoch: 19 [20/74]	loss: 0.004759
# Train Epoch: 19 [30/74]	loss: 0.010661
# Train Epoch: 19 [40/74]	loss: 0.008439
# Train Epoch: 19 [50/74]	loss: 0.006053
# Train Epoch: 19 [60/74]	loss: 0.007415
# Train Epoch: 19 [70/74]	loss: 0.004238
# [19]Validation Loss: 0.5512,Accuracy: 88.8514%
# Train Epoch: 20 [0/74]	loss: 0.005498
# Train Epoch: 20 [10/74]	loss: 0.006738
# Train Epoch: 20 [20/74]	loss: 0.005227
# Train Epoch: 20 [30/74]	loss: 0.008016
# Train Epoch: 20 [40/74]	loss: 0.004511
# Train Epoch: 20 [50/74]	loss: 0.005474
# Train Epoch: 20 [60/74]	loss: 0.004785
# Train Epoch: 20 [70/74]	loss: 0.004205
# [20]Validation Loss: 0.5407,Accuracy: 89.5270%
# Train Epoch: 21 [0/74]	loss: 0.005375
# Train Epoch: 21 [10/74]	loss: 0.004230
# Train Epoch: 21 [20/74]	loss: 0.005360
# Train Epoch: 21 [30/74]	loss: 0.004075
# Train Epoch: 21 [40/74]	loss: 0.005184
# Train Epoch: 21 [50/74]	loss: 0.007120
# Train Epoch: 21 [60/74]	loss: 0.004326
# Train Epoch: 21 [70/74]	loss: 0.006918
# [21]Validation Loss: 0.5428,Accuracy: 89.8649%
# Train Epoch: 22 [0/74]	loss: 0.003842
# Train Epoch: 22 [10/74]	loss: 0.004332
# Train Epoch: 22 [20/74]	loss: 0.005453
# Train Epoch: 22 [30/74]	loss: 0.005618
# Train Epoch: 22 [40/74]	loss: 0.008933
# Train Epoch: 22 [50/74]	loss: 0.005921
# Train Epoch: 22 [60/74]	loss: 0.006167
# Train Epoch: 22 [70/74]	loss: 0.003814
# [22]Validation Loss: 0.5403,Accuracy: 88.8514%
# Train Epoch: 23 [0/74]	loss: 0.005435
# Train Epoch: 23 [10/74]	loss: 0.005220
# Train Epoch: 23 [20/74]	loss: 0.006507
# Train Epoch: 23 [30/74]	loss: 0.004301
# Train Epoch: 23 [40/74]	loss: 0.003661
# Train Epoch: 23 [50/74]	loss: 0.004572
# Train Epoch: 23 [60/74]	loss: 0.004461
# Train Epoch: 23 [70/74]	loss: 0.004841
# [23]Validation Loss: 0.5298,Accuracy: 89.5270%
# Train Epoch: 24 [0/74]	loss: 0.004062
# Train Epoch: 24 [10/74]	loss: 0.008019
# Train Epoch: 24 [20/74]	loss: 0.004406
# Train Epoch: 24 [30/74]	loss: 0.005457
# Train Epoch: 24 [40/74]	loss: 0.004594
# Train Epoch: 24 [50/74]	loss: 0.004562
# Train Epoch: 24 [60/74]	loss: 0.004031
# Train Epoch: 24 [70/74]	loss: 0.003459
# [24]Validation Loss: 0.5323,Accuracy: 89.1892%
# Train Epoch: 25 [0/74]	loss: 0.003471
# Train Epoch: 25 [10/74]	loss: 0.003143
# Train Epoch: 25 [20/74]	loss: 0.005075
# Train Epoch: 25 [30/74]	loss: 0.003343
# Train Epoch: 25 [40/74]	loss: 0.004093
# Train Epoch: 25 [50/74]	loss: 0.004198
# Train Epoch: 25 [60/74]	loss: 0.004132
# Train Epoch: 25 [70/74]	loss: 0.003255
# [25]Validation Loss: 0.5254,Accuracy: 89.1892%
# Train Epoch: 26 [0/74]	loss: 0.003004
# Train Epoch: 26 [10/74]	loss: 0.006079
# Train Epoch: 26 [20/74]	loss: 0.004574
# Train Epoch: 26 [30/74]	loss: 0.003229
# Train Epoch: 26 [40/74]	loss: 0.002823
# Train Epoch: 26 [50/74]	loss: 0.003741
# Train Epoch: 26 [60/74]	loss: 0.003995
# Train Epoch: 26 [70/74]	loss: 0.004465
# [26]Validation Loss: 0.5325,Accuracy: 89.5270%
# Train Epoch: 27 [0/74]	loss: 0.003334
# Train Epoch: 27 [10/74]	loss: 0.003306
# Train Epoch: 27 [20/74]	loss: 0.003205
# Train Epoch: 27 [30/74]	loss: 0.004240
# Train Epoch: 27 [40/74]	loss: 0.003174
# Train Epoch: 27 [50/74]	loss: 0.004193
# Train Epoch: 27 [60/74]	loss: 0.004160
# Train Epoch: 27 [70/74]	loss: 0.003413
# [27]Validation Loss: 0.5358,Accuracy: 89.5270%
# Train Epoch: 28 [0/74]	loss: 0.003144
# Train Epoch: 28 [10/74]	loss: 0.003173
# Train Epoch: 28 [20/74]	loss: 0.003563
# Train Epoch: 28 [30/74]	loss: 0.002393
# Train Epoch: 28 [40/74]	loss: 0.003552
# Train Epoch: 28 [50/74]	loss: 0.003728
# Train Epoch: 28 [60/74]	loss: 0.001983
# Train Epoch: 28 [70/74]	loss: 0.003403
# [28]Validation Loss: 0.5287,Accuracy: 89.8649%
# Train Epoch: 29 [0/74]	loss: 0.001947
# Train Epoch: 29 [10/74]	loss: 0.002589
# Train Epoch: 29 [20/74]	loss: 0.002607
# Train Epoch: 29 [30/74]	loss: 0.002251
# Train Epoch: 29 [40/74]	loss: 0.002166
# Train Epoch: 29 [50/74]	loss: 0.002080
# Train Epoch: 29 [60/74]	loss: 0.002491
# Train Epoch: 29 [70/74]	loss: 0.001978
# [29]Validation Loss: 0.5289,Accuracy: 89.5270%
# [FINAL] Test Loss: 0.5333,Accuracy: 88.5906%
# Best Accuracy:  90.20270270270271
# Elasped Time: 0h, 16m, 47s
# time: 0h, 16m, 47s
