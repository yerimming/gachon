# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_AL2_EfficientNet(9)_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   AdamP optimizer 사용
# *   Label Smoothing
# *   EfficientNet 모델 사용
# *   get_cosine_schedule_with_warmup 스케줄러 사용
# *   class_num = 200

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install wandb                        # Install Weight%Biases
# !pip3 install adamp
# !pip install efficientnet_pytorch
# Out:
# Collecting wandb
#   Downloading wandb-0.16.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 25.9 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 27.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.34.0-py2.py3-none-any.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 36.4 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.40 docker-pycreds-0.4.0 gitdb-4.0.11 sentry-sdk-1.34.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.16.0
# Collecting adamp
#   Downloading adamp-0.3.0.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: adamp
#   Building wheel for adamp (setup.py) ... done
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5982 sha256=5424d6f850879d4b5c7dc751d4eed79fe9210a9bcd01ed86c6371b8bcd44920c
#   Stored in directory: /root/.cache/pip/wheels/c7/ad/0f/b41b1c45b18c66e5eef5d2254415af8055c7e2b0934145157d
# Successfully built adamp
# Installing collected packages: adamp
# Successfully installed adamp-0.3.0
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet_pytorch
#   Building wheel for efficientnet_pytorch (setup.py) ... done
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16428 sha256=473e99cfe6aed036aea69b1ac524f5f4821f133ddad28635557702c4700090b2
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# Installing collected packages: efficientnet_pytorch
# Successfully installed efficientnet_pytorch-0.7.1

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image,ImageEnhance

from efficientnet_pytorch import EfficientNet

from torch.utils.data import ConcatDataset
from collections import Counter

from adamp import AdamP

import numpy as np

import wandb    # Import Weight&Biases

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
wandb.login()     # Login to Weight&Biaes
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# initialize Weight&Biases settings
run = wandb.init(project="Active_learning_2", notes = "CV_AL_2_final.ver", name = "efficientnet-b0(3)")

cfg = {
    "architecture": "CNN",
    "dataset": "CUB2011",
    "classes": 200,
    "learning_rate": 1e-4,
    "epochs": 30,
    "batch_size": 8
}
wandb.config.update(cfg)



# Define Hyperparameters
lr = cfg['learning_rate']
BATCH_SIZE = cfg['batch_size']
EPOCH = cfg['epochs']
print("\n<Hyperparameters>\nEPOCH = {}\nBATCH SIZE = {}\nLearning rate = {}\t" .format(EPOCH, BATCH_SIZE, lr))

### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = int(label)
    return (img, label)
# Out:
# Finishing last run (ID:fsorinip) before initializing another...
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">driven-firebrand-2</strong> at: <a href='https://wandb.ai/cv_al2/Active_learning_2/runs/fsorinip' target="_blank">https://wandb.ai/cv_al2/Active_learning_2/runs/fsorinip</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231112_070302-fsorinip/logs</code>
# Successfully finished last run (ID:fsorinip). Initializing new run:<br/>
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/content/wandb/run-20231112_070347-mslqh5s5</code>
# Syncing run <strong><a href='https://wandb.ai/cv_al2/Active_learning_2/runs/mslqh5s5' target="_blank">snowy-tree-3</a></strong> to <a href='https://wandb.ai/cv_al2/Active_learning_2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/cv_al2/Active_learning_2' target="_blank">https://wandb.ai/cv_al2/Active_learning_2</a>
#  View run at <a href='https://wandb.ai/cv_al2/Active_learning_2/runs/mslqh5s5' target="_blank">https://wandb.ai/cv_al2/Active_learning_2/runs/mslqh5s5</a>
# <Hyperparameters>
# EPOCH = 30
# BATCH SIZE = 8
# Learning rate = 0.0001

# %%
# Geomentric transform + Visual corruptions
class AddGaussianNoise(object):
    def __init__(self, mean=0, std=1, p=0.5):
        self.mean = mean
        self.std = std
        self.p = p

    def __call__(self, img):
        if np.random.rand() < self.p:
            img_array = np.array(img)
            noise = np.random.normal(self.mean, self.std, img_array.shape)
            noisy_image = np.clip(img_array + noise, 0, 255)  # Clip values to the range [0, 255]
            return Image.fromarray(noisy_image.astype(np.uint8))
        else:
            return img

    def __repr__(self):
        return self.__class__.__name__ + f'(mean={self.mean}, std={self.std}, p={self.p})'


class AdjustContrast(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

class AdjustBrightness(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Brightness(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

# %%
### Data Preprocessing & Data Augmentation ###
transforms_train_origin = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.ToTensor(),])

transforms_test = transforms.Compose([
    transforms.Resize((448,448)),
    transforms.ToTensor(),])

# Geomentric transform + Visual corruptions
transforms_train_g_v = transforms.Compose([
    transforms.Resize((448, 448)),
    #transforms.RandomResizedCrop(448),
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandomVerticalFlip(0.5),
    transforms.RandomRotation(30),
    AddGaussianNoise(mean=0, std=25, p=0.5),  # 가우시안 노이즈를 추가합니다.
    AdjustContrast(factor=2.0),  # 대비를 조절합니다.
    AdjustBrightness(factor=1.5),  # 밝기를 조절합니다.
    transforms.ToTensor(),
])

BATCH_SIZE = 8

train_set_origin = CUB2011(mode='train',
                    transform=transforms_train_origin)
val_set = CUB2011(mode='valid',
                  transform=transforms_test)
test_set = CUB2011(mode='test',
                  transform=transforms_test)

train_set_augmented2 = CUB2011(mode='train',transform=transforms_train_g_v) # 2)

train_loader = DataLoader(train_set_origin,batch_size=BATCH_SIZE,shuffle=True)

# 다 합친거
train_set_combined = ConcatDataset([train_set_origin,train_set_augmented2])

print('Num of each dataset: ',len(train_set_combined),len(val_set),len(test_set))

# Dataloader class는 bath기반의 딥러닝모델 학습을 위해서 mini batch를 만들어주는 역할을 한다
# dataloader를 통해 dataset의 전체 데이터가 batch size로 나뉘게 된다
train_loader = DataLoader(train_set_combined, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")
# Out:
# Num of each dataset:  4720 296 298
# Loaded dataloader

# %%
import matplotlib.pyplot as plt

# Define the number of rows and columns for the grid
num_rows = 4  # You can change this to the desired number of rows
num_cols = 4  # You can change this to the desired number of columns

# Function to unnormalize and display a grid of images
def imshow_grid(images, num_rows, num_cols):
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 10))
    for i in range(num_rows):
        for j in range(num_cols):
            index = i * num_cols + j
            if index < len(images):
                img = images[index] / 2 + 0.5  # Unnormalize the image
                npimg = img.numpy()
                ax = axes[i, j]
                ax.imshow(np.transpose(npimg, (1, 2, 0)))
                ax.axis('off')

    plt.show()

# Iterate through the train_loader
for batch_idx, (images, labels) in enumerate(train_loader):
    if batch_idx >= 3:
        break  # Stop after visualizing the specified number of batches

    print(f"Batch {batch_idx + 1}")
    imshow_grid(images, num_rows, num_cols)  # Display the grid of images

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 39.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 38.0 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 39.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.35.0

# %%
from transformers import get_cosine_schedule_with_warmup

### Model / Optimizer ###
EPOCH = 30
lr = 0.0001

model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=200)
print(model)

### Tranfer Learning ###
'''
num_features = model.classifier.in_features
model.fc = nn.Linear(num_features,50)
'''
model.to(DEVICE)

optimizer = AdamP(model.parameters(), lr=lr)

scheduler = get_cosine_schedule_with_warmup(optimizer,
                                    num_warmup_steps=len(train_loader)*3,
                                    num_training_steps=len(train_loader)*EPOCH)

print("Created a learning model and optimizer")
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100%|██████████| 20.4M/20.4M [00:00<00:00, 154MB/s]
# Loaded pretrained weights for efficientnet-b0
# EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d((0, 1, 0, 1))
#   )
#   (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (1): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#         (static_padding): ZeroPad2d((0, 1, 0, 1))
#       )
#       (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         96, 4, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         4, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (2): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#         (static_padding): ZeroPad2d((1, 2, 1, 2))
#       )
#       (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         144, 6, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         6, 144, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#         (static_padding): ZeroPad2d((0, 1, 0, 1))
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (6-7): 2 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (9-10): 2 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#         (static_padding): ZeroPad2d((1, 2, 1, 2))
#       )
#       (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         672, 28, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         28, 672, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (12-14): 3 x MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#         (static_padding): ZeroPad2d((2, 2, 2, 2))
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#         (static_padding): ZeroPad2d((1, 1, 1, 1))
#       )
#       (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1152, 48, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         48, 1152, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (_conv_head): Conv2dStaticSamePadding(
#     320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#     (static_padding): Identity()
#   )
#   (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#   (_dropout): Dropout(p=0.2, inplace=False)
#   (_fc): Linear(in_features=1280, out_features=200, bias=True)
#   (_swish): MemoryEfficientSwish()
# )
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch, scheduler):
  model.train()
  criterion = nn.CrossEntropyLoss(label_smoothing=0.11)
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    train_loss = criterion(output,target)

    train_loss.backward()
    optimizer.step()

    if scheduler != None:
      scheduler.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

wandb.define_metric("train_loss", summary = "min")
wandb.define_metric("val_loss", summary = "min")
wandb.define_metric("val_acc", summary = "max")

# %%
### Main ###
start = time.time()
best = 0
train_losses = []  # 훈련 손실을 저장할 목록
val_losses = []    # 검증 손실을 저장할 목록
val_accuracys = []

for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch, scheduler)
  val_loss,val_accuracy = evaluate(model,val_loader)
  # Log train loss, validation loss, and validation accuracy into Weight & Biases by the function of epoch
  wandb.log({"train_loss": train_loss, "val_loss": val_loss, "val_acc": val_accuracy}, step=epoch)

# 훈련 및 검증 손실을 목록에 추가
  train_losses.append(train_loss)
  val_losses.append(val_loss)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  val_accuracys.append(val_accuracy)
  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")


# Finish Weight & Biases
wandb.finish()
# Out:
# Train Epoch: 0 [0/590]	loss: 5.316823
# Train Epoch: 0 [10/590]	loss: 5.224382
# Train Epoch: 0 [20/590]	loss: 5.216716
# Train Epoch: 0 [30/590]	loss: 5.237330
# Train Epoch: 0 [40/590]	loss: 5.230913
# Train Epoch: 0 [50/590]	loss: 5.218343
# Train Epoch: 0 [60/590]	loss: 5.292959
# Train Epoch: 0 [70/590]	loss: 5.310737
# Train Epoch: 0 [80/590]	loss: 5.294342
# Train Epoch: 0 [90/590]	loss: 5.246967
# Train Epoch: 0 [100/590]	loss: 5.242859
# Train Epoch: 0 [110/590]	loss: 5.218513
# Train Epoch: 0 [120/590]	loss: 5.234756
# Train Epoch: 0 [130/590]	loss: 5.242126
# Train Epoch: 0 [140/590]	loss: 5.310105
# Train Epoch: 0 [150/590]	loss: 5.279877
# Train Epoch: 0 [160/590]	loss: 5.250822
# Train Epoch: 0 [170/590]	loss: 5.176746
# Train Epoch: 0 [180/590]	loss: 5.223146
# Train Epoch: 0 [190/590]	loss: 5.164922
# Train Epoch: 0 [200/590]	loss: 5.267459
# Train Epoch: 0 [210/590]	loss: 5.227059
# Train Epoch: 0 [220/590]	loss: 5.140690
# Train Epoch: 0 [230/590]	loss: 5.142663
# Train Epoch: 0 [240/590]	loss: 5.134569
# Train Epoch: 0 [250/590]	loss: 5.100009
# Train Epoch: 0 [260/590]	loss: 5.034884
# Train Epoch: 0 [270/590]	loss: 5.091056
# Train Epoch: 0 [280/590]	loss: 5.030699
# Train Epoch: 0 [290/590]	loss: 4.932813
# Train Epoch: 0 [300/590]	loss: 4.939618
# Train Epoch: 0 [310/590]	loss: 4.934311
# Train Epoch: 0 [320/590]	loss: 4.866770
# Train Epoch: 0 [330/590]	loss: 4.851659
# Train Epoch: 0 [340/590]	loss: 4.859569
# Train Epoch: 0 [350/590]	loss: 4.900717
# Train Epoch: 0 [360/590]	loss: 4.916251
# Train Epoch: 0 [370/590]	loss: 4.775985
# Train Epoch: 0 [380/590]	loss: 4.752621
# Train Epoch: 0 [390/590]	loss: 4.690299
# Train Epoch: 0 [400/590]	loss: 4.834876
# Train Epoch: 0 [410/590]	loss: 4.559491
# Train Epoch: 0 [420/590]	loss: 4.711987
# Train Epoch: 0 [430/590]	loss: 4.681200
# Train Epoch: 0 [440/590]	loss: 4.534925
# Train Epoch: 0 [450/590]	loss: 4.638747
# Train Epoch: 0 [460/590]	loss: 4.593368
# Train Epoch: 0 [470/590]	loss: 4.456359
# Train Epoch: 0 [480/590]	loss: 4.523893
# Train Epoch: 0 [490/590]	loss: 4.487831
# Train Epoch: 0 [500/590]	loss: 4.420475
# Train Epoch: 0 [510/590]	loss: 4.354481
# Train Epoch: 0 [520/590]	loss: 4.433436
# Train Epoch: 0 [530/590]	loss: 4.369280
# Train Epoch: 0 [540/590]	loss: 4.285792
# Train Epoch: 0 [550/590]	loss: 4.384477
# Train Epoch: 0 [560/590]	loss: 4.202928
# Train Epoch: 0 [570/590]	loss: 4.288353
# Train Epoch: 0 [580/590]	loss: 4.358446
# [0]Validation Loss: 3.9308,Accuracy: 13.5135%
# Train Epoch: 1 [0/590]	loss: 4.220922
# Train Epoch: 1 [10/590]	loss: 4.313511
# Train Epoch: 1 [20/590]	loss: 4.297382
# Train Epoch: 1 [30/590]	loss: 4.240235
# Train Epoch: 1 [40/590]	loss: 4.217615
# Train Epoch: 1 [50/590]	loss: 4.216521
# Train Epoch: 1 [60/590]	loss: 4.318882
# Train Epoch: 1 [70/590]	loss: 4.169614
# Train Epoch: 1 [80/590]	loss: 4.032179
# Train Epoch: 1 [90/590]	loss: 4.094992
# Train Epoch: 1 [100/590]	loss: 3.982667
# Train Epoch: 1 [110/590]	loss: 4.085767
# Train Epoch: 1 [120/590]	loss: 4.066927
# Train Epoch: 1 [130/590]	loss: 4.013710
# Train Epoch: 1 [140/590]	loss: 4.105379
# Train Epoch: 1 [150/590]	loss: 4.146630
# Train Epoch: 1 [160/590]	loss: 3.946486
# Train Epoch: 1 [170/590]	loss: 3.980898
# Train Epoch: 1 [180/590]	loss: 4.137950
# Train Epoch: 1 [190/590]	loss: 4.073484
# Train Epoch: 1 [200/590]	loss: 4.053619
# Train Epoch: 1 [210/590]	loss: 4.006441
# Train Epoch: 1 [220/590]	loss: 4.087528
# Train Epoch: 1 [230/590]	loss: 3.983702
# Train Epoch: 1 [240/590]	loss: 3.863734
# Train Epoch: 1 [250/590]	loss: 4.070888
# Train Epoch: 1 [260/590]	loss: 3.838180
# Train Epoch: 1 [270/590]	loss: 3.798740
# Train Epoch: 1 [280/590]	loss: 3.964263
# Train Epoch: 1 [290/590]	loss: 3.980230
# Train Epoch: 1 [300/590]	loss: 3.930255
# Train Epoch: 1 [310/590]	loss: 3.735626
# Train Epoch: 1 [320/590]	loss: 3.687194
# Train Epoch: 1 [330/590]	loss: 3.925287
# Train Epoch: 1 [340/590]	loss: 3.744166
# Train Epoch: 1 [350/590]	loss: 3.954177
# Train Epoch: 1 [360/590]	loss: 3.596966
# Train Epoch: 1 [370/590]	loss: 3.701151
# Train Epoch: 1 [380/590]	loss: 3.594044
# Train Epoch: 1 [390/590]	loss: 3.698221
# Train Epoch: 1 [400/590]	loss: 3.476604
# Train Epoch: 1 [410/590]	loss: 3.552987
# Train Epoch: 1 [420/590]	loss: 3.560951
# Train Epoch: 1 [430/590]	loss: 3.627445
# Train Epoch: 1 [440/590]	loss: 3.638386
# Train Epoch: 1 [450/590]	loss: 3.843305
# Train Epoch: 1 [460/590]	loss: 3.469761
# Train Epoch: 1 [470/590]	loss: 3.148982
# Train Epoch: 1 [480/590]	loss: 3.377707
# Train Epoch: 1 [490/590]	loss: 3.480479
# Train Epoch: 1 [500/590]	loss: 3.347255
# Train Epoch: 1 [510/590]	loss: 3.361713
# Train Epoch: 1 [520/590]	loss: 3.212750
# Train Epoch: 1 [530/590]	loss: 3.327477
# Train Epoch: 1 [540/590]	loss: 3.242095
# Train Epoch: 1 [550/590]	loss: 3.223662
# Train Epoch: 1 [560/590]	loss: 3.156565
# Train Epoch: 1 [570/590]	loss: 3.044559
# Train Epoch: 1 [580/590]	loss: 3.282996
# [1]Validation Loss: 2.2107,Accuracy: 55.0676%
# Train Epoch: 2 [0/590]	loss: 3.203856
# Train Epoch: 2 [10/590]	loss: 2.866832
# Train Epoch: 2 [20/590]	loss: 3.989069
# Train Epoch: 2 [30/590]	loss: 3.032550
# Train Epoch: 2 [40/590]	loss: 2.664265
# Train Epoch: 2 [50/590]	loss: 3.062655
# Train Epoch: 2 [60/590]	loss: 3.425280
# Train Epoch: 2 [70/590]	loss: 2.907688
# Train Epoch: 2 [80/590]	loss: 2.984579
# Train Epoch: 2 [90/590]	loss: 3.533585
# Train Epoch: 2 [100/590]	loss: 2.690504
# Train Epoch: 2 [110/590]	loss: 2.996878
# Train Epoch: 2 [120/590]	loss: 3.173186
# Train Epoch: 2 [130/590]	loss: 2.842403
# Train Epoch: 2 [140/590]	loss: 2.906267
# Train Epoch: 2 [150/590]	loss: 3.119127
# Train Epoch: 2 [160/590]	loss: 2.976396
# Train Epoch: 2 [170/590]	loss: 2.887762
# Train Epoch: 2 [180/590]	loss: 2.613319
# Train Epoch: 2 [190/590]	loss: 2.752680
# Train Epoch: 2 [200/590]	loss: 2.913833
# Train Epoch: 2 [210/590]	loss: 2.771189
# Train Epoch: 2 [220/590]	loss: 2.514778
# Train Epoch: 2 [230/590]	loss: 2.635588
# Train Epoch: 2 [240/590]	loss: 2.319482
# Train Epoch: 2 [250/590]	loss: 2.231255
# Train Epoch: 2 [260/590]	loss: 2.738678
# Train Epoch: 2 [270/590]	loss: 2.319767
# Train Epoch: 2 [280/590]	loss: 3.228173
# Train Epoch: 2 [290/590]	loss: 2.431555
# Train Epoch: 2 [300/590]	loss: 2.332794
# Train Epoch: 2 [310/590]	loss: 2.871753
# Train Epoch: 2 [320/590]	loss: 2.575768
# Train Epoch: 2 [330/590]	loss: 2.342570
# Train Epoch: 2 [340/590]	loss: 3.025846
# Train Epoch: 2 [350/590]	loss: 2.288668
# Train Epoch: 2 [360/590]	loss: 2.335666
# Train Epoch: 2 [370/590]	loss: 2.300474
# Train Epoch: 2 [380/590]	loss: 2.525347
# Train Epoch: 2 [390/590]	loss: 1.908126
# Train Epoch: 2 [400/590]	loss: 2.144261
# Train Epoch: 2 [410/590]	loss: 2.135665
# Train Epoch: 2 [420/590]	loss: 2.049673
# Train Epoch: 2 [430/590]	loss: 1.951578
# Train Epoch: 2 [440/590]	loss: 2.575648
# Train Epoch: 2 [450/590]	loss: 1.626900
# Train Epoch: 2 [460/590]	loss: 2.613214
# Train Epoch: 2 [470/590]	loss: 2.318715
# Train Epoch: 2 [480/590]	loss: 2.348021
# Train Epoch: 2 [490/590]	loss: 2.406203
# Train Epoch: 2 [500/590]	loss: 2.797911
# Train Epoch: 2 [510/590]	loss: 2.752372
# Train Epoch: 2 [520/590]	loss: 2.278979
# Train Epoch: 2 [530/590]	loss: 2.084927
# Train Epoch: 2 [540/590]	loss: 1.997788
# Train Epoch: 2 [550/590]	loss: 2.677540
# Train Epoch: 2 [560/590]	loss: 2.114733
# Train Epoch: 2 [570/590]	loss: 2.178531
# Train Epoch: 2 [580/590]	loss: 2.056665
# [2]Validation Loss: 0.9232,Accuracy: 83.1081%
# Train Epoch: 3 [0/590]	loss: 1.821401
# Train Epoch: 3 [10/590]	loss: 1.695446
# Train Epoch: 3 [20/590]	loss: 2.176140
# Train Epoch: 3 [30/590]	loss: 2.384064
# Train Epoch: 3 [40/590]	loss: 1.850627
# Train Epoch: 3 [50/590]	loss: 2.814680
# Train Epoch: 3 [60/590]	loss: 1.964346
# Train Epoch: 3 [70/590]	loss: 1.995409
# Train Epoch: 3 [80/590]	loss: 1.803966
# Train Epoch: 3 [90/590]	loss: 2.334873
# Train Epoch: 3 [100/590]	loss: 1.663811
# Train Epoch: 3 [110/590]	loss: 1.713298
# Train Epoch: 3 [120/590]	loss: 1.842104
# Train Epoch: 3 [130/590]	loss: 2.508784
# Train Epoch: 3 [140/590]	loss: 1.686637
# Train Epoch: 3 [150/590]	loss: 1.385776
# Train Epoch: 3 [160/590]	loss: 1.773877
# Train Epoch: 3 [170/590]	loss: 1.885154
# Train Epoch: 3 [180/590]	loss: 1.567286
# Train Epoch: 3 [190/590]	loss: 1.681135
# Train Epoch: 3 [200/590]	loss: 2.735895
# Train Epoch: 3 [210/590]	loss: 1.824559
# Train Epoch: 3 [220/590]	loss: 1.902893
# Train Epoch: 3 [230/590]	loss: 2.218998
# Train Epoch: 3 [240/590]	loss: 1.878211
# Train Epoch: 3 [250/590]	loss: 2.353422
# Train Epoch: 3 [260/590]	loss: 1.788522
# Train Epoch: 3 [270/590]	loss: 2.729231
# Train Epoch: 3 [280/590]	loss: 1.916254
# Train Epoch: 3 [290/590]	loss: 1.794925
# Train Epoch: 3 [300/590]	loss: 1.698569
# Train Epoch: 3 [310/590]	loss: 1.937649
# Train Epoch: 3 [320/590]	loss: 1.579210
# Train Epoch: 3 [330/590]	loss: 1.903195
# Train Epoch: 3 [340/590]	loss: 2.456727
# Train Epoch: 3 [350/590]	loss: 1.747470
# Train Epoch: 3 [360/590]	loss: 1.770343
# Train Epoch: 3 [370/590]	loss: 1.734905
# Train Epoch: 3 [380/590]	loss: 1.808508
# Train Epoch: 3 [390/590]	loss: 1.285977
# Train Epoch: 3 [400/590]	loss: 1.724362
# Train Epoch: 3 [410/590]	loss: 1.721372
# Train Epoch: 3 [420/590]	loss: 2.198553
# Train Epoch: 3 [430/590]	loss: 2.003560
# Train Epoch: 3 [440/590]	loss: 1.894469
# Train Epoch: 3 [450/590]	loss: 1.738193
# Train Epoch: 3 [460/590]	loss: 1.859972
# Train Epoch: 3 [470/590]	loss: 2.033701
# Train Epoch: 3 [480/590]	loss: 1.816413
# Train Epoch: 3 [490/590]	loss: 1.807362
# Train Epoch: 3 [500/590]	loss: 1.440192
# Train Epoch: 3 [510/590]	loss: 1.497826
# Train Epoch: 3 [520/590]	loss: 1.214297
# Train Epoch: 3 [530/590]	loss: 1.333112
# Train Epoch: 3 [540/590]	loss: 1.480251
# Train Epoch: 3 [550/590]	loss: 1.756718
# Train Epoch: 3 [560/590]	loss: 1.921925
# Train Epoch: 3 [570/590]	loss: 1.815412
# Train Epoch: 3 [580/590]	loss: 1.702471
# [3]Validation Loss: 0.5088,Accuracy: 87.8378%
# Train Epoch: 4 [0/590]	loss: 1.326880
# Train Epoch: 4 [10/590]	loss: 1.517370
# Train Epoch: 4 [20/590]	loss: 1.613887
# Train Epoch: 4 [30/590]	loss: 1.520038
# Train Epoch: 4 [40/590]	loss: 1.646589
# Train Epoch: 4 [50/590]	loss: 1.545928
# Train Epoch: 4 [60/590]	loss: 1.372818
# Train Epoch: 4 [70/590]	loss: 1.679756
# Train Epoch: 4 [80/590]	loss: 1.371344
# Train Epoch: 4 [90/590]	loss: 1.436180
# Train Epoch: 4 [100/590]	loss: 1.934664
# Train Epoch: 4 [110/590]	loss: 1.438395
# Train Epoch: 4 [120/590]	loss: 1.516660
# Train Epoch: 4 [130/590]	loss: 1.368962
# Train Epoch: 4 [140/590]	loss: 1.501359
# Train Epoch: 4 [150/590]	loss: 1.228895
# Train Epoch: 4 [160/590]	loss: 1.522555
# Train Epoch: 4 [170/590]	loss: 1.557185
# Train Epoch: 4 [180/590]	loss: 1.809809
# Train Epoch: 4 [190/590]	loss: 1.478879
# Train Epoch: 4 [200/590]	loss: 1.568288
# Train Epoch: 4 [210/590]	loss: 1.530675
# Train Epoch: 4 [220/590]	loss: 1.270374
# Train Epoch: 4 [230/590]	loss: 1.432572
# Train Epoch: 4 [240/590]	loss: 1.663692
# Train Epoch: 4 [250/590]	loss: 1.337519
# Train Epoch: 4 [260/590]	loss: 1.207841
# Train Epoch: 4 [270/590]	loss: 1.432403
# Train Epoch: 4 [280/590]	loss: 1.829817
# Train Epoch: 4 [290/590]	loss: 1.498244
# Train Epoch: 4 [300/590]	loss: 1.595961
# Train Epoch: 4 [310/590]	loss: 1.379480
# Train Epoch: 4 [320/590]	loss: 1.685849
# Train Epoch: 4 [330/590]	loss: 1.986312
# Train Epoch: 4 [340/590]	loss: 1.506090
# Train Epoch: 4 [350/590]	loss: 1.491106
# Train Epoch: 4 [360/590]	loss: 1.363291
# Train Epoch: 4 [370/590]	loss: 1.915716
# Train Epoch: 4 [380/590]	loss: 1.379199
# Train Epoch: 4 [390/590]	loss: 1.349176
# Train Epoch: 4 [400/590]	loss: 1.602694
# Train Epoch: 4 [410/590]	loss: 1.354959
# Train Epoch: 4 [420/590]	loss: 1.592521
# Train Epoch: 4 [430/590]	loss: 1.454194
# Train Epoch: 4 [440/590]	loss: 1.446333
# Train Epoch: 4 [450/590]	loss: 1.421504
# Train Epoch: 4 [460/590]	loss: 1.577986
# Train Epoch: 4 [470/590]	loss: 1.498976
# Train Epoch: 4 [480/590]	loss: 1.412630
# Train Epoch: 4 [490/590]	loss: 1.493371
# Train Epoch: 4 [500/590]	loss: 1.359794
# Train Epoch: 4 [510/590]	loss: 1.625264
# Train Epoch: 4 [520/590]	loss: 1.684182
# Train Epoch: 4 [530/590]	loss: 1.577260
# Train Epoch: 4 [540/590]	loss: 1.695341
# Train Epoch: 4 [550/590]	loss: 1.806063
# Train Epoch: 4 [560/590]	loss: 1.138432
# Train Epoch: 4 [570/590]	loss: 1.209549
# Train Epoch: 4 [580/590]	loss: 1.621993
# [4]Validation Loss: 0.4812,Accuracy: 87.1622%
# Train Epoch: 5 [0/590]	loss: 1.513025
# Train Epoch: 5 [10/590]	loss: 1.416915
# Train Epoch: 5 [20/590]	loss: 1.119834
# Train Epoch: 5 [30/590]	loss: 1.554564
# Train Epoch: 5 [40/590]	loss: 1.433395
# Train Epoch: 5 [50/590]	loss: 1.509794
# Train Epoch: 5 [60/590]	loss: 1.313406
# Train Epoch: 5 [70/590]	loss: 1.278951
# Train Epoch: 5 [80/590]	loss: 1.467322
# Train Epoch: 5 [90/590]	loss: 1.494009
# Train Epoch: 5 [100/590]	loss: 1.534922
# Train Epoch: 5 [110/590]	loss: 1.937864
# Train Epoch: 5 [120/590]	loss: 1.382801
# Train Epoch: 5 [130/590]	loss: 1.534476
# Train Epoch: 5 [140/590]	loss: 1.282517
# Train Epoch: 5 [150/590]	loss: 1.400700
# Train Epoch: 5 [160/590]	loss: 1.550469
# Train Epoch: 5 [170/590]	loss: 1.815753
# Train Epoch: 5 [180/590]	loss: 1.138679
# Train Epoch: 5 [190/590]	loss: 1.255164
# Train Epoch: 5 [200/590]	loss: 1.290355
# Train Epoch: 5 [210/590]	loss: 1.258117
# Train Epoch: 5 [220/590]	loss: 1.285625
# Train Epoch: 5 [230/590]	loss: 1.494052
# Train Epoch: 5 [240/590]	loss: 1.426424
# Train Epoch: 5 [250/590]	loss: 1.255782
# Train Epoch: 5 [260/590]	loss: 1.138287
# Train Epoch: 5 [270/590]	loss: 1.259583
# Train Epoch: 5 [280/590]	loss: 1.218733
# Train Epoch: 5 [290/590]	loss: 1.378039
# Train Epoch: 5 [300/590]	loss: 1.422065
# Train Epoch: 5 [310/590]	loss: 1.584011
# Train Epoch: 5 [320/590]	loss: 1.401280
# Train Epoch: 5 [330/590]	loss: 1.119380
# Train Epoch: 5 [340/590]	loss: 1.452265
# Train Epoch: 5 [350/590]	loss: 1.293377
# Train Epoch: 5 [360/590]	loss: 1.552446
# Train Epoch: 5 [370/590]	loss: 1.234802
# Train Epoch: 5 [380/590]	loss: 1.305177
# Train Epoch: 5 [390/590]	loss: 1.255625
# Train Epoch: 5 [400/590]	loss: 1.467022
# Train Epoch: 5 [410/590]	loss: 1.819611
# Train Epoch: 5 [420/590]	loss: 1.290833
# Train Epoch: 5 [430/590]	loss: 1.379675
# Train Epoch: 5 [440/590]	loss: 1.013369
# Train Epoch: 5 [450/590]	loss: 1.400217
# Train Epoch: 5 [460/590]	loss: 1.378659
# Train Epoch: 5 [470/590]	loss: 1.304727
# Train Epoch: 5 [480/590]	loss: 1.102254
# Train Epoch: 5 [490/590]	loss: 1.111928
# Train Epoch: 5 [500/590]	loss: 1.334438
# Train Epoch: 5 [510/590]	loss: 1.579076
# Train Epoch: 5 [520/590]	loss: 1.146971
# Train Epoch: 5 [530/590]	loss: 1.250082
# Train Epoch: 5 [540/590]	loss: 1.510875
# Train Epoch: 5 [550/590]	loss: 1.093319
# Train Epoch: 5 [560/590]	loss: 1.419308
# Train Epoch: 5 [570/590]	loss: 1.229103
# Train Epoch: 5 [580/590]	loss: 1.301397
# [5]Validation Loss: 0.3382,Accuracy: 92.5676%
# Train Epoch: 6 [0/590]	loss: 1.440118
# Train Epoch: 6 [10/590]	loss: 1.561626
# Train Epoch: 6 [20/590]	loss: 1.096066
# Train Epoch: 6 [30/590]	loss: 1.134714
# Train Epoch: 6 [40/590]	loss: 1.617124
# Train Epoch: 6 [50/590]	loss: 1.145907
# Train Epoch: 6 [60/590]	loss: 1.042482
# Train Epoch: 6 [70/590]	loss: 1.365182
# Train Epoch: 6 [80/590]	loss: 1.113649
# Train Epoch: 6 [90/590]	loss: 1.165044
# Train Epoch: 6 [100/590]	loss: 1.313459
# Train Epoch: 6 [110/590]	loss: 1.245975
# Train Epoch: 6 [120/590]	loss: 1.287884
# Train Epoch: 6 [130/590]	loss: 1.068296
# Train Epoch: 6 [140/590]	loss: 1.544859
# Train Epoch: 6 [150/590]	loss: 1.178405
# Train Epoch: 6 [160/590]	loss: 1.070738
# Train Epoch: 6 [170/590]	loss: 1.384982
# Train Epoch: 6 [180/590]	loss: 1.116895
# Train Epoch: 6 [190/590]	loss: 1.151947
# Train Epoch: 6 [200/590]	loss: 1.220428
# Train Epoch: 6 [210/590]	loss: 1.073568
# Train Epoch: 6 [220/590]	loss: 1.330068
# Train Epoch: 6 [230/590]	loss: 1.605292
# Train Epoch: 6 [240/590]	loss: 1.065855
# Train Epoch: 6 [250/590]	loss: 1.181638
# Train Epoch: 6 [260/590]	loss: 1.254657
# Train Epoch: 6 [270/590]	loss: 1.152487
# Train Epoch: 6 [280/590]	loss: 1.161968
# Train Epoch: 6 [290/590]	loss: 1.741609
# Train Epoch: 6 [300/590]	loss: 1.173775
# Train Epoch: 6 [310/590]	loss: 1.427160
# Train Epoch: 6 [320/590]	loss: 1.220586
# Train Epoch: 6 [330/590]	loss: 1.070864
# Train Epoch: 6 [340/590]	loss: 1.045443
# Train Epoch: 6 [350/590]	loss: 1.228524
# Train Epoch: 6 [360/590]	loss: 1.349637
# Train Epoch: 6 [370/590]	loss: 1.136233
# Train Epoch: 6 [380/590]	loss: 1.512043
# Train Epoch: 6 [390/590]	loss: 1.080203
# Train Epoch: 6 [400/590]	loss: 1.639893
# Train Epoch: 6 [410/590]	loss: 1.105666
# Train Epoch: 6 [420/590]	loss: 1.688793
# Train Epoch: 6 [430/590]	loss: 1.755623
# Train Epoch: 6 [440/590]	loss: 1.442254
# Train Epoch: 6 [450/590]	loss: 1.059298
# Train Epoch: 6 [460/590]	loss: 1.811158
# Train Epoch: 6 [470/590]	loss: 1.211405
# Train Epoch: 6 [480/590]	loss: 2.577427
# Train Epoch: 6 [490/590]	loss: 1.195101
# Train Epoch: 6 [500/590]	loss: 1.310638
# Train Epoch: 6 [510/590]	loss: 1.029529
# Train Epoch: 6 [520/590]	loss: 1.538579
# Train Epoch: 6 [530/590]	loss: 1.202651
# Train Epoch: 6 [540/590]	loss: 1.309793
# Train Epoch: 6 [550/590]	loss: 1.538708
# Train Epoch: 6 [560/590]	loss: 1.102785
# Train Epoch: 6 [570/590]	loss: 1.220963
# Train Epoch: 6 [580/590]	loss: 1.162285
# [6]Validation Loss: 0.3836,Accuracy: 90.5405%
# Train Epoch: 7 [0/590]	loss: 1.198006
# Train Epoch: 7 [10/590]	loss: 1.194374
# Train Epoch: 7 [20/590]	loss: 1.476674
# Train Epoch: 7 [30/590]	loss: 1.306147
# Train Epoch: 7 [40/590]	loss: 1.035188
# Train Epoch: 7 [50/590]	loss: 1.159956
# Train Epoch: 7 [60/590]	loss: 1.198374
# Train Epoch: 7 [70/590]	loss: 1.037107
# Train Epoch: 7 [80/590]	loss: 1.034630
# Train Epoch: 7 [90/590]	loss: 1.198760
# Train Epoch: 7 [100/590]	loss: 1.097791
# Train Epoch: 7 [110/590]	loss: 1.056516
# Train Epoch: 7 [120/590]	loss: 1.227448
# Train Epoch: 7 [130/590]	loss: 1.040278
# Train Epoch: 7 [140/590]	loss: 1.121235
# Train Epoch: 7 [150/590]	loss: 1.109873
# Train Epoch: 7 [160/590]	loss: 1.484355
# Train Epoch: 7 [170/590]	loss: 1.091534
# Train Epoch: 7 [180/590]	loss: 1.147252
# Train Epoch: 7 [190/590]	loss: 1.085026
# Train Epoch: 7 [200/590]	loss: 1.276714
# Train Epoch: 7 [210/590]	loss: 1.139417
# Train Epoch: 7 [220/590]	loss: 1.114660
# Train Epoch: 7 [230/590]	loss: 1.050218
# Train Epoch: 7 [240/590]	loss: 1.026321
# Train Epoch: 7 [250/590]	loss: 1.074058
# Train Epoch: 7 [260/590]	loss: 1.766879
# Train Epoch: 7 [270/590]	loss: 1.334315
# Train Epoch: 7 [280/590]	loss: 1.231111
# Train Epoch: 7 [290/590]	loss: 1.445418
# Train Epoch: 7 [300/590]	loss: 1.084435
# Train Epoch: 7 [310/590]	loss: 1.140782
# Train Epoch: 7 [320/590]	loss: 1.397875
# Train Epoch: 7 [330/590]	loss: 1.214706
# Train Epoch: 7 [340/590]	loss: 1.223372
# Train Epoch: 7 [350/590]	loss: 1.232531
# Train Epoch: 7 [360/590]	loss: 1.062424
# Train Epoch: 7 [370/590]	loss: 1.245685
# Train Epoch: 7 [380/590]	loss: 1.116801
# Train Epoch: 7 [390/590]	loss: 1.288594
# Train Epoch: 7 [400/590]	loss: 1.628978
# Train Epoch: 7 [410/590]	loss: 1.018112
# Train Epoch: 7 [420/590]	loss: 1.122725
# Train Epoch: 7 [430/590]	loss: 1.354878
# Train Epoch: 7 [440/590]	loss: 1.068015
# Train Epoch: 7 [450/590]	loss: 1.329851
# Train Epoch: 7 [460/590]	loss: 1.397388
# Train Epoch: 7 [470/590]	loss: 1.090912
# Train Epoch: 7 [480/590]	loss: 1.052020
# Train Epoch: 7 [490/590]	loss: 1.300379
# Train Epoch: 7 [500/590]	loss: 1.084466
# Train Epoch: 7 [510/590]	loss: 1.469815
# Train Epoch: 7 [520/590]	loss: 1.067523
# Train Epoch: 7 [530/590]	loss: 1.183928
# Train Epoch: 7 [540/590]	loss: 1.029359
# Train Epoch: 7 [550/590]	loss: 1.346020
# Train Epoch: 7 [560/590]	loss: 1.424263
# Train Epoch: 7 [570/590]	loss: 1.191188
# Train Epoch: 7 [580/590]	loss: 1.069089
# [7]Validation Loss: 0.3223,Accuracy: 92.2297%
# Train Epoch: 8 [0/590]	loss: 1.230281
# Train Epoch: 8 [10/590]	loss: 1.082122
# Train Epoch: 8 [20/590]	loss: 1.104234
# Train Epoch: 8 [30/590]	loss: 1.021783
# Train Epoch: 8 [40/590]	loss: 1.106557
# Train Epoch: 8 [50/590]	loss: 1.361813
# Train Epoch: 8 [60/590]	loss: 1.047064
# Train Epoch: 8 [70/590]	loss: 1.049088
# Train Epoch: 8 [80/590]	loss: 1.043442
# Train Epoch: 8 [90/590]	loss: 1.005257
# Train Epoch: 8 [100/590]	loss: 1.323689
# Train Epoch: 8 [110/590]	loss: 1.172957
# Train Epoch: 8 [120/590]	loss: 1.279383
# Train Epoch: 8 [130/590]	loss: 1.153194
# Train Epoch: 8 [140/590]	loss: 1.227251
# Train Epoch: 8 [150/590]	loss: 1.083688
# Train Epoch: 8 [160/590]	loss: 1.176212
# Train Epoch: 8 [170/590]	loss: 1.228682
# Train Epoch: 8 [180/590]	loss: 1.353745
# Train Epoch: 8 [190/590]	loss: 1.525682
# Train Epoch: 8 [200/590]	loss: 1.270011
# Train Epoch: 8 [210/590]	loss: 1.032006
# Train Epoch: 8 [220/590]	loss: 1.315998
# Train Epoch: 8 [230/590]	loss: 1.120180
# Train Epoch: 8 [240/590]	loss: 1.151968
# Train Epoch: 8 [250/590]	loss: 1.216645
# Train Epoch: 8 [260/590]	loss: 1.038784
# Train Epoch: 8 [270/590]	loss: 1.422741
# Train Epoch: 8 [280/590]	loss: 1.046775
# Train Epoch: 8 [290/590]	loss: 1.064231
# Train Epoch: 8 [300/590]	loss: 1.249929
# Train Epoch: 8 [310/590]	loss: 1.429094
# Train Epoch: 8 [320/590]	loss: 1.812961
# Train Epoch: 8 [330/590]	loss: 1.241827
# Train Epoch: 8 [340/590]	loss: 1.087780
# Train Epoch: 8 [350/590]	loss: 1.427636
# Train Epoch: 8 [360/590]	loss: 1.031717
# Train Epoch: 8 [370/590]	loss: 1.032623
# Train Epoch: 8 [380/590]	loss: 1.011027
# Train Epoch: 8 [390/590]	loss: 1.034379
# Train Epoch: 8 [400/590]	loss: 1.159423
# Train Epoch: 8 [410/590]	loss: 1.073446
# Train Epoch: 8 [420/590]	loss: 1.234885
# Train Epoch: 8 [430/590]	loss: 1.059388
# Train Epoch: 8 [440/590]	loss: 1.049944
# Train Epoch: 8 [450/590]	loss: 1.202659
# Train Epoch: 8 [460/590]	loss: 1.015899
# Train Epoch: 8 [470/590]	loss: 0.995887
# Train Epoch: 8 [480/590]	loss: 1.003330
# Train Epoch: 8 [490/590]	loss: 1.281151
# Train Epoch: 8 [500/590]	loss: 1.017455
# Train Epoch: 8 [510/590]	loss: 1.145854
# Train Epoch: 8 [520/590]	loss: 1.313335
# Train Epoch: 8 [530/590]	loss: 1.427253
# Train Epoch: 8 [540/590]	loss: 1.276745
# Train Epoch: 8 [550/590]	loss: 1.025113
# Train Epoch: 8 [560/590]	loss: 1.320381
# Train Epoch: 8 [570/590]	loss: 1.225555
# Train Epoch: 8 [580/590]	loss: 1.079046
# [8]Validation Loss: 0.3085,Accuracy: 92.5676%
# Train Epoch: 9 [0/590]	loss: 1.284670
# Train Epoch: 9 [10/590]	loss: 1.073263
# Train Epoch: 9 [20/590]	loss: 1.042158
# Train Epoch: 9 [30/590]	loss: 1.045744
# Train Epoch: 9 [40/590]	loss: 1.058336
# Train Epoch: 9 [50/590]	loss: 1.292917
# Train Epoch: 9 [60/590]	loss: 1.088071
# Train Epoch: 9 [70/590]	loss: 1.198673
# Train Epoch: 9 [80/590]	loss: 1.114094
# Train Epoch: 9 [90/590]	loss: 1.181472
# Train Epoch: 9 [100/590]	loss: 1.201524
# Train Epoch: 9 [110/590]	loss: 1.005971
# Train Epoch: 9 [120/590]	loss: 1.074215
# Train Epoch: 9 [130/590]	loss: 1.031900
# Train Epoch: 9 [140/590]	loss: 1.148428
# Train Epoch: 9 [150/590]	loss: 1.037728
# Train Epoch: 9 [160/590]	loss: 1.024400
# Train Epoch: 9 [170/590]	loss: 1.018741
# Train Epoch: 9 [180/590]	loss: 1.255169
# Train Epoch: 9 [190/590]	loss: 1.002939
# Train Epoch: 9 [200/590]	loss: 1.202823
# Train Epoch: 9 [210/590]	loss: 1.015987
# Train Epoch: 9 [220/590]	loss: 1.271750
# Train Epoch: 9 [230/590]	loss: 1.104392
# Train Epoch: 9 [240/590]	loss: 1.031233
# Train Epoch: 9 [250/590]	loss: 1.156743
# Train Epoch: 9 [260/590]	loss: 1.015356
# Train Epoch: 9 [270/590]	loss: 1.164563
# Train Epoch: 9 [280/590]	loss: 1.075487
# Train Epoch: 9 [290/590]	loss: 1.453822
# Train Epoch: 9 [300/590]	loss: 1.015797
# Train Epoch: 9 [310/590]	loss: 1.105050
# Train Epoch: 9 [320/590]	loss: 1.051123
# Train Epoch: 9 [330/590]	loss: 1.164759
# Train Epoch: 9 [340/590]	loss: 1.352385
# Train Epoch: 9 [350/590]	loss: 1.034995
# Train Epoch: 9 [360/590]	loss: 1.173106
# Train Epoch: 9 [370/590]	loss: 1.323317
# Train Epoch: 9 [380/590]	loss: 1.029119
# Train Epoch: 9 [390/590]	loss: 1.155496
# Train Epoch: 9 [400/590]	loss: 1.069428
# Train Epoch: 9 [410/590]	loss: 1.177369
# Train Epoch: 9 [420/590]	loss: 1.168337
# Train Epoch: 9 [430/590]	loss: 1.113200
# Train Epoch: 9 [440/590]	loss: 1.289660
# Train Epoch: 9 [450/590]	loss: 1.124684
# Train Epoch: 9 [460/590]	loss: 1.118603
# Train Epoch: 9 [470/590]	loss: 1.281504
# Train Epoch: 9 [480/590]	loss: 1.236686
# Train Epoch: 9 [490/590]	loss: 1.264888
# Train Epoch: 9 [500/590]	loss: 1.055226
# Train Epoch: 9 [510/590]	loss: 1.827239
# Train Epoch: 9 [520/590]	loss: 1.361251
# Train Epoch: 9 [530/590]	loss: 1.039551
# Train Epoch: 9 [540/590]	loss: 1.037297
# Train Epoch: 9 [550/590]	loss: 1.095112
# Train Epoch: 9 [560/590]	loss: 1.064868
# Train Epoch: 9 [570/590]	loss: 1.269311
# Train Epoch: 9 [580/590]	loss: 1.164253
# [9]Validation Loss: 0.3686,Accuracy: 90.2027%
# Train Epoch: 10 [0/590]	loss: 1.145881
# Train Epoch: 10 [10/590]	loss: 1.089714
# Train Epoch: 10 [20/590]	loss: 1.044080
# Train Epoch: 10 [30/590]	loss: 1.088702
# Train Epoch: 10 [40/590]	loss: 1.127888
# Train Epoch: 10 [50/590]	loss: 1.136826
# Train Epoch: 10 [60/590]	loss: 1.220285
# Train Epoch: 10 [70/590]	loss: 1.243006
# Train Epoch: 10 [80/590]	loss: 1.047776
# Train Epoch: 10 [90/590]	loss: 0.984830
# Train Epoch: 10 [100/590]	loss: 1.057016
# Train Epoch: 10 [110/590]	loss: 1.112379
# Train Epoch: 10 [120/590]	loss: 1.059403
# Train Epoch: 10 [130/590]	loss: 1.014883
# Train Epoch: 10 [140/590]	loss: 1.005139
# Train Epoch: 10 [150/590]	loss: 1.011090
# Train Epoch: 10 [160/590]	loss: 1.052072
# Train Epoch: 10 [170/590]	loss: 1.017310
# Train Epoch: 10 [180/590]	loss: 1.027233
# Train Epoch: 10 [190/590]	loss: 1.040550
# Train Epoch: 10 [200/590]	loss: 1.028258
# Train Epoch: 10 [210/590]	loss: 1.013546
# Train Epoch: 10 [220/590]	loss: 1.038289
# Train Epoch: 10 [230/590]	loss: 1.338593
# Train Epoch: 10 [240/590]	loss: 1.010011
# Train Epoch: 10 [250/590]	loss: 1.078560
# Train Epoch: 10 [260/590]	loss: 1.050281
# Train Epoch: 10 [270/590]	loss: 1.170934
# Train Epoch: 10 [280/590]	loss: 1.599876
# Train Epoch: 10 [290/590]	loss: 1.276564
# Train Epoch: 10 [300/590]	loss: 1.151938
# Train Epoch: 10 [310/590]	loss: 1.384804
# Train Epoch: 10 [320/590]	loss: 1.227588
# Train Epoch: 10 [330/590]	loss: 0.999800
# Train Epoch: 10 [340/590]	loss: 1.163664
# Train Epoch: 10 [350/590]	loss: 1.126977
# Train Epoch: 10 [360/590]	loss: 1.147345
# Train Epoch: 10 [370/590]	loss: 1.050161
# Train Epoch: 10 [380/590]	loss: 1.052833
# Train Epoch: 10 [390/590]	loss: 1.025237
# Train Epoch: 10 [400/590]	loss: 1.222014
# Train Epoch: 10 [410/590]	loss: 1.100843
# Train Epoch: 10 [420/590]	loss: 1.007089
# Train Epoch: 10 [430/590]	loss: 1.311720
# Train Epoch: 10 [440/590]	loss: 1.055633
# Train Epoch: 10 [450/590]	loss: 1.001950
# Train Epoch: 10 [460/590]	loss: 1.054316
# Train Epoch: 10 [470/590]	loss: 1.037495
# Train Epoch: 10 [480/590]	loss: 1.071679
# Train Epoch: 10 [490/590]	loss: 1.035697
# Train Epoch: 10 [500/590]	loss: 0.998215
# Train Epoch: 10 [510/590]	loss: 1.047687
# Train Epoch: 10 [520/590]	loss: 1.116115
# Train Epoch: 10 [530/590]	loss: 1.046062
# Train Epoch: 10 [540/590]	loss: 1.063397
# Train Epoch: 10 [550/590]	loss: 1.054584
# Train Epoch: 10 [560/590]	loss: 1.016986
# Train Epoch: 10 [570/590]	loss: 1.414247
# Train Epoch: 10 [580/590]	loss: 1.015158
# [10]Validation Loss: 0.2931,Accuracy: 93.5811%
# Train Epoch: 11 [0/590]	loss: 1.080246
# Train Epoch: 11 [10/590]	loss: 1.053797
# Train Epoch: 11 [20/590]	loss: 1.015857
# Train Epoch: 11 [30/590]	loss: 1.005916
# Train Epoch: 11 [40/590]	loss: 1.012777
# Train Epoch: 11 [50/590]	loss: 1.018108
# Train Epoch: 11 [60/590]	loss: 1.062178
# Train Epoch: 11 [70/590]	loss: 1.039470
# Train Epoch: 11 [80/590]	loss: 1.030335
# Train Epoch: 11 [90/590]	loss: 1.024423
# Train Epoch: 11 [100/590]	loss: 1.336133
# Train Epoch: 11 [110/590]	loss: 1.274169
# Train Epoch: 11 [120/590]	loss: 1.196700
# Train Epoch: 11 [130/590]	loss: 1.010187
# Train Epoch: 11 [140/590]	loss: 1.036275
# Train Epoch: 11 [150/590]	loss: 1.007267
# Train Epoch: 11 [160/590]	loss: 1.087915
# Train Epoch: 11 [170/590]	loss: 0.997102
# Train Epoch: 11 [180/590]	loss: 1.040739
# Train Epoch: 11 [190/590]	loss: 1.220899
# Train Epoch: 11 [200/590]	loss: 1.084192
# Train Epoch: 11 [210/590]	loss: 1.328440
# Train Epoch: 11 [220/590]	loss: 1.007934
# Train Epoch: 11 [230/590]	loss: 1.498719
# Train Epoch: 11 [240/590]	loss: 1.069421
# Train Epoch: 11 [250/590]	loss: 1.189463
# Train Epoch: 11 [260/590]	loss: 1.037898
# Train Epoch: 11 [270/590]	loss: 1.046099
# Train Epoch: 11 [280/590]	loss: 1.017764
# Train Epoch: 11 [290/590]	loss: 1.173208
# Train Epoch: 11 [300/590]	loss: 1.038555
# Train Epoch: 11 [310/590]	loss: 1.284256
# Train Epoch: 11 [320/590]	loss: 1.054398
# Train Epoch: 11 [330/590]	loss: 1.148046
# Train Epoch: 11 [340/590]	loss: 1.097836
# Train Epoch: 11 [350/590]	loss: 1.123135
# Train Epoch: 11 [360/590]	loss: 1.042886
# Train Epoch: 11 [370/590]	loss: 1.001180
# Train Epoch: 11 [380/590]	loss: 1.025110
# Train Epoch: 11 [390/590]	loss: 1.092187
# Train Epoch: 11 [400/590]	loss: 1.417928
# Train Epoch: 11 [410/590]	loss: 1.136407
# Train Epoch: 11 [420/590]	loss: 1.009435
# Train Epoch: 11 [430/590]	loss: 1.081152
# Train Epoch: 11 [440/590]	loss: 1.088157
# Train Epoch: 11 [450/590]	loss: 1.032784
# Train Epoch: 11 [460/590]	loss: 0.994438
# Train Epoch: 11 [470/590]	loss: 0.999700
# Train Epoch: 11 [480/590]	loss: 1.317407
# Train Epoch: 11 [490/590]	loss: 1.277864
# Train Epoch: 11 [500/590]	loss: 1.103083
# Train Epoch: 11 [510/590]	loss: 0.987463
# Train Epoch: 11 [520/590]	loss: 1.333147
# Train Epoch: 11 [530/590]	loss: 1.116433
# Train Epoch: 11 [540/590]	loss: 1.005335
# Train Epoch: 11 [550/590]	loss: 1.288618
# Train Epoch: 11 [560/590]	loss: 1.012344
# Train Epoch: 11 [570/590]	loss: 1.016705
# Train Epoch: 11 [580/590]	loss: 0.986631
# [11]Validation Loss: 0.3172,Accuracy: 93.2432%
# Train Epoch: 12 [0/590]	loss: 0.990988
# Train Epoch: 12 [10/590]	loss: 1.276914
# Train Epoch: 12 [20/590]	loss: 1.059985
# Train Epoch: 12 [30/590]	loss: 1.142968
# Train Epoch: 12 [40/590]	loss: 1.096420
# Train Epoch: 12 [50/590]	loss: 1.027308
# Train Epoch: 12 [60/590]	loss: 1.404413
# Train Epoch: 12 [70/590]	loss: 1.049607
# Train Epoch: 12 [80/590]	loss: 1.090915
# Train Epoch: 12 [90/590]	loss: 1.052730
# Train Epoch: 12 [100/590]	loss: 1.038739
# Train Epoch: 12 [110/590]	loss: 1.166497
# Train Epoch: 12 [120/590]	loss: 1.032892
# Train Epoch: 12 [130/590]	loss: 1.127199
# Train Epoch: 12 [140/590]	loss: 1.027605
# Train Epoch: 12 [150/590]	loss: 1.027526
# Train Epoch: 12 [160/590]	loss: 0.993435
# Train Epoch: 12 [170/590]	loss: 0.988948
# Train Epoch: 12 [180/590]	loss: 1.188265
# Train Epoch: 12 [190/590]	loss: 1.085235
# Train Epoch: 12 [200/590]	loss: 1.047590
# Train Epoch: 12 [210/590]	loss: 0.998536
# Train Epoch: 12 [220/590]	loss: 1.058659
# Train Epoch: 12 [230/590]	loss: 0.969239
# Train Epoch: 12 [240/590]	loss: 1.583887
# Train Epoch: 12 [250/590]	loss: 1.139018
# Train Epoch: 12 [260/590]	loss: 1.124115
# Train Epoch: 12 [270/590]	loss: 1.054310
# Train Epoch: 12 [280/590]	loss: 1.275471
# Train Epoch: 12 [290/590]	loss: 0.991656
# Train Epoch: 12 [300/590]	loss: 1.341234
# Train Epoch: 12 [310/590]	loss: 1.038366
# Train Epoch: 12 [320/590]	loss: 1.106303
# Train Epoch: 12 [330/590]	loss: 1.216474
# Train Epoch: 12 [340/590]	loss: 1.034579
# Train Epoch: 12 [350/590]	loss: 1.019563
# Train Epoch: 12 [360/590]	loss: 1.046242
# Train Epoch: 12 [370/590]	loss: 0.975762
# Train Epoch: 12 [380/590]	loss: 1.122504
# Train Epoch: 12 [390/590]	loss: 1.043983
# Train Epoch: 12 [400/590]	loss: 0.993764
# Train Epoch: 12 [410/590]	loss: 1.026490
# Train Epoch: 12 [420/590]	loss: 1.250126
# Train Epoch: 12 [430/590]	loss: 1.037316
# Train Epoch: 12 [440/590]	loss: 1.010914
# Train Epoch: 12 [450/590]	loss: 1.083277
# Train Epoch: 12 [460/590]	loss: 1.292154
# Train Epoch: 12 [470/590]	loss: 1.054508
# Train Epoch: 12 [480/590]	loss: 1.029888
# Train Epoch: 12 [490/590]	loss: 1.235975
# Train Epoch: 12 [500/590]	loss: 1.013331
# Train Epoch: 12 [510/590]	loss: 1.137401
# Train Epoch: 12 [520/590]	loss: 1.011510
# Train Epoch: 12 [530/590]	loss: 0.995512
# Train Epoch: 12 [540/590]	loss: 1.312684
# Train Epoch: 12 [550/590]	loss: 1.022853
# Train Epoch: 12 [560/590]	loss: 1.006431
# Train Epoch: 12 [570/590]	loss: 0.998333
# Train Epoch: 12 [580/590]	loss: 1.006261
# [12]Validation Loss: 0.3536,Accuracy: 90.5405%
# Train Epoch: 13 [0/590]	loss: 1.092490
# Train Epoch: 13 [10/590]	loss: 1.122925
# Train Epoch: 13 [20/590]	loss: 1.010062
# Train Epoch: 13 [30/590]	loss: 1.180292
# Train Epoch: 13 [40/590]	loss: 0.999973
# Train Epoch: 13 [50/590]	loss: 1.182871
# Train Epoch: 13 [60/590]	loss: 1.015096
# Train Epoch: 13 [70/590]	loss: 1.007630
# Train Epoch: 13 [80/590]	loss: 1.024814
# Train Epoch: 13 [90/590]	loss: 1.041011
# Train Epoch: 13 [100/590]	loss: 1.122981
# Train Epoch: 13 [110/590]	loss: 1.002296
# Train Epoch: 13 [120/590]	loss: 1.021689
# Train Epoch: 13 [130/590]	loss: 0.997385
# Train Epoch: 13 [140/590]	loss: 0.983768
# Train Epoch: 13 [150/590]	loss: 0.984232
# Train Epoch: 13 [160/590]	loss: 1.049581
# Train Epoch: 13 [170/590]	loss: 0.987216
# Train Epoch: 13 [180/590]	loss: 0.992920
# Train Epoch: 13 [190/590]	loss: 1.145475
# Train Epoch: 13 [200/590]	loss: 1.022798
# Train Epoch: 13 [210/590]	loss: 1.058741
# Train Epoch: 13 [220/590]	loss: 0.967355
# Train Epoch: 13 [230/590]	loss: 1.033589
# Train Epoch: 13 [240/590]	loss: 1.067152
# Train Epoch: 13 [250/590]	loss: 1.028589
# Train Epoch: 13 [260/590]	loss: 0.987493
# Train Epoch: 13 [270/590]	loss: 1.153017
# Train Epoch: 13 [280/590]	loss: 1.033523
# Train Epoch: 13 [290/590]	loss: 1.016630
# Train Epoch: 13 [300/590]	loss: 0.996167
# Train Epoch: 13 [310/590]	loss: 0.984569
# Train Epoch: 13 [320/590]	loss: 0.996102
# Train Epoch: 13 [330/590]	loss: 1.101542
# Train Epoch: 13 [340/590]	loss: 0.977031
# Train Epoch: 13 [350/590]	loss: 1.001512
# Train Epoch: 13 [360/590]	loss: 1.144503
# Train Epoch: 13 [370/590]	loss: 1.041979
# Train Epoch: 13 [380/590]	loss: 1.004322
# Train Epoch: 13 [390/590]	loss: 0.980371
# Train Epoch: 13 [400/590]	loss: 0.974558
# Train Epoch: 13 [410/590]	loss: 1.018930
# Train Epoch: 13 [420/590]	loss: 1.366293
# Train Epoch: 13 [430/590]	loss: 0.994548
# Train Epoch: 13 [440/590]	loss: 1.007939
# Train Epoch: 13 [450/590]	loss: 0.983171
# Train Epoch: 13 [460/590]	loss: 1.093974
# Train Epoch: 13 [470/590]	loss: 1.267994
# Train Epoch: 13 [480/590]	loss: 1.302063
# Train Epoch: 13 [490/590]	loss: 1.072546
# Train Epoch: 13 [500/590]	loss: 1.019979
# Train Epoch: 13 [510/590]	loss: 1.115734
# Train Epoch: 13 [520/590]	loss: 1.098778
# Train Epoch: 13 [530/590]	loss: 1.009627
# Train Epoch: 13 [540/590]	loss: 1.003263
# Train Epoch: 13 [550/590]	loss: 0.996425
# Train Epoch: 13 [560/590]	loss: 1.114779
# Train Epoch: 13 [570/590]	loss: 1.027443
# Train Epoch: 13 [580/590]	loss: 1.085634
# [13]Validation Loss: 0.3109,Accuracy: 92.9054%
# Train Epoch: 14 [0/590]	loss: 0.994911
# Train Epoch: 14 [10/590]	loss: 1.020669
# Train Epoch: 14 [20/590]	loss: 1.318400
# Train Epoch: 14 [30/590]	loss: 1.035758
# Train Epoch: 14 [40/590]	loss: 1.017432
# Train Epoch: 14 [50/590]	loss: 1.026008
# Train Epoch: 14 [60/590]	loss: 0.977271
# Train Epoch: 14 [70/590]	loss: 1.089265
# Train Epoch: 14 [80/590]	loss: 0.996735
# Train Epoch: 14 [90/590]	loss: 1.141647
# Train Epoch: 14 [100/590]	loss: 0.981456
# Train Epoch: 14 [110/590]	loss: 0.984486
# Train Epoch: 14 [120/590]	loss: 0.985264
# Train Epoch: 14 [130/590]	loss: 1.111845
# Train Epoch: 14 [140/590]	loss: 0.987759
# Train Epoch: 14 [150/590]	loss: 0.995968
# Train Epoch: 14 [160/590]	loss: 1.037275
# Train Epoch: 14 [170/590]	loss: 1.052112
# Train Epoch: 14 [180/590]	loss: 0.979865
# Train Epoch: 14 [190/590]	loss: 1.020655
# Train Epoch: 14 [200/590]	loss: 1.199511
# Train Epoch: 14 [210/590]	loss: 1.015626
# Train Epoch: 14 [220/590]	loss: 1.021220
# Train Epoch: 14 [230/590]	loss: 1.051738
# Train Epoch: 14 [240/590]	loss: 1.118068
# Train Epoch: 14 [250/590]	loss: 1.003193
# Train Epoch: 14 [260/590]	loss: 1.141170
# Train Epoch: 14 [270/590]	loss: 1.020643
# Train Epoch: 14 [280/590]	loss: 0.987677
# Train Epoch: 14 [290/590]	loss: 1.124509
# Train Epoch: 14 [300/590]	loss: 0.999391
# Train Epoch: 14 [310/590]	loss: 0.998803
# Train Epoch: 14 [320/590]	loss: 0.995205
# Train Epoch: 14 [330/590]	loss: 1.008974
# Train Epoch: 14 [340/590]	loss: 1.058967
# Train Epoch: 14 [350/590]	loss: 0.972306
# Train Epoch: 14 [360/590]	loss: 1.013661
# Train Epoch: 14 [370/590]	loss: 0.983642
# Train Epoch: 14 [380/590]	loss: 0.992617
# Train Epoch: 14 [390/590]	loss: 1.063672
# Train Epoch: 14 [400/590]	loss: 1.059719
# Train Epoch: 14 [410/590]	loss: 1.030391
# Train Epoch: 14 [420/590]	loss: 0.988145
# Train Epoch: 14 [430/590]	loss: 1.041125
# Train Epoch: 14 [440/590]	loss: 1.076419
# Train Epoch: 14 [450/590]	loss: 1.022004
# Train Epoch: 14 [460/590]	loss: 0.999465
# Train Epoch: 14 [470/590]	loss: 1.061577
# Train Epoch: 14 [480/590]	loss: 0.986676
# Train Epoch: 14 [490/590]	loss: 1.031814
# Train Epoch: 14 [500/590]	loss: 0.978149
# Train Epoch: 14 [510/590]	loss: 0.980005
# Train Epoch: 14 [520/590]	loss: 1.152141
# Train Epoch: 14 [530/590]	loss: 0.982497
# Train Epoch: 14 [540/590]	loss: 1.029356
# Train Epoch: 14 [550/590]	loss: 1.002391
# Train Epoch: 14 [560/590]	loss: 1.031783
# Train Epoch: 14 [570/590]	loss: 0.992994
# Train Epoch: 14 [580/590]	loss: 0.980871
# [14]Validation Loss: 0.3225,Accuracy: 94.5946%
# Train Epoch: 15 [0/590]	loss: 0.982669
# Train Epoch: 15 [10/590]	loss: 1.097703
# Train Epoch: 15 [20/590]	loss: 0.979059
# Train Epoch: 15 [30/590]	loss: 0.983580
# Train Epoch: 15 [40/590]	loss: 0.985357
# Train Epoch: 15 [50/590]	loss: 1.098492
# Train Epoch: 15 [60/590]	loss: 0.984017
# Train Epoch: 15 [70/590]	loss: 1.105554
# Train Epoch: 15 [80/590]	loss: 1.012133
# Train Epoch: 15 [90/590]	loss: 0.993495
# Train Epoch: 15 [100/590]	loss: 0.978124
# Train Epoch: 15 [110/590]	loss: 0.981026
# Train Epoch: 15 [120/590]	loss: 1.010602
# Train Epoch: 15 [130/590]	loss: 1.049251
# Train Epoch: 15 [140/590]	loss: 1.163906
# Train Epoch: 15 [150/590]	loss: 1.004977
# Train Epoch: 15 [160/590]	loss: 0.972720
# Train Epoch: 15 [170/590]	loss: 1.188183
# Train Epoch: 15 [180/590]	loss: 0.987610
# Train Epoch: 15 [190/590]	loss: 1.260154
# Train Epoch: 15 [200/590]	loss: 1.148989
# Train Epoch: 15 [210/590]	loss: 0.991188
# Train Epoch: 15 [220/590]	loss: 0.997678
# Train Epoch: 15 [230/590]	loss: 0.976038
# Train Epoch: 15 [240/590]	loss: 1.006935
# Train Epoch: 15 [250/590]	loss: 0.969629
# Train Epoch: 15 [260/590]	loss: 1.052107
# Train Epoch: 15 [270/590]	loss: 1.025948
# Train Epoch: 15 [280/590]	loss: 0.987411
# Train Epoch: 15 [290/590]	loss: 1.137545
# Train Epoch: 15 [300/590]	loss: 1.205946
# Train Epoch: 15 [310/590]	loss: 1.030661
# Train Epoch: 15 [320/590]	loss: 1.098899
# Train Epoch: 15 [330/590]	loss: 0.971191
# Train Epoch: 15 [340/590]	loss: 1.091251
# Train Epoch: 15 [350/590]	loss: 1.052820
# Train Epoch: 15 [360/590]	loss: 1.014947
# Train Epoch: 15 [370/590]	loss: 0.984432
# Train Epoch: 15 [380/590]	loss: 0.999260
# Train Epoch: 15 [390/590]	loss: 0.970026
# Train Epoch: 15 [400/590]	loss: 0.965669
# Train Epoch: 15 [410/590]	loss: 0.967856
# Train Epoch: 15 [420/590]	loss: 0.995602
# Train Epoch: 15 [430/590]	loss: 0.992378
# Train Epoch: 15 [440/590]	loss: 1.042552
# Train Epoch: 15 [450/590]	loss: 0.969813
# Train Epoch: 15 [460/590]	loss: 1.123588
# Train Epoch: 15 [470/590]	loss: 0.968273
# Train Epoch: 15 [480/590]	loss: 1.001654
# Train Epoch: 15 [490/590]	loss: 0.969894
# Train Epoch: 15 [500/590]	loss: 1.094107
# Train Epoch: 15 [510/590]	loss: 0.980476
# Train Epoch: 15 [520/590]	loss: 1.027521
# Train Epoch: 15 [530/590]	loss: 1.034943
# Train Epoch: 15 [540/590]	loss: 1.038817
# Train Epoch: 15 [550/590]	loss: 0.970471
# Train Epoch: 15 [560/590]	loss: 0.987309
# Train Epoch: 15 [570/590]	loss: 0.961544
# Train Epoch: 15 [580/590]	loss: 0.974149
# [15]Validation Loss: 0.3161,Accuracy: 92.5676%
# Train Epoch: 16 [0/590]	loss: 1.136172
# Train Epoch: 16 [10/590]	loss: 0.992285
# Train Epoch: 16 [20/590]	loss: 1.012310
# Train Epoch: 16 [30/590]	loss: 1.001472
# Train Epoch: 16 [40/590]	loss: 0.979929
# Train Epoch: 16 [50/590]	loss: 0.983997
# Train Epoch: 16 [60/590]	loss: 1.027193
# Train Epoch: 16 [70/590]	loss: 0.981908
# Train Epoch: 16 [80/590]	loss: 0.991409
# Train Epoch: 16 [90/590]	loss: 1.010908
# Train Epoch: 16 [100/590]	loss: 0.991400
# Train Epoch: 16 [110/590]	loss: 0.978333
# Train Epoch: 16 [120/590]	loss: 0.981543
# Train Epoch: 16 [130/590]	loss: 1.028329
# Train Epoch: 16 [140/590]	loss: 1.016274
# Train Epoch: 16 [150/590]	loss: 1.035235
# Train Epoch: 16 [160/590]	loss: 1.060314
# Train Epoch: 16 [170/590]	loss: 1.054613
# Train Epoch: 16 [180/590]	loss: 0.986654
# Train Epoch: 16 [190/590]	loss: 1.018667
# Train Epoch: 16 [200/590]	loss: 1.000925
# Train Epoch: 16 [210/590]	loss: 1.028455
# Train Epoch: 16 [220/590]	loss: 1.066009
# Train Epoch: 16 [230/590]	loss: 1.002006
# Train Epoch: 16 [240/590]	loss: 0.972041
# Train Epoch: 16 [250/590]	loss: 1.103773
# Train Epoch: 16 [260/590]	loss: 0.979306
# Train Epoch: 16 [270/590]	loss: 0.964483
# Train Epoch: 16 [280/590]	loss: 0.981056
# Train Epoch: 16 [290/590]	loss: 1.000445
# Train Epoch: 16 [300/590]	loss: 1.144621
# Train Epoch: 16 [310/590]	loss: 1.004050
# Train Epoch: 16 [320/590]	loss: 0.969486
# Train Epoch: 16 [330/590]	loss: 0.959372
# Train Epoch: 16 [340/590]	loss: 0.985466
# Train Epoch: 16 [350/590]	loss: 1.026189
# Train Epoch: 16 [360/590]	loss: 1.016036
# Train Epoch: 16 [370/590]	loss: 0.984390
# Train Epoch: 16 [380/590]	loss: 0.999769
# Train Epoch: 16 [390/590]	loss: 1.057178
# Train Epoch: 16 [400/590]	loss: 0.982245
# Train Epoch: 16 [410/590]	loss: 0.985741
# Train Epoch: 16 [420/590]	loss: 0.980212
# Train Epoch: 16 [430/590]	loss: 0.954830
# Train Epoch: 16 [440/590]	loss: 1.010882
# Train Epoch: 16 [450/590]	loss: 0.983267
# Train Epoch: 16 [460/590]	loss: 0.961800
# Train Epoch: 16 [470/590]	loss: 0.982157
# Train Epoch: 16 [480/590]	loss: 0.969483
# Train Epoch: 16 [490/590]	loss: 1.001359
# Train Epoch: 16 [500/590]	loss: 1.096104
# Train Epoch: 16 [510/590]	loss: 1.065764
# Train Epoch: 16 [520/590]	loss: 0.997689
# Train Epoch: 16 [530/590]	loss: 0.972206
# Train Epoch: 16 [540/590]	loss: 1.006465
# Train Epoch: 16 [550/590]	loss: 1.421496
# Train Epoch: 16 [560/590]	loss: 0.991761
# Train Epoch: 16 [570/590]	loss: 0.983005
# Train Epoch: 16 [580/590]	loss: 0.973733
# [16]Validation Loss: 0.3028,Accuracy: 93.5811%
# Train Epoch: 17 [0/590]	loss: 1.058761
# Train Epoch: 17 [10/590]	loss: 1.002962
# Train Epoch: 17 [20/590]	loss: 0.983630
# Train Epoch: 17 [30/590]	loss: 0.961547
# Train Epoch: 17 [40/590]	loss: 0.986090
# Train Epoch: 17 [50/590]	loss: 1.036439
# Train Epoch: 17 [60/590]	loss: 0.970121
# Train Epoch: 17 [70/590]	loss: 1.010010
# Train Epoch: 17 [80/590]	loss: 1.091779
# Train Epoch: 17 [90/590]	loss: 0.980052
# Train Epoch: 17 [100/590]	loss: 0.968833
# Train Epoch: 17 [110/590]	loss: 0.981837
# Train Epoch: 17 [120/590]	loss: 0.982305
# Train Epoch: 17 [130/590]	loss: 1.048306
# Train Epoch: 17 [140/590]	loss: 0.963888
# Train Epoch: 17 [150/590]	loss: 1.215607
# Train Epoch: 17 [160/590]	loss: 0.984704
# Train Epoch: 17 [170/590]	loss: 0.968615
# Train Epoch: 17 [180/590]	loss: 1.234167
# Train Epoch: 17 [190/590]	loss: 0.984896
# Train Epoch: 17 [200/590]	loss: 1.059773
# Train Epoch: 17 [210/590]	loss: 0.974275
# Train Epoch: 17 [220/590]	loss: 1.036133
# Train Epoch: 17 [230/590]	loss: 1.027258
# Train Epoch: 17 [240/590]	loss: 1.105398
# Train Epoch: 17 [250/590]	loss: 0.976617
# Train Epoch: 17 [260/590]	loss: 1.008486
# Train Epoch: 17 [270/590]	loss: 0.965461
# Train Epoch: 17 [280/590]	loss: 1.162339
# Train Epoch: 17 [290/590]	loss: 0.963782
# Train Epoch: 17 [300/590]	loss: 0.990273
# Train Epoch: 17 [310/590]	loss: 0.967584
# Train Epoch: 17 [320/590]	loss: 0.989388
# Train Epoch: 17 [330/590]	loss: 1.052484
# Train Epoch: 17 [340/590]	loss: 0.965184
# Train Epoch: 17 [350/590]	loss: 0.988464
# Train Epoch: 17 [360/590]	loss: 1.136427
# Train Epoch: 17 [370/590]	loss: 1.124044
# Train Epoch: 17 [380/590]	loss: 0.991283
# Train Epoch: 17 [390/590]	loss: 1.012542
# Train Epoch: 17 [400/590]	loss: 1.068048
# Train Epoch: 17 [410/590]	loss: 0.970886
# Train Epoch: 17 [420/590]	loss: 0.970544
# Train Epoch: 17 [430/590]	loss: 0.979096
# Train Epoch: 17 [440/590]	loss: 0.992011
# Train Epoch: 17 [450/590]	loss: 0.985758
# Train Epoch: 17 [460/590]	loss: 0.972489
# Train Epoch: 17 [470/590]	loss: 1.198353
# Train Epoch: 17 [480/590]	loss: 0.971755
# Train Epoch: 17 [490/590]	loss: 1.051313
# Train Epoch: 17 [500/590]	loss: 1.005280
# Train Epoch: 17 [510/590]	loss: 1.039095
# Train Epoch: 17 [520/590]	loss: 0.984135
# Train Epoch: 17 [530/590]	loss: 0.960547
# Train Epoch: 17 [540/590]	loss: 1.132528
# Train Epoch: 17 [550/590]	loss: 1.020103
# Train Epoch: 17 [560/590]	loss: 1.076797
# Train Epoch: 17 [570/590]	loss: 0.998679
# Train Epoch: 17 [580/590]	loss: 1.242365
# [17]Validation Loss: 0.2989,Accuracy: 92.9054%
# Train Epoch: 18 [0/590]	loss: 1.087798
# Train Epoch: 18 [10/590]	loss: 1.079248
# Train Epoch: 18 [20/590]	loss: 1.032817
# Train Epoch: 18 [30/590]	loss: 1.414447
# Train Epoch: 18 [40/590]	loss: 0.990176
# Train Epoch: 18 [50/590]	loss: 1.025826
# Train Epoch: 18 [60/590]	loss: 0.980154
# Train Epoch: 18 [70/590]	loss: 1.101606
# Train Epoch: 18 [80/590]	loss: 1.005242
# Train Epoch: 18 [90/590]	loss: 0.967622
# Train Epoch: 18 [100/590]	loss: 0.973521
# Train Epoch: 18 [110/590]	loss: 1.234280
# Train Epoch: 18 [120/590]	loss: 0.998641
# Train Epoch: 18 [130/590]	loss: 1.057014
# Train Epoch: 18 [140/590]	loss: 0.975980
# Train Epoch: 18 [150/590]	loss: 1.019122
# Train Epoch: 18 [160/590]	loss: 1.063002
# Train Epoch: 18 [170/590]	loss: 0.969867
# Train Epoch: 18 [180/590]	loss: 0.997494
# Train Epoch: 18 [190/590]	loss: 0.971335
# Train Epoch: 18 [200/590]	loss: 0.974294
# Train Epoch: 18 [210/590]	loss: 0.965053
# Train Epoch: 18 [220/590]	loss: 0.992479
# Train Epoch: 18 [230/590]	loss: 0.970575
# Train Epoch: 18 [240/590]	loss: 0.978246
# Train Epoch: 18 [250/590]	loss: 1.019485
# Train Epoch: 18 [260/590]	loss: 0.974045
# Train Epoch: 18 [270/590]	loss: 1.089657
# Train Epoch: 18 [280/590]	loss: 1.019850
# Train Epoch: 18 [290/590]	loss: 1.030272
# Train Epoch: 18 [300/590]	loss: 1.000111
# Train Epoch: 18 [310/590]	loss: 1.046076
# Train Epoch: 18 [320/590]	loss: 1.021860
# Train Epoch: 18 [330/590]	loss: 1.022772
# Train Epoch: 18 [340/590]	loss: 0.981388
# Train Epoch: 18 [350/590]	loss: 0.980509
# Train Epoch: 18 [360/590]	loss: 0.975164
# Train Epoch: 18 [370/590]	loss: 1.088921
# Train Epoch: 18 [380/590]	loss: 0.975559
# Train Epoch: 18 [390/590]	loss: 1.008510
# Train Epoch: 18 [400/590]	loss: 1.013541
# Train Epoch: 18 [410/590]	loss: 0.990302
# Train Epoch: 18 [420/590]	loss: 0.965513
# Train Epoch: 18 [430/590]	loss: 1.200779
# Train Epoch: 18 [440/590]	loss: 0.978871
# Train Epoch: 18 [450/590]	loss: 0.973614
# Train Epoch: 18 [460/590]	loss: 1.009783
# Train Epoch: 18 [470/590]	loss: 0.977507
# Train Epoch: 18 [480/590]	loss: 0.975631
# Train Epoch: 18 [490/590]	loss: 0.970945
# Train Epoch: 18 [500/590]	loss: 0.977014
# Train Epoch: 18 [510/590]	loss: 0.975157
# Train Epoch: 18 [520/590]	loss: 0.972184
# Train Epoch: 18 [530/590]	loss: 0.992073
# Train Epoch: 18 [540/590]	loss: 0.985396
# Train Epoch: 18 [550/590]	loss: 0.970303
# Train Epoch: 18 [560/590]	loss: 0.983124
# Train Epoch: 18 [570/590]	loss: 0.974659
# Train Epoch: 18 [580/590]	loss: 0.982553
# [18]Validation Loss: 0.3038,Accuracy: 92.9054%
# Train Epoch: 19 [0/590]	loss: 1.054415
# Train Epoch: 19 [10/590]	loss: 0.994225
# Train Epoch: 19 [20/590]	loss: 0.985621
# Train Epoch: 19 [30/590]	loss: 0.974882
# Train Epoch: 19 [40/590]	loss: 1.056053
# Train Epoch: 19 [50/590]	loss: 1.024394
# Train Epoch: 19 [60/590]	loss: 1.001890
# Train Epoch: 19 [70/590]	loss: 1.139093
# Train Epoch: 19 [80/590]	loss: 0.990309
# Train Epoch: 19 [90/590]	loss: 0.990015
# Train Epoch: 19 [100/590]	loss: 0.958056
# Train Epoch: 19 [110/590]	loss: 1.006308
# Train Epoch: 19 [120/590]	loss: 0.977858
# Train Epoch: 19 [130/590]	loss: 0.966760
# Train Epoch: 19 [140/590]	loss: 0.985726
# Train Epoch: 19 [150/590]	loss: 1.086822
# Train Epoch: 19 [160/590]	loss: 0.964724
# Train Epoch: 19 [170/590]	loss: 0.966952
# Train Epoch: 19 [180/590]	loss: 0.978544
# Train Epoch: 19 [190/590]	loss: 0.966608
# Train Epoch: 19 [200/590]	loss: 0.971642
# Train Epoch: 19 [210/590]	loss: 0.951753
# Train Epoch: 19 [220/590]	loss: 0.974253
# Train Epoch: 19 [230/590]	loss: 0.961948
# Train Epoch: 19 [240/590]	loss: 0.968252
# Train Epoch: 19 [250/590]	loss: 1.059300
# Train Epoch: 19 [260/590]	loss: 0.993740
# Train Epoch: 19 [270/590]	loss: 0.977259
# Train Epoch: 19 [280/590]	loss: 1.420944
# Train Epoch: 19 [290/590]	loss: 0.977829
# Train Epoch: 19 [300/590]	loss: 0.989973
# Train Epoch: 19 [310/590]	loss: 0.978154
# Train Epoch: 19 [320/590]	loss: 0.962440
# Train Epoch: 19 [330/590]	loss: 0.981428
# Train Epoch: 19 [340/590]	loss: 1.007067
# Train Epoch: 19 [350/590]	loss: 1.016536
# Train Epoch: 19 [360/590]	loss: 1.002505
# Train Epoch: 19 [370/590]	loss: 0.958753
# Train Epoch: 19 [380/590]	loss: 1.060736
# Train Epoch: 19 [390/590]	loss: 0.975145
# Train Epoch: 19 [400/590]	loss: 0.996099
# Train Epoch: 19 [410/590]	loss: 0.983496
# Train Epoch: 19 [420/590]	loss: 0.972519
# Train Epoch: 19 [430/590]	loss: 1.114771
# Train Epoch: 19 [440/590]	loss: 0.970954
# Train Epoch: 19 [450/590]	loss: 0.980899
# Train Epoch: 19 [460/590]	loss: 0.994743
# ...
# Train Epoch: 23 [440/590]	loss: 1.023381
# Train Epoch: 23 [450/590]	loss: 1.112522
# Train Epoch: 23 [460/590]	loss: 1.007856
# Train Epoch: 23 [470/590]	loss: 0.989766
# Train Epoch: 23 [480/590]	loss: 1.060644
# Train Epoch: 23 [490/590]	loss: 1.001041
# Train Epoch: 23 [500/590]	loss: 0.981489
# Train Epoch: 23 [510/590]	loss: 1.024842
# Train Epoch: 23 [520/590]	loss: 1.088318
# Train Epoch: 23 [530/590]	loss: 1.071944
# Train Epoch: 23 [540/590]	loss: 1.106506
# Train Epoch: 23 [550/590]	loss: 0.991096
# Train Epoch: 23 [560/590]	loss: 1.025749
# Train Epoch: 23 [570/590]	loss: 0.956247
# Train Epoch: 23 [580/590]	loss: 0.979549
# [23]Validation Loss: 0.2996,Accuracy: 94.5946%
# Train Epoch: 24 [0/590]	loss: 0.968090
# Train Epoch: 24 [10/590]	loss: 0.976208
# Train Epoch: 24 [20/590]	loss: 0.968694
# Train Epoch: 24 [30/590]	loss: 1.170603
# Train Epoch: 24 [40/590]	loss: 1.023505
# Train Epoch: 24 [50/590]	loss: 0.986423
# Train Epoch: 24 [60/590]	loss: 0.963035
# Train Epoch: 24 [70/590]	loss: 1.085271
# Train Epoch: 24 [80/590]	loss: 1.024778
# Train Epoch: 24 [90/590]	loss: 0.963041
# Train Epoch: 24 [100/590]	loss: 1.007003
# Train Epoch: 24 [110/590]	loss: 0.965907
# Train Epoch: 24 [120/590]	loss: 0.970073
# Train Epoch: 24 [130/590]	loss: 0.962856
# Train Epoch: 24 [140/590]	loss: 0.983491
# Train Epoch: 24 [150/590]	loss: 0.963785
# Train Epoch: 24 [160/590]	loss: 0.974161
# Train Epoch: 24 [170/590]	loss: 0.995624
# Train Epoch: 24 [180/590]	loss: 1.014273
# Train Epoch: 24 [190/590]	loss: 1.001641
# Train Epoch: 24 [200/590]	loss: 0.989912
# Train Epoch: 24 [210/590]	loss: 1.047931
# Train Epoch: 24 [220/590]	loss: 0.986791
# Train Epoch: 24 [230/590]	loss: 1.114328
# Train Epoch: 24 [240/590]	loss: 1.009126
# Train Epoch: 24 [250/590]	loss: 0.960225
# Train Epoch: 24 [260/590]	loss: 0.961711
# Train Epoch: 24 [270/590]	loss: 1.014976
# Train Epoch: 24 [280/590]	loss: 0.972557
# Train Epoch: 24 [290/590]	loss: 0.961505
# Train Epoch: 24 [300/590]	loss: 0.962559
# Train Epoch: 24 [310/590]	loss: 0.965070
# Train Epoch: 24 [320/590]	loss: 0.955873
# Train Epoch: 24 [330/590]	loss: 0.955852
# Train Epoch: 24 [340/590]	loss: 0.958147
# Train Epoch: 24 [350/590]	loss: 0.984879
# Train Epoch: 24 [360/590]	loss: 0.978469
# Train Epoch: 24 [370/590]	loss: 0.966755
# Train Epoch: 24 [380/590]	loss: 0.972344
# Train Epoch: 24 [390/590]	loss: 1.187712
# Train Epoch: 24 [400/590]	loss: 0.983795
# Train Epoch: 24 [410/590]	loss: 0.964705
# Train Epoch: 24 [420/590]	loss: 0.974665
# Train Epoch: 24 [430/590]	loss: 0.956944
# Train Epoch: 24 [440/590]	loss: 0.967222
# Train Epoch: 24 [450/590]	loss: 0.972120
# Train Epoch: 24 [460/590]	loss: 0.959556
# Train Epoch: 24 [470/590]	loss: 0.964927
# Train Epoch: 24 [480/590]	loss: 0.966444
# Train Epoch: 24 [490/590]	loss: 1.029697
# Train Epoch: 24 [500/590]	loss: 1.000951
# Train Epoch: 24 [510/590]	loss: 0.964639
# Train Epoch: 24 [520/590]	loss: 1.002322
# Train Epoch: 24 [530/590]	loss: 0.962450
# Train Epoch: 24 [540/590]	loss: 0.970469
# Train Epoch: 24 [550/590]	loss: 0.964542
# Train Epoch: 24 [560/590]	loss: 0.971665
# Train Epoch: 24 [570/590]	loss: 0.992744
# Train Epoch: 24 [580/590]	loss: 1.045800
# [24]Validation Loss: 0.3040,Accuracy: 93.5811%
# Train Epoch: 25 [0/590]	loss: 0.972033
# Train Epoch: 25 [10/590]	loss: 0.963889
# Train Epoch: 25 [20/590]	loss: 0.971491
# Train Epoch: 25 [30/590]	loss: 0.976541
# Train Epoch: 25 [40/590]	loss: 1.025271
# Train Epoch: 25 [50/590]	loss: 0.977781
# Train Epoch: 25 [60/590]	loss: 1.053927
# Train Epoch: 25 [70/590]	loss: 0.973732
# Train Epoch: 25 [80/590]	loss: 0.952981
# Train Epoch: 25 [90/590]	loss: 1.102864
# Train Epoch: 25 [100/590]	loss: 0.957555
# Train Epoch: 25 [110/590]	loss: 1.017065
# Train Epoch: 25 [120/590]	loss: 0.983693
# Train Epoch: 25 [130/590]	loss: 0.994644
# Train Epoch: 25 [140/590]	loss: 0.993570
# Train Epoch: 25 [150/590]	loss: 1.015292
# Train Epoch: 25 [160/590]	loss: 0.984148
# Train Epoch: 25 [170/590]	loss: 0.973322
# Train Epoch: 25 [180/590]	loss: 0.961061
# Train Epoch: 25 [190/590]	loss: 0.959809
# Train Epoch: 25 [200/590]	loss: 1.043041
# Train Epoch: 25 [210/590]	loss: 0.978073
# Train Epoch: 25 [220/590]	loss: 0.980892
# Train Epoch: 25 [230/590]	loss: 0.969704
# Train Epoch: 25 [240/590]	loss: 0.964461
# Train Epoch: 25 [250/590]	loss: 1.166988
# Train Epoch: 25 [260/590]	loss: 0.999099
# Train Epoch: 25 [270/590]	loss: 1.037762
# Train Epoch: 25 [280/590]	loss: 0.979557
# Train Epoch: 25 [290/590]	loss: 0.972006
# Train Epoch: 25 [300/590]	loss: 1.017368
# Train Epoch: 25 [310/590]	loss: 0.993315
# Train Epoch: 25 [320/590]	loss: 1.138443
# Train Epoch: 25 [330/590]	loss: 1.032355
# Train Epoch: 25 [340/590]	loss: 1.001307
# Train Epoch: 25 [350/590]	loss: 0.985786
# Train Epoch: 25 [360/590]	loss: 0.982806
# Train Epoch: 25 [370/590]	loss: 0.977844
# Train Epoch: 25 [380/590]	loss: 0.977412
# Train Epoch: 25 [390/590]	loss: 0.971962
# Train Epoch: 25 [400/590]	loss: 0.975883
# Train Epoch: 25 [410/590]	loss: 0.968519
# Train Epoch: 25 [420/590]	loss: 0.986754
# Train Epoch: 25 [430/590]	loss: 0.967502
# Train Epoch: 25 [440/590]	loss: 0.990002
# Train Epoch: 25 [450/590]	loss: 0.986862
# Train Epoch: 25 [460/590]	loss: 0.952548
# Train Epoch: 25 [470/590]	loss: 0.984011
# Train Epoch: 25 [480/590]	loss: 0.976645
# Train Epoch: 25 [490/590]	loss: 0.992528
# Train Epoch: 25 [500/590]	loss: 0.957818
# Train Epoch: 25 [510/590]	loss: 0.973525
# Train Epoch: 25 [520/590]	loss: 0.973024
# Train Epoch: 25 [530/590]	loss: 0.965715
# Train Epoch: 25 [540/590]	loss: 0.962472
# Train Epoch: 25 [550/590]	loss: 0.975146
# Train Epoch: 25 [560/590]	loss: 1.067457
# Train Epoch: 25 [570/590]	loss: 0.985729
# Train Epoch: 25 [580/590]	loss: 0.974176
# [25]Validation Loss: 0.2926,Accuracy: 94.2568%
# Train Epoch: 26 [0/590]	loss: 0.978114
# Train Epoch: 26 [10/590]	loss: 0.944028
# Train Epoch: 26 [20/590]	loss: 0.972495
# Train Epoch: 26 [30/590]	loss: 0.952599
# Train Epoch: 26 [40/590]	loss: 1.019445
# Train Epoch: 26 [50/590]	loss: 1.053607
# Train Epoch: 26 [60/590]	loss: 1.071135
# Train Epoch: 26 [70/590]	loss: 1.028880
# Train Epoch: 26 [80/590]	loss: 0.975197
# Train Epoch: 26 [90/590]	loss: 1.178869
# Train Epoch: 26 [100/590]	loss: 1.025272
# Train Epoch: 26 [110/590]	loss: 1.008733
# Train Epoch: 26 [120/590]	loss: 0.997453
# Train Epoch: 26 [130/590]	loss: 0.998111
# Train Epoch: 26 [140/590]	loss: 0.976060
# Train Epoch: 26 [150/590]	loss: 1.009485
# Train Epoch: 26 [160/590]	loss: 1.117558
# Train Epoch: 26 [170/590]	loss: 0.962605
# Train Epoch: 26 [180/590]	loss: 0.981480
# Train Epoch: 26 [190/590]	loss: 0.967680
# Train Epoch: 26 [200/590]	loss: 1.002059
# Train Epoch: 26 [210/590]	loss: 0.976089
# Train Epoch: 26 [220/590]	loss: 0.955698
# Train Epoch: 26 [230/590]	loss: 0.998251
# Train Epoch: 26 [240/590]	loss: 0.978988
# Train Epoch: 26 [250/590]	loss: 0.967355
# Train Epoch: 26 [260/590]	loss: 0.968394
# Train Epoch: 26 [270/590]	loss: 0.954530
# Train Epoch: 26 [280/590]	loss: 1.060476
# Train Epoch: 26 [290/590]	loss: 0.976100
# Train Epoch: 26 [300/590]	loss: 1.154815
# Train Epoch: 26 [310/590]	loss: 1.008281
# Train Epoch: 26 [320/590]	loss: 1.004609
# Train Epoch: 26 [330/590]	loss: 0.992694
# Train Epoch: 26 [340/590]	loss: 1.018823
# Train Epoch: 26 [350/590]	loss: 0.987038
# Train Epoch: 26 [360/590]	loss: 0.971235
# Train Epoch: 26 [370/590]	loss: 0.980139
# Train Epoch: 26 [380/590]	loss: 0.977949
# Train Epoch: 26 [390/590]	loss: 0.959520
# Train Epoch: 26 [400/590]	loss: 0.978793
# Train Epoch: 26 [410/590]	loss: 0.964673
# Train Epoch: 26 [420/590]	loss: 1.002937
# Train Epoch: 26 [430/590]	loss: 0.971361
# Train Epoch: 26 [440/590]	loss: 0.972065
# Train Epoch: 26 [450/590]	loss: 0.964623
# Train Epoch: 26 [460/590]	loss: 1.016792
# Train Epoch: 26 [470/590]	loss: 0.956191
# Train Epoch: 26 [480/590]	loss: 0.959278
# Train Epoch: 26 [490/590]	loss: 0.975520
# Train Epoch: 26 [500/590]	loss: 0.959368
# Train Epoch: 26 [510/590]	loss: 0.984806
# Train Epoch: 26 [520/590]	loss: 1.012894
# Train Epoch: 26 [530/590]	loss: 0.971341
# Train Epoch: 26 [540/590]	loss: 1.130800
# Train Epoch: 26 [550/590]	loss: 0.984948
# Train Epoch: 26 [560/590]	loss: 0.952541
# Train Epoch: 26 [570/590]	loss: 1.010185
# Train Epoch: 26 [580/590]	loss: 1.034027
# [26]Validation Loss: 0.2975,Accuracy: 93.5811%
# Train Epoch: 27 [0/590]	loss: 0.993274
# Train Epoch: 27 [10/590]	loss: 1.060982
# Train Epoch: 27 [20/590]	loss: 0.959739
# Train Epoch: 27 [30/590]	loss: 1.183203
# Train Epoch: 27 [40/590]	loss: 0.988869
# Train Epoch: 27 [50/590]	loss: 0.985349
# Train Epoch: 27 [60/590]	loss: 0.969558
# Train Epoch: 27 [70/590]	loss: 0.953984
# Train Epoch: 27 [80/590]	loss: 0.969293
# Train Epoch: 27 [90/590]	loss: 1.024020
# Train Epoch: 27 [100/590]	loss: 1.036588
# Train Epoch: 27 [110/590]	loss: 0.974152
# Train Epoch: 27 [120/590]	loss: 1.003535
# Train Epoch: 27 [130/590]	loss: 0.960672
# Train Epoch: 27 [140/590]	loss: 0.981422
# Train Epoch: 27 [150/590]	loss: 1.004770
# Train Epoch: 27 [160/590]	loss: 1.017004
# Train Epoch: 27 [170/590]	loss: 0.971317
# Train Epoch: 27 [180/590]	loss: 1.033538
# Train Epoch: 27 [190/590]	loss: 1.015372
# Train Epoch: 27 [200/590]	loss: 0.956292
# Train Epoch: 27 [210/590]	loss: 0.972787
# Train Epoch: 27 [220/590]	loss: 0.955747
# Train Epoch: 27 [230/590]	loss: 1.008495
# Train Epoch: 27 [240/590]	loss: 0.973737
# Train Epoch: 27 [250/590]	loss: 0.984295
# Train Epoch: 27 [260/590]	loss: 0.985796
# Train Epoch: 27 [270/590]	loss: 0.968320
# Train Epoch: 27 [280/590]	loss: 1.009143
# Train Epoch: 27 [290/590]	loss: 0.959769
# Train Epoch: 27 [300/590]	loss: 0.985171
# Train Epoch: 27 [310/590]	loss: 1.017629
# Train Epoch: 27 [320/590]	loss: 0.966201
# Train Epoch: 27 [330/590]	loss: 0.988721
# Train Epoch: 27 [340/590]	loss: 0.992115
# Train Epoch: 27 [350/590]	loss: 1.062487
# Train Epoch: 27 [360/590]	loss: 0.970583
# Train Epoch: 27 [370/590]	loss: 0.967661
# Train Epoch: 27 [380/590]	loss: 0.961559
# Train Epoch: 27 [390/590]	loss: 1.020640
# Train Epoch: 27 [400/590]	loss: 0.954703
# Train Epoch: 27 [410/590]	loss: 1.016888
# Train Epoch: 27 [420/590]	loss: 0.994781
# Train Epoch: 27 [430/590]	loss: 0.985334
# Train Epoch: 27 [440/590]	loss: 0.970756
# Train Epoch: 27 [450/590]	loss: 1.006194
# Train Epoch: 27 [460/590]	loss: 0.967112
# Train Epoch: 27 [470/590]	loss: 1.006095
# Train Epoch: 27 [480/590]	loss: 1.034072
# Train Epoch: 27 [490/590]	loss: 0.978775
# Train Epoch: 27 [500/590]	loss: 0.969833
# Train Epoch: 27 [510/590]	loss: 0.981838
# Train Epoch: 27 [520/590]	loss: 0.965977
# Train Epoch: 27 [530/590]	loss: 0.963714
# Train Epoch: 27 [540/590]	loss: 1.020800
# Train Epoch: 27 [550/590]	loss: 0.963249
# Train Epoch: 27 [560/590]	loss: 0.979613
# Train Epoch: 27 [570/590]	loss: 0.978971
# Train Epoch: 27 [580/590]	loss: 0.965391
# [27]Validation Loss: 0.2987,Accuracy: 93.9189%
# Train Epoch: 28 [0/590]	loss: 0.977353
# Train Epoch: 28 [10/590]	loss: 0.990577
# Train Epoch: 28 [20/590]	loss: 0.969331
# Train Epoch: 28 [30/590]	loss: 0.958259
# Train Epoch: 28 [40/590]	loss: 1.043848
# Train Epoch: 28 [50/590]	loss: 0.961030
# Train Epoch: 28 [60/590]	loss: 0.970795
# Train Epoch: 28 [70/590]	loss: 0.967887
# Train Epoch: 28 [80/590]	loss: 0.980649
# Train Epoch: 28 [90/590]	loss: 1.017178
# Train Epoch: 28 [100/590]	loss: 0.986029
# Train Epoch: 28 [110/590]	loss: 0.988972
# Train Epoch: 28 [120/590]	loss: 1.026084
# Train Epoch: 28 [130/590]	loss: 0.958712
# Train Epoch: 28 [140/590]	loss: 1.262920
# Train Epoch: 28 [150/590]	loss: 0.965167
# Train Epoch: 28 [160/590]	loss: 0.967697
# Train Epoch: 28 [170/590]	loss: 1.006789
# Train Epoch: 28 [180/590]	loss: 1.049293
# Train Epoch: 28 [190/590]	loss: 0.974169
# Train Epoch: 28 [200/590]	loss: 0.960014
# Train Epoch: 28 [210/590]	loss: 0.960901
# Train Epoch: 28 [220/590]	loss: 0.975222
# Train Epoch: 28 [230/590]	loss: 0.967944
# Train Epoch: 28 [240/590]	loss: 0.989482
# Train Epoch: 28 [250/590]	loss: 1.095965
# Train Epoch: 28 [260/590]	loss: 0.967474
# Train Epoch: 28 [270/590]	loss: 0.966200
# Train Epoch: 28 [280/590]	loss: 0.968412
# Train Epoch: 28 [290/590]	loss: 1.088159
# Train Epoch: 28 [300/590]	loss: 0.953466
# Train Epoch: 28 [310/590]	loss: 0.966448
# Train Epoch: 28 [320/590]	loss: 0.972946
# Train Epoch: 28 [330/590]	loss: 1.022126
# Train Epoch: 28 [340/590]	loss: 0.973390
# Train Epoch: 28 [350/590]	loss: 1.027278
# Train Epoch: 28 [360/590]	loss: 0.987382
# Train Epoch: 28 [370/590]	loss: 0.973669
# Train Epoch: 28 [380/590]	loss: 1.049575
# Train Epoch: 28 [390/590]	loss: 0.973512
# Train Epoch: 28 [400/590]	loss: 0.992280
# Train Epoch: 28 [410/590]	loss: 0.985561
# Train Epoch: 28 [420/590]	loss: 0.987652
# Train Epoch: 28 [430/590]	loss: 0.966230
# Train Epoch: 28 [440/590]	loss: 1.134618
# Train Epoch: 28 [450/590]	loss: 0.984029
# Train Epoch: 28 [460/590]	loss: 0.986188
# Train Epoch: 28 [470/590]	loss: 0.960589
# Train Epoch: 28 [480/590]	loss: 1.009696
# Train Epoch: 28 [490/590]	loss: 0.968910
# Train Epoch: 28 [500/590]	loss: 0.965828
# Train Epoch: 28 [510/590]	loss: 0.963677
# Train Epoch: 28 [520/590]	loss: 0.967663
# Train Epoch: 28 [530/590]	loss: 0.975387
# Train Epoch: 28 [540/590]	loss: 0.961460
# Train Epoch: 28 [550/590]	loss: 1.043010
# Train Epoch: 28 [560/590]	loss: 1.263847
# Train Epoch: 28 [570/590]	loss: 1.025701
# Train Epoch: 28 [580/590]	loss: 1.007223
# [28]Validation Loss: 0.3007,Accuracy: 93.5811%
# Train Epoch: 29 [0/590]	loss: 0.979058
# Train Epoch: 29 [10/590]	loss: 1.022226
# Train Epoch: 29 [20/590]	loss: 1.167715
# Train Epoch: 29 [30/590]	loss: 0.968769
# Train Epoch: 29 [40/590]	loss: 1.111860
# Train Epoch: 29 [50/590]	loss: 1.168406
# Train Epoch: 29 [60/590]	loss: 0.976627
# Train Epoch: 29 [70/590]	loss: 1.048929
# Train Epoch: 29 [80/590]	loss: 0.963198
# Train Epoch: 29 [90/590]	loss: 0.964000
# Train Epoch: 29 [100/590]	loss: 0.972571
# Train Epoch: 29 [110/590]	loss: 0.955021
# Train Epoch: 29 [120/590]	loss: 1.013267
# Train Epoch: 29 [130/590]	loss: 0.967403
# Train Epoch: 29 [140/590]	loss: 0.980838
# Train Epoch: 29 [150/590]	loss: 0.977022
# Train Epoch: 29 [160/590]	loss: 1.155839
# Train Epoch: 29 [170/590]	loss: 0.974801
# Train Epoch: 29 [180/590]	loss: 0.971982
# Train Epoch: 29 [190/590]	loss: 0.955957
# Train Epoch: 29 [200/590]	loss: 0.957174
# Train Epoch: 29 [210/590]	loss: 0.975834
# Train Epoch: 29 [220/590]	loss: 1.019774
# Train Epoch: 29 [230/590]	loss: 0.979787
# Train Epoch: 29 [240/590]	loss: 0.964925
# Train Epoch: 29 [250/590]	loss: 0.962975
# Train Epoch: 29 [260/590]	loss: 0.963963
# Train Epoch: 29 [270/590]	loss: 0.998891
# Train Epoch: 29 [280/590]	loss: 0.993150
# Train Epoch: 29 [290/590]	loss: 0.962087
# Train Epoch: 29 [300/590]	loss: 1.003843
# Train Epoch: 29 [310/590]	loss: 0.973961
# Train Epoch: 29 [320/590]	loss: 1.057171
# Train Epoch: 29 [330/590]	loss: 0.962415
# Train Epoch: 29 [340/590]	loss: 0.972019
# Train Epoch: 29 [350/590]	loss: 1.082052
# Train Epoch: 29 [360/590]	loss: 0.983035
# Train Epoch: 29 [370/590]	loss: 0.971415
# Train Epoch: 29 [380/590]	loss: 0.978331
# Train Epoch: 29 [390/590]	loss: 1.211049
# Train Epoch: 29 [400/590]	loss: 0.983057
# Train Epoch: 29 [410/590]	loss: 0.963019
# Train Epoch: 29 [420/590]	loss: 0.964822
# Train Epoch: 29 [430/590]	loss: 1.050981
# Train Epoch: 29 [440/590]	loss: 0.961338
# Train Epoch: 29 [450/590]	loss: 0.997529
# Train Epoch: 29 [460/590]	loss: 0.967457
# Train Epoch: 29 [470/590]	loss: 0.972437
# Train Epoch: 29 [480/590]	loss: 1.006361
# Train Epoch: 29 [490/590]	loss: 1.008937
# Train Epoch: 29 [500/590]	loss: 0.970929
# Train Epoch: 29 [510/590]	loss: 0.951366
# Train Epoch: 29 [520/590]	loss: 0.969658
# Train Epoch: 29 [530/590]	loss: 0.976487
# Train Epoch: 29 [540/590]	loss: 0.973970
# Train Epoch: 29 [550/590]	loss: 1.007408
# Train Epoch: 29 [560/590]	loss: 0.958072
# Train Epoch: 29 [570/590]	loss: 0.974348
# Train Epoch: 29 [580/590]	loss: 0.973564
# [29]Validation Loss: 0.3001,Accuracy: 94.2568%
# [FINAL] Test Loss: 0.3447,Accuracy: 94.6309%
# Best Accuracy:  94.5945945945946
# Elasped Time: 2h, 132m, 26s
# time: 2h, 132m, 26s
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">snowy-tree-3</strong> at: <a href='https://wandb.ai/cv_al2/Active_learning_2/runs/mslqh5s5' target="_blank">https://wandb.ai/cv_al2/Active_learning_2/runs/mslqh5s5</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231112_070347-mslqh5s5/logs</code>

# %%
# 이제 손실 값을 플로팅합니다.
import matplotlib.pyplot as plt

# train_loss와 val_loss 텐서를 CPU로 이동하고 NumPy 배열로 변환
train_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in train_losses]
val_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), train_losses, label='train_loss', marker='o')
plt.plot(range(1, EPOCH + 1), val_losses, label='val_loss', marker='o')
plt.title('Training and Validation Loss Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()


val_accuracys = [acc.cpu().detach().numpy() if isinstance(acc, torch.Tensor) else acc for acc in val_accuracys]
plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), val_accuracys, label='val_accuracy', marker='o')
plt.title('Validation Accuracy Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras

# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

model_builder = keras.applications.xception.Xception
img_size = (299, 299)
preprocess_input = keras.applications.xception.preprocess_input
decode_predictions = keras.applications.xception.decode_predictions

last_conv_layer_name = "block14_sepconv2_act"

# The local path to our target image
import random

# 테스트 데이터셋에서 무작위로 이미지 선택
random_index = random.randint(0, len(test_set) - 1)
img_path = test_set.image_folder[random_index]
img_path = os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/test',img_path)
display(Image(img_path))

def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.utils.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.utils.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = keras.models.Model(
        model.inputs, [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
# Prepare image
img_array = preprocess_input(get_img_array(img_path, size=img_size))

# Make model
model = model_builder(weights="imagenet")

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=1)[0])

# Generate class activation heatmap
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91884032/91884032 [==============================] - 1s 0us/step
# 1/1 [==============================] - 2s 2s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 0us/step
# Predicted: [('n01855032', 'red-breasted_merganser', 9.74061)]

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.utils.load_img(img_path)
    img = keras.utils.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.utils.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.utils.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.utils.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))


save_and_display_gradcam(img_path, heatmap)
# Out:
# <ipython-input-20-8a3df7f2985d>:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap("jet")
