# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_AL_test7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# lr 0.1에서 0.0001로 수정, amsgrad 활성화

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image
#내가 추가
import re

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = re.sub(r'\([^)]*\)', '', label)
    label = int(label)
    return (img, label)

# %%
### Data Preprocessing ###

'''
# 데이터 정규화 추가
# 정규화 변환 정의
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
'''
transforms_train = transforms.Compose([transforms.Resize((448,448)),
                                       transforms.ToTensor()])
transforms_valtest = transforms.Compose([transforms.Resize((448,448)),
                                         transforms.ToTensor()])

BATCH_SIZE = 32
train_set = CUB2011(mode='train',
                    transform=transforms_train)
# transforms_train을 transforms_valtest로 변경
val_set = CUB2011(mode='valid',
                  transform=transforms_valtest)
test_set = CUB2011(mode='test',
                  transform=transforms_valtest)

print('Num of each dataset: ',len(train_set),len(val_set),len(test_set))

train_loader = DataLoader(train_set,batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")

### Model / Optimizer ###
EPOCH = 30
lr = 0.0001

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(),lr=lr, amsgrad=True)

print("Created a learning model and optimizer")
# Out:
# Num of each dataset:  2362 296 298
# Loaded dataloader
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 119MB/s]
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    # loss func을 어떤 것을 사용할 것인지?
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/74]	loss: 4.007736
# Train Epoch: 0 [10/74]	loss: 3.863555
# Train Epoch: 0 [20/74]	loss: 3.586116
# Train Epoch: 0 [30/74]	loss: 3.184973
# Train Epoch: 0 [40/74]	loss: 3.090641
# Train Epoch: 0 [50/74]	loss: 2.640280
# Train Epoch: 0 [60/74]	loss: 2.581485
# Train Epoch: 0 [70/74]	loss: 2.503563
# [0]Validation Loss: 2.0589,Accuracy: 62.1622%
# Train Epoch: 1 [0/74]	loss: 2.160699
# Train Epoch: 1 [10/74]	loss: 1.997633
# Train Epoch: 1 [20/74]	loss: 1.757651
# Train Epoch: 1 [30/74]	loss: 1.656673
# Train Epoch: 1 [40/74]	loss: 1.505854
# Train Epoch: 1 [50/74]	loss: 1.856119
# Train Epoch: 1 [60/74]	loss: 1.279496
# Train Epoch: 1 [70/74]	loss: 1.366922
# [1]Validation Loss: 1.4050,Accuracy: 80.4054%
# Train Epoch: 2 [0/74]	loss: 0.960432
# Train Epoch: 2 [10/74]	loss: 1.078509
# Train Epoch: 2 [20/74]	loss: 0.927500
# Train Epoch: 2 [30/74]	loss: 0.786981
# Train Epoch: 2 [40/74]	loss: 0.852010
# Train Epoch: 2 [50/74]	loss: 0.624421
# Train Epoch: 2 [60/74]	loss: 0.805453
# Train Epoch: 2 [70/74]	loss: 0.868033
# [2]Validation Loss: 1.0219,Accuracy: 86.4865%
# Train Epoch: 3 [0/74]	loss: 0.428815
# Train Epoch: 3 [10/74]	loss: 0.537993
# Train Epoch: 3 [20/74]	loss: 0.405951
# Train Epoch: 3 [30/74]	loss: 0.497640
# Train Epoch: 3 [40/74]	loss: 0.504571
# Train Epoch: 3 [50/74]	loss: 0.467028
# Train Epoch: 3 [60/74]	loss: 0.431646
# Train Epoch: 3 [70/74]	loss: 0.488387
# [3]Validation Loss: 0.7812,Accuracy: 87.5000%
# Train Epoch: 4 [0/74]	loss: 0.203711
# Train Epoch: 4 [10/74]	loss: 0.194708
# Train Epoch: 4 [20/74]	loss: 0.199239
# Train Epoch: 4 [30/74]	loss: 0.168568
# Train Epoch: 4 [40/74]	loss: 0.138342
# Train Epoch: 4 [50/74]	loss: 0.164206
# Train Epoch: 4 [60/74]	loss: 0.240233
# Train Epoch: 4 [70/74]	loss: 0.181084
# [4]Validation Loss: 0.6726,Accuracy: 88.8514%
# Train Epoch: 5 [0/74]	loss: 0.108671
# Train Epoch: 5 [10/74]	loss: 0.117308
# Train Epoch: 5 [20/74]	loss: 0.092909
# Train Epoch: 5 [30/74]	loss: 0.101589
# Train Epoch: 5 [40/74]	loss: 0.139434
# Train Epoch: 5 [50/74]	loss: 0.086782
# Train Epoch: 5 [60/74]	loss: 0.081015
# Train Epoch: 5 [70/74]	loss: 0.150286
# [5]Validation Loss: 0.6485,Accuracy: 88.5135%
# Train Epoch: 6 [0/74]	loss: 0.084216
# Train Epoch: 6 [10/74]	loss: 0.074633
# Train Epoch: 6 [20/74]	loss: 0.080718
# Train Epoch: 6 [30/74]	loss: 0.095382
# Train Epoch: 6 [40/74]	loss: 0.061213
# Train Epoch: 6 [50/74]	loss: 0.076045
# Train Epoch: 6 [60/74]	loss: 0.081516
# Train Epoch: 6 [70/74]	loss: 0.058127
# [6]Validation Loss: 0.6235,Accuracy: 88.8514%
# Train Epoch: 7 [0/74]	loss: 0.054341
# Train Epoch: 7 [10/74]	loss: 0.070731
# Train Epoch: 7 [20/74]	loss: 0.053253
# Train Epoch: 7 [30/74]	loss: 0.043152
# Train Epoch: 7 [40/74]	loss: 0.043179
# Train Epoch: 7 [50/74]	loss: 0.043890
# Train Epoch: 7 [60/74]	loss: 0.045971
# Train Epoch: 7 [70/74]	loss: 0.045798
# [7]Validation Loss: 0.5980,Accuracy: 88.1757%
# Train Epoch: 8 [0/74]	loss: 0.036923
# Train Epoch: 8 [10/74]	loss: 0.048953
# Train Epoch: 8 [20/74]	loss: 0.054633
# Train Epoch: 8 [30/74]	loss: 0.043547
# Train Epoch: 8 [40/74]	loss: 0.037313
# Train Epoch: 8 [50/74]	loss: 0.041991
# Train Epoch: 8 [60/74]	loss: 0.033160
# Train Epoch: 8 [70/74]	loss: 0.033418
# [8]Validation Loss: 0.5853,Accuracy: 90.2027%
# Train Epoch: 9 [0/74]	loss: 0.031116
# Train Epoch: 9 [10/74]	loss: 0.033850
# Train Epoch: 9 [20/74]	loss: 0.034850
# Train Epoch: 9 [30/74]	loss: 0.028177
# Train Epoch: 9 [40/74]	loss: 0.028002
# Train Epoch: 9 [50/74]	loss: 0.025774
# Train Epoch: 9 [60/74]	loss: 0.028449
# Train Epoch: 9 [70/74]	loss: 0.032016
# [9]Validation Loss: 0.5802,Accuracy: 89.5270%
# Train Epoch: 10 [0/74]	loss: 0.022350
# Train Epoch: 10 [10/74]	loss: 0.021705
# Train Epoch: 10 [20/74]	loss: 0.023730
# Train Epoch: 10 [30/74]	loss: 0.025169
# Train Epoch: 10 [40/74]	loss: 0.025476
# Train Epoch: 10 [50/74]	loss: 0.026397
# Train Epoch: 10 [60/74]	loss: 0.022036
# Train Epoch: 10 [70/74]	loss: 0.027058
# [10]Validation Loss: 0.5683,Accuracy: 88.8514%
# Train Epoch: 11 [0/74]	loss: 0.017119
# Train Epoch: 11 [10/74]	loss: 0.022789
# Train Epoch: 11 [20/74]	loss: 0.019754
# Train Epoch: 11 [30/74]	loss: 0.016166
# Train Epoch: 11 [40/74]	loss: 0.019634
# Train Epoch: 11 [50/74]	loss: 0.017027
# Train Epoch: 11 [60/74]	loss: 0.021906
# Train Epoch: 11 [70/74]	loss: 0.018184
# [11]Validation Loss: 0.5535,Accuracy: 89.1892%
# Train Epoch: 12 [0/74]	loss: 0.018705
# Train Epoch: 12 [10/74]	loss: 0.017291
# Train Epoch: 12 [20/74]	loss: 0.018575
# Train Epoch: 12 [30/74]	loss: 0.029392
# Train Epoch: 12 [40/74]	loss: 0.025961
# Train Epoch: 12 [50/74]	loss: 0.015300
# Train Epoch: 12 [60/74]	loss: 0.022071
# Train Epoch: 12 [70/74]	loss: 0.016863
# [12]Validation Loss: 0.5500,Accuracy: 90.2027%
# Train Epoch: 13 [0/74]	loss: 0.012916
# Train Epoch: 13 [10/74]	loss: 0.015303
# Train Epoch: 13 [20/74]	loss: 0.015099
# Train Epoch: 13 [30/74]	loss: 0.019491
# Train Epoch: 13 [40/74]	loss: 0.013873
# Train Epoch: 13 [50/74]	loss: 0.016074
# Train Epoch: 13 [60/74]	loss: 0.014996
# Train Epoch: 13 [70/74]	loss: 0.019130
# [13]Validation Loss: 0.5433,Accuracy: 90.2027%
# Train Epoch: 14 [0/74]	loss: 0.016804
# Train Epoch: 14 [10/74]	loss: 0.013541
# Train Epoch: 14 [20/74]	loss: 0.012063
# Train Epoch: 14 [30/74]	loss: 0.014094
# Train Epoch: 14 [40/74]	loss: 0.011153
# Train Epoch: 14 [50/74]	loss: 0.013998
# Train Epoch: 14 [60/74]	loss: 0.012739
# Train Epoch: 14 [70/74]	loss: 0.009879
# [14]Validation Loss: 0.5480,Accuracy: 89.8649%
# Train Epoch: 15 [0/74]	loss: 0.015180
# Train Epoch: 15 [10/74]	loss: 0.013840
# Train Epoch: 15 [20/74]	loss: 0.014438
# Train Epoch: 15 [30/74]	loss: 0.012642
# Train Epoch: 15 [40/74]	loss: 0.015971
# Train Epoch: 15 [50/74]	loss: 0.013650
# Train Epoch: 15 [60/74]	loss: 0.017205
# Train Epoch: 15 [70/74]	loss: 0.012280
# [15]Validation Loss: 0.5241,Accuracy: 90.5405%
# Train Epoch: 16 [0/74]	loss: 0.010326
# Train Epoch: 16 [10/74]	loss: 0.009882
# Train Epoch: 16 [20/74]	loss: 0.014911
# Train Epoch: 16 [30/74]	loss: 0.009571
# Train Epoch: 16 [40/74]	loss: 0.013387
# Train Epoch: 16 [50/74]	loss: 0.018514
# Train Epoch: 16 [60/74]	loss: 0.011595
# Train Epoch: 16 [70/74]	loss: 0.008885
# [16]Validation Loss: 0.5242,Accuracy: 88.8514%
# Train Epoch: 17 [0/74]	loss: 0.010907
# Train Epoch: 17 [10/74]	loss: 0.013822
# Train Epoch: 17 [20/74]	loss: 0.009389
# Train Epoch: 17 [30/74]	loss: 0.009516
# Train Epoch: 17 [40/74]	loss: 0.009798
# Train Epoch: 17 [50/74]	loss: 0.010511
# Train Epoch: 17 [60/74]	loss: 0.013906
# Train Epoch: 17 [70/74]	loss: 0.013938
# [17]Validation Loss: 0.5387,Accuracy: 89.8649%
# Train Epoch: 18 [0/74]	loss: 0.011649
# Train Epoch: 18 [10/74]	loss: 0.007265
# Train Epoch: 18 [20/74]	loss: 0.007729
# Train Epoch: 18 [30/74]	loss: 0.008691
# Train Epoch: 18 [40/74]	loss: 0.008383
# Train Epoch: 18 [50/74]	loss: 0.016467
# Train Epoch: 18 [60/74]	loss: 0.006864
# Train Epoch: 18 [70/74]	loss: 0.010279
# [18]Validation Loss: 0.5275,Accuracy: 89.5270%
# Train Epoch: 19 [0/74]	loss: 0.011212
# Train Epoch: 19 [10/74]	loss: 0.010117
# Train Epoch: 19 [20/74]	loss: 0.013473
# Train Epoch: 19 [30/74]	loss: 0.007558
# Train Epoch: 19 [40/74]	loss: 0.008842
# Train Epoch: 19 [50/74]	loss: 0.008750
# Train Epoch: 19 [60/74]	loss: 0.010185
# Train Epoch: 19 [70/74]	loss: 0.007163
# [19]Validation Loss: 0.5270,Accuracy: 89.8649%
# Train Epoch: 20 [0/74]	loss: 0.008142
# Train Epoch: 20 [10/74]	loss: 0.007219
# Train Epoch: 20 [20/74]	loss: 0.009202
# Train Epoch: 20 [30/74]	loss: 0.008710
# Train Epoch: 20 [40/74]	loss: 0.006954
# Train Epoch: 20 [50/74]	loss: 0.005581
# Train Epoch: 20 [60/74]	loss: 0.006690
# Train Epoch: 20 [70/74]	loss: 0.007224
# [20]Validation Loss: 0.5195,Accuracy: 89.8649%
# Train Epoch: 21 [0/74]	loss: 0.007461
# Train Epoch: 21 [10/74]	loss: 0.006956
# Train Epoch: 21 [20/74]	loss: 0.010826
# Train Epoch: 21 [30/74]	loss: 0.005434
# Train Epoch: 21 [40/74]	loss: 0.007833
# Train Epoch: 21 [50/74]	loss: 0.008415
# Train Epoch: 21 [60/74]	loss: 0.006111
# Train Epoch: 21 [70/74]	loss: 0.006542
# [21]Validation Loss: 0.5158,Accuracy: 89.5270%
# Train Epoch: 22 [0/74]	loss: 0.007557
# Train Epoch: 22 [10/74]	loss: 0.008120
# Train Epoch: 22 [20/74]	loss: 0.006094
# Train Epoch: 22 [30/74]	loss: 0.008389
# Train Epoch: 22 [40/74]	loss: 0.005959
# Train Epoch: 22 [50/74]	loss: 0.005662
# Train Epoch: 22 [60/74]	loss: 0.008808
# Train Epoch: 22 [70/74]	loss: 0.010270
# [22]Validation Loss: 0.5167,Accuracy: 90.2027%
# Train Epoch: 23 [0/74]	loss: 0.008769
# Train Epoch: 23 [10/74]	loss: 0.005055
# Train Epoch: 23 [20/74]	loss: 0.006944
# Train Epoch: 23 [30/74]	loss: 0.006983
# Train Epoch: 23 [40/74]	loss: 0.007911
# Train Epoch: 23 [50/74]	loss: 0.009752
# Train Epoch: 23 [60/74]	loss: 0.006872
# Train Epoch: 23 [70/74]	loss: 0.005233
# [23]Validation Loss: 0.5121,Accuracy: 89.8649%
# Train Epoch: 24 [0/74]	loss: 0.008541
# Train Epoch: 24 [10/74]	loss: 0.008658
# Train Epoch: 24 [20/74]	loss: 0.005193
# Train Epoch: 24 [30/74]	loss: 0.005966
# Train Epoch: 24 [40/74]	loss: 0.006313
# Train Epoch: 24 [50/74]	loss: 0.006453
# Train Epoch: 24 [60/74]	loss: 0.005596
# Train Epoch: 24 [70/74]	loss: 0.005136
# [24]Validation Loss: 0.5119,Accuracy: 89.8649%
# Train Epoch: 25 [0/74]	loss: 0.006870
# Train Epoch: 25 [10/74]	loss: 0.005450
# Train Epoch: 25 [20/74]	loss: 0.004335
# Train Epoch: 25 [30/74]	loss: 0.005302
# Train Epoch: 25 [40/74]	loss: 0.007431
# Train Epoch: 25 [50/74]	loss: 0.009917
# Train Epoch: 25 [60/74]	loss: 0.006055
# Train Epoch: 25 [70/74]	loss: 0.003371
# [25]Validation Loss: 0.5065,Accuracy: 90.8784%
# Train Epoch: 26 [0/74]	loss: 0.005757
# Train Epoch: 26 [10/74]	loss: 0.005917
# Train Epoch: 26 [20/74]	loss: 0.007839
# Train Epoch: 26 [30/74]	loss: 0.005462
# Train Epoch: 26 [40/74]	loss: 0.007352
# Train Epoch: 26 [50/74]	loss: 0.008493
# Train Epoch: 26 [60/74]	loss: 0.006987
# Train Epoch: 26 [70/74]	loss: 0.006516
# [26]Validation Loss: 0.5096,Accuracy: 89.8649%
# Train Epoch: 27 [0/74]	loss: 0.005863
# Train Epoch: 27 [10/74]	loss: 0.006182
# Train Epoch: 27 [20/74]	loss: 0.004561
# Train Epoch: 27 [30/74]	loss: 0.004445
# Train Epoch: 27 [40/74]	loss: 0.004625
# Train Epoch: 27 [50/74]	loss: 0.004872
# Train Epoch: 27 [60/74]	loss: 0.007525
# Train Epoch: 27 [70/74]	loss: 0.006420
# [27]Validation Loss: 0.5154,Accuracy: 89.5270%
# Train Epoch: 28 [0/74]	loss: 0.004564
# Train Epoch: 28 [10/74]	loss: 0.004145
# Train Epoch: 28 [20/74]	loss: 0.004436
# Train Epoch: 28 [30/74]	loss: 0.006474
# Train Epoch: 28 [40/74]	loss: 0.005663
# Train Epoch: 28 [50/74]	loss: 0.004569
# Train Epoch: 28 [60/74]	loss: 0.004616
# Train Epoch: 28 [70/74]	loss: 0.005504
# [28]Validation Loss: 0.5075,Accuracy: 89.5270%
# Train Epoch: 29 [0/74]	loss: 0.003260
# Train Epoch: 29 [10/74]	loss: 0.004259
# Train Epoch: 29 [20/74]	loss: 0.005895
# Train Epoch: 29 [30/74]	loss: 0.006120
# Train Epoch: 29 [40/74]	loss: 0.003729
# Train Epoch: 29 [50/74]	loss: 0.006192
# Train Epoch: 29 [60/74]	loss: 0.003691
# Train Epoch: 29 [70/74]	loss: 0.004494
# [29]Validation Loss: 0.5111,Accuracy: 89.8649%
# [FINAL] Test Loss: 0.5663,Accuracy: 87.9195%
# Best Accuracy:  90.87837837837837
# Elasped Time: 0h, 25m, 55s
# time: 0h, 25m, 55s
