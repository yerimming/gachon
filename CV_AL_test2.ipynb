# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_AL_test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# lr 0.1에서 0.001로 수정,
# weight_decay 0.001로 설정.(기본값 0.0)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image
#내가 추가
import re

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = re.sub(r'\([^)]*\)', '', label)
    label = int(label)
    return (img, label)

# %%
### Data Preprocessing ###

'''
# 데이터 정규화 추가
# 정규화 변환 정의
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
'''
transforms_train = transforms.Compose([transforms.Resize((448,448)),
                                       transforms.ToTensor()])
transforms_valtest = transforms.Compose([transforms.Resize((448,448)),
                                         transforms.ToTensor()])

BATCH_SIZE = 32
train_set = CUB2011(mode='train',
                    transform=transforms_train)
# transforms_train을 transforms_valtest로 변경
val_set = CUB2011(mode='valid',
                  transform=transforms_valtest)
test_set = CUB2011(mode='test',
                  transform=transforms_valtest)

print('Num of each dataset: ',len(train_set),len(val_set),len(test_set))

train_loader = DataLoader(train_set,batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")

### Model / Optimizer ###
EPOCH = 30
lr = 0.001

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(),lr=lr, weight_decay=0.001)

print("Created a learning model and optimizer")
# Out:
# Num of each dataset:  2362 296 298
# Loaded dataloader
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    # loss func을 어떤 것을 사용할 것인지?
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/74]	loss: 4.042320
# Train Epoch: 0 [10/74]	loss: 3.655072
# Train Epoch: 0 [20/74]	loss: 3.463990
# Train Epoch: 0 [30/74]	loss: 2.666629
# Train Epoch: 0 [40/74]	loss: 3.034514
# Train Epoch: 0 [50/74]	loss: 2.378748
# Train Epoch: 0 [60/74]	loss: 2.540417
# Train Epoch: 0 [70/74]	loss: 2.050491
# [0]Validation Loss: 2.1758,Accuracy: 46.6216%
# Train Epoch: 1 [0/74]	loss: 1.652216
# Train Epoch: 1 [10/74]	loss: 1.358386
# Train Epoch: 1 [20/74]	loss: 1.424488
# Train Epoch: 1 [30/74]	loss: 1.344020
# Train Epoch: 1 [40/74]	loss: 0.815002
# Train Epoch: 1 [50/74]	loss: 1.093242
# Train Epoch: 1 [60/74]	loss: 1.377661
# Train Epoch: 1 [70/74]	loss: 1.098092
# [1]Validation Loss: 1.9387,Accuracy: 48.6486%
# Train Epoch: 2 [0/74]	loss: 0.893850
# Train Epoch: 2 [10/74]	loss: 0.639493
# Train Epoch: 2 [20/74]	loss: 0.736705
# Train Epoch: 2 [30/74]	loss: 0.607774
# Train Epoch: 2 [40/74]	loss: 0.759367
# Train Epoch: 2 [50/74]	loss: 1.051470
# Train Epoch: 2 [60/74]	loss: 0.662717
# Train Epoch: 2 [70/74]	loss: 0.698937
# [2]Validation Loss: 1.9716,Accuracy: 43.9189%
# Train Epoch: 3 [0/74]	loss: 0.672112
# Train Epoch: 3 [10/74]	loss: 0.601282
# Train Epoch: 3 [20/74]	loss: 0.618045
# Train Epoch: 3 [30/74]	loss: 0.683123
# Train Epoch: 3 [40/74]	loss: 0.573952
# Train Epoch: 3 [50/74]	loss: 0.578389
# Train Epoch: 3 [60/74]	loss: 0.454367
# Train Epoch: 3 [70/74]	loss: 0.453348
# [3]Validation Loss: 1.5493,Accuracy: 59.4595%
# Train Epoch: 4 [0/74]	loss: 0.402202
# Train Epoch: 4 [10/74]	loss: 0.565201
# Train Epoch: 4 [20/74]	loss: 0.443106
# Train Epoch: 4 [30/74]	loss: 0.635076
# Train Epoch: 4 [40/74]	loss: 0.358708
# Train Epoch: 4 [50/74]	loss: 0.384999
# Train Epoch: 4 [60/74]	loss: 0.474648
# Train Epoch: 4 [70/74]	loss: 0.636757
# [4]Validation Loss: 1.3321,Accuracy: 65.8784%
# Train Epoch: 5 [0/74]	loss: 0.244264
# Train Epoch: 5 [10/74]	loss: 0.351398
# Train Epoch: 5 [20/74]	loss: 0.274291
# Train Epoch: 5 [30/74]	loss: 0.669136
# Train Epoch: 5 [40/74]	loss: 0.244016
# Train Epoch: 5 [50/74]	loss: 0.636483
# Train Epoch: 5 [60/74]	loss: 0.294863
# Train Epoch: 5 [70/74]	loss: 0.539571
# [5]Validation Loss: 1.3395,Accuracy: 62.1622%
# Train Epoch: 6 [0/74]	loss: 0.197949
# Train Epoch: 6 [10/74]	loss: 0.399310
# Train Epoch: 6 [20/74]	loss: 0.322546
# Train Epoch: 6 [30/74]	loss: 0.273135
# Train Epoch: 6 [40/74]	loss: 0.323205
# Train Epoch: 6 [50/74]	loss: 0.196613
# Train Epoch: 6 [60/74]	loss: 0.478543
# Train Epoch: 6 [70/74]	loss: 0.289348
# [6]Validation Loss: 2.1045,Accuracy: 48.3108%
# Train Epoch: 7 [0/74]	loss: 0.294698
# Train Epoch: 7 [10/74]	loss: 0.431599
# Train Epoch: 7 [20/74]	loss: 0.443587
# Train Epoch: 7 [30/74]	loss: 0.422829
# Train Epoch: 7 [40/74]	loss: 0.349445
# Train Epoch: 7 [50/74]	loss: 0.332252
# Train Epoch: 7 [60/74]	loss: 0.355871
# Train Epoch: 7 [70/74]	loss: 0.515618
# [7]Validation Loss: 1.5101,Accuracy: 58.1081%
# Train Epoch: 8 [0/74]	loss: 0.231872
# Train Epoch: 8 [10/74]	loss: 0.228241
# Train Epoch: 8 [20/74]	loss: 0.131533
# Train Epoch: 8 [30/74]	loss: 0.080698
# Train Epoch: 8 [40/74]	loss: 0.199373
# Train Epoch: 8 [50/74]	loss: 0.163513
# Train Epoch: 8 [60/74]	loss: 0.301700
# Train Epoch: 8 [70/74]	loss: 0.433228
# [8]Validation Loss: 1.6382,Accuracy: 54.0541%
# Train Epoch: 9 [0/74]	loss: 0.179862
# Train Epoch: 9 [10/74]	loss: 0.211904
# Train Epoch: 9 [20/74]	loss: 0.247492
# Train Epoch: 9 [30/74]	loss: 0.195959
# Train Epoch: 9 [40/74]	loss: 0.107866
# Train Epoch: 9 [50/74]	loss: 0.132197
# Train Epoch: 9 [60/74]	loss: 0.155841
# Train Epoch: 9 [70/74]	loss: 0.241765
# [9]Validation Loss: 3.2044,Accuracy: 41.5541%
# Train Epoch: 10 [0/74]	loss: 0.154409
# Train Epoch: 10 [10/74]	loss: 0.249504
# Train Epoch: 10 [20/74]	loss: 0.308749
# Train Epoch: 10 [30/74]	loss: 0.263818
# Train Epoch: 10 [40/74]	loss: 0.123079
# Train Epoch: 10 [50/74]	loss: 0.157517
# Train Epoch: 10 [60/74]	loss: 0.173513
# Train Epoch: 10 [70/74]	loss: 0.141824
# [10]Validation Loss: 1.0818,Accuracy: 72.2973%
# Train Epoch: 11 [0/74]	loss: 0.109518
# Train Epoch: 11 [10/74]	loss: 0.075785
# Train Epoch: 11 [20/74]	loss: 0.219422
# Train Epoch: 11 [30/74]	loss: 0.083506
# Train Epoch: 11 [40/74]	loss: 0.183230
# Train Epoch: 11 [50/74]	loss: 0.157339
# Train Epoch: 11 [60/74]	loss: 0.183599
# Train Epoch: 11 [70/74]	loss: 0.306152
# [11]Validation Loss: 1.8823,Accuracy: 51.3514%
# Train Epoch: 12 [0/74]	loss: 0.209673
# Train Epoch: 12 [10/74]	loss: 0.293185
# Train Epoch: 12 [20/74]	loss: 0.170747
# Train Epoch: 12 [30/74]	loss: 0.193219
# Train Epoch: 12 [40/74]	loss: 0.317985
# Train Epoch: 12 [50/74]	loss: 0.310179
# Train Epoch: 12 [60/74]	loss: 0.354095
# Train Epoch: 12 [70/74]	loss: 0.172002
# [12]Validation Loss: 1.6645,Accuracy: 59.4595%
# Train Epoch: 13 [0/74]	loss: 0.202290
# Train Epoch: 13 [10/74]	loss: 0.278506
# Train Epoch: 13 [20/74]	loss: 0.147647
# Train Epoch: 13 [30/74]	loss: 0.271566
# Train Epoch: 13 [40/74]	loss: 0.373205
# Train Epoch: 13 [50/74]	loss: 0.107284
# Train Epoch: 13 [60/74]	loss: 0.205176
# Train Epoch: 13 [70/74]	loss: 0.103100
# [13]Validation Loss: 1.5179,Accuracy: 58.1081%
# Train Epoch: 14 [0/74]	loss: 0.080636
# Train Epoch: 14 [10/74]	loss: 0.160452
# Train Epoch: 14 [20/74]	loss: 0.069375
# Train Epoch: 14 [30/74]	loss: 0.179106
# Train Epoch: 14 [40/74]	loss: 0.113394
# Train Epoch: 14 [50/74]	loss: 0.206067
# Train Epoch: 14 [60/74]	loss: 0.164064
# Train Epoch: 14 [70/74]	loss: 0.177552
# [14]Validation Loss: 1.6713,Accuracy: 59.4595%
# Train Epoch: 15 [0/74]	loss: 0.109143
# Train Epoch: 15 [10/74]	loss: 0.055092
# Train Epoch: 15 [20/74]	loss: 0.202518
# Train Epoch: 15 [30/74]	loss: 0.157426
# Train Epoch: 15 [40/74]	loss: 0.221273
# Train Epoch: 15 [50/74]	loss: 0.125994
# Train Epoch: 15 [60/74]	loss: 0.148516
# Train Epoch: 15 [70/74]	loss: 0.050590
# [15]Validation Loss: 1.2404,Accuracy: 69.9324%
# Train Epoch: 16 [0/74]	loss: 0.109530
# Train Epoch: 16 [10/74]	loss: 0.049823
# Train Epoch: 16 [20/74]	loss: 0.147775
# Train Epoch: 16 [30/74]	loss: 0.064312
# Train Epoch: 16 [40/74]	loss: 0.037290
# Train Epoch: 16 [50/74]	loss: 0.065903
# Train Epoch: 16 [60/74]	loss: 0.081886
# Train Epoch: 16 [70/74]	loss: 0.092404
# [16]Validation Loss: 1.2934,Accuracy: 66.5541%
# Train Epoch: 17 [0/74]	loss: 0.061842
# Train Epoch: 17 [10/74]	loss: 0.194304
# Train Epoch: 17 [20/74]	loss: 0.089279
# Train Epoch: 17 [30/74]	loss: 0.169867
# Train Epoch: 17 [40/74]	loss: 0.064535
# Train Epoch: 17 [50/74]	loss: 0.161122
# Train Epoch: 17 [60/74]	loss: 0.312353
# Train Epoch: 17 [70/74]	loss: 0.256828
# [17]Validation Loss: 1.8344,Accuracy: 54.3919%
# Train Epoch: 18 [0/74]	loss: 0.182990
# Train Epoch: 18 [10/74]	loss: 0.151631
# Train Epoch: 18 [20/74]	loss: 0.136305
# Train Epoch: 18 [30/74]	loss: 0.096476
# Train Epoch: 18 [40/74]	loss: 0.218536
# Train Epoch: 18 [50/74]	loss: 0.123412
# Train Epoch: 18 [60/74]	loss: 0.136184
# Train Epoch: 18 [70/74]	loss: 0.296786
# [18]Validation Loss: 2.4546,Accuracy: 49.6622%
# Train Epoch: 19 [0/74]	loss: 0.115682
# Train Epoch: 19 [10/74]	loss: 0.161955
# Train Epoch: 19 [20/74]	loss: 0.297014
# Train Epoch: 19 [30/74]	loss: 0.222350
# Train Epoch: 19 [40/74]	loss: 0.207668
# Train Epoch: 19 [50/74]	loss: 0.220934
# Train Epoch: 19 [60/74]	loss: 0.221470
# Train Epoch: 19 [70/74]	loss: 0.454556
# [19]Validation Loss: 1.9357,Accuracy: 53.7162%
# Train Epoch: 20 [0/74]	loss: 0.162075
# Train Epoch: 20 [10/74]	loss: 0.413275
# Train Epoch: 20 [20/74]	loss: 0.433516
# Train Epoch: 20 [30/74]	loss: 0.188015
# Train Epoch: 20 [40/74]	loss: 0.241352
# Train Epoch: 20 [50/74]	loss: 0.136038
# Train Epoch: 20 [60/74]	loss: 0.394716
# Train Epoch: 20 [70/74]	loss: 0.194274
# [20]Validation Loss: 1.5430,Accuracy: 61.1486%
# Train Epoch: 21 [0/74]	loss: 0.233593
# Train Epoch: 21 [10/74]	loss: 0.179535
# Train Epoch: 21 [20/74]	loss: 0.142763
# Train Epoch: 21 [30/74]	loss: 0.206630
# Train Epoch: 21 [40/74]	loss: 0.270148
# Train Epoch: 21 [50/74]	loss: 0.177241
# Train Epoch: 21 [60/74]	loss: 0.094348
# Train Epoch: 21 [70/74]	loss: 0.229367
# [21]Validation Loss: 1.4286,Accuracy: 64.1892%
# Train Epoch: 22 [0/74]	loss: 0.238290
# Train Epoch: 22 [10/74]	loss: 0.121307
# Train Epoch: 22 [20/74]	loss: 0.137618
# Train Epoch: 22 [30/74]	loss: 0.168566
# Train Epoch: 22 [40/74]	loss: 0.112657
# Train Epoch: 22 [50/74]	loss: 0.119361
# Train Epoch: 22 [60/74]	loss: 0.074689
# Train Epoch: 22 [70/74]	loss: 0.196966
# [22]Validation Loss: 1.2089,Accuracy: 66.5541%
# Train Epoch: 23 [0/74]	loss: 0.073972
# Train Epoch: 23 [10/74]	loss: 0.047077
# Train Epoch: 23 [20/74]	loss: 0.101449
# Train Epoch: 23 [30/74]	loss: 0.080258
# Train Epoch: 23 [40/74]	loss: 0.023943
# Train Epoch: 23 [50/74]	loss: 0.059197
# Train Epoch: 23 [60/74]	loss: 0.152486
# Train Epoch: 23 [70/74]	loss: 0.067511
# [23]Validation Loss: 1.2313,Accuracy: 68.5811%
# Train Epoch: 24 [0/74]	loss: 0.061475
# Train Epoch: 24 [10/74]	loss: 0.041060
# Train Epoch: 24 [20/74]	loss: 0.022157
# Train Epoch: 24 [30/74]	loss: 0.045273
# Train Epoch: 24 [40/74]	loss: 0.040409
# Train Epoch: 24 [50/74]	loss: 0.026523
# Train Epoch: 24 [60/74]	loss: 0.043638
# Train Epoch: 24 [70/74]	loss: 0.038453
# [24]Validation Loss: 1.0507,Accuracy: 71.2838%
# Train Epoch: 25 [0/74]	loss: 0.041412
# Train Epoch: 25 [10/74]	loss: 0.032854
# Train Epoch: 25 [20/74]	loss: 0.051587
# Train Epoch: 25 [30/74]	loss: 0.064752
# Train Epoch: 25 [40/74]	loss: 0.037795
# Train Epoch: 25 [50/74]	loss: 0.135285
# Train Epoch: 25 [60/74]	loss: 0.085508
# Train Epoch: 25 [70/74]	loss: 0.067832
# [25]Validation Loss: 1.4163,Accuracy: 63.8514%
# Train Epoch: 26 [0/74]	loss: 0.062899
# Train Epoch: 26 [10/74]	loss: 0.056945
# Train Epoch: 26 [20/74]	loss: 0.041533
# Train Epoch: 26 [30/74]	loss: 0.026406
# Train Epoch: 26 [40/74]	loss: 0.019682
# Train Epoch: 26 [50/74]	loss: 0.040288
# Train Epoch: 26 [60/74]	loss: 0.034648
# Train Epoch: 26 [70/74]	loss: 0.088852
# [26]Validation Loss: 1.3509,Accuracy: 66.8919%
# Train Epoch: 27 [0/74]	loss: 0.085608
# Train Epoch: 27 [10/74]	loss: 0.074993
# Train Epoch: 27 [20/74]	loss: 0.077445
# Train Epoch: 27 [30/74]	loss: 0.139649
# Train Epoch: 27 [40/74]	loss: 0.207521
# Train Epoch: 27 [50/74]	loss: 0.344926
# Train Epoch: 27 [60/74]	loss: 0.475376
# Train Epoch: 27 [70/74]	loss: 0.516050
# [27]Validation Loss: 4.0739,Accuracy: 27.3649%
# Train Epoch: 28 [0/74]	loss: 0.394156
# Train Epoch: 28 [10/74]	loss: 0.303648
# Train Epoch: 28 [20/74]	loss: 0.572429
# Train Epoch: 28 [30/74]	loss: 0.364331
# Train Epoch: 28 [40/74]	loss: 0.371869
# Train Epoch: 28 [50/74]	loss: 0.545960
# Train Epoch: 28 [60/74]	loss: 0.270698
# Train Epoch: 28 [70/74]	loss: 0.266941
# [28]Validation Loss: 1.7814,Accuracy: 55.7432%
# Train Epoch: 29 [0/74]	loss: 0.373567
# Train Epoch: 29 [10/74]	loss: 0.274402
# Train Epoch: 29 [20/74]	loss: 0.412592
# Train Epoch: 29 [30/74]	loss: 0.509810
# Train Epoch: 29 [40/74]	loss: 0.217065
# Train Epoch: 29 [50/74]	loss: 0.288483
# Train Epoch: 29 [60/74]	loss: 0.172355
# Train Epoch: 29 [70/74]	loss: 0.242452
# [29]Validation Loss: 1.4920,Accuracy: 63.1757%
# [FINAL] Test Loss: 1.5503,Accuracy: 59.3960%
# Best Accuracy:  72.29729729729729
# Elasped Time: 0h, 16m, 53s
# time: 0h, 16m, 53s
