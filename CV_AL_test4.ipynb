# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_AL_test4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# lr 0.1에서 0.0001로 수정, normalize -> 이전보다 2% 정도 감소 -> normalize 안 해야겠다.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image
#내가 추가
import re

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = re.sub(r'\([^)]*\)', '', label)
    label = int(label)
    return (img, label)

# %%
### Data Preprocessing ###


# 데이터 정규화 추가
# 정규화 변환 정의
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

transforms_train = transforms.Compose([transforms.Resize((448,448)),
                                       transforms.ToTensor(), normalize])
transforms_valtest = transforms.Compose([transforms.Resize((448,448)),
                                         transforms.ToTensor(), normalize])

BATCH_SIZE = 32
train_set = CUB2011(mode='train',
                    transform=transforms_train)
# transforms_train을 transforms_valtest로 변경
val_set = CUB2011(mode='valid',
                  transform=transforms_valtest)
test_set = CUB2011(mode='test',
                  transform=transforms_valtest)

print('Num of each dataset: ',len(train_set),len(val_set),len(test_set))

train_loader = DataLoader(train_set,batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")

### Model / Optimizer ###
EPOCH = 30
lr = 0.0001

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(),lr=lr)

print("Created a learning model and optimizer")
# Out:
# Num of each dataset:  2362 296 298
# Loaded dataloader
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    # loss func을 어떤 것을 사용할 것인지?
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/74]	loss: 4.080179
# Train Epoch: 0 [10/74]	loss: 3.589410
# Train Epoch: 0 [20/74]	loss: 3.599243
# Train Epoch: 0 [30/74]	loss: 3.299802
# Train Epoch: 0 [40/74]	loss: 3.008298
# Train Epoch: 0 [50/74]	loss: 2.858878
# Train Epoch: 0 [60/74]	loss: 2.703613
# Train Epoch: 0 [70/74]	loss: 2.284138
# [0]Validation Loss: 2.2181,Accuracy: 58.1081%
# Train Epoch: 1 [0/74]	loss: 2.035335
# Train Epoch: 1 [10/74]	loss: 1.808260
# Train Epoch: 1 [20/74]	loss: 1.658718
# Train Epoch: 1 [30/74]	loss: 1.653066
# Train Epoch: 1 [40/74]	loss: 1.554013
# Train Epoch: 1 [50/74]	loss: 1.572207
# Train Epoch: 1 [60/74]	loss: 1.651436
# Train Epoch: 1 [70/74]	loss: 1.258947
# [1]Validation Loss: 1.3915,Accuracy: 79.7297%
# Train Epoch: 2 [0/74]	loss: 0.945642
# Train Epoch: 2 [10/74]	loss: 0.889204
# Train Epoch: 2 [20/74]	loss: 0.904316
# Train Epoch: 2 [30/74]	loss: 0.867574
# Train Epoch: 2 [40/74]	loss: 0.788080
# Train Epoch: 2 [50/74]	loss: 0.825523
# Train Epoch: 2 [60/74]	loss: 0.786190
# Train Epoch: 2 [70/74]	loss: 0.641644
# [2]Validation Loss: 1.1133,Accuracy: 82.4324%
# Train Epoch: 3 [0/74]	loss: 0.544441
# Train Epoch: 3 [10/74]	loss: 0.490844
# Train Epoch: 3 [20/74]	loss: 0.528249
# Train Epoch: 3 [30/74]	loss: 0.428235
# Train Epoch: 3 [40/74]	loss: 0.490850
# Train Epoch: 3 [50/74]	loss: 0.419088
# Train Epoch: 3 [60/74]	loss: 0.301364
# Train Epoch: 3 [70/74]	loss: 0.345353
# [3]Validation Loss: 0.8284,Accuracy: 85.8108%
# Train Epoch: 4 [0/74]	loss: 0.276569
# Train Epoch: 4 [10/74]	loss: 0.250786
# Train Epoch: 4 [20/74]	loss: 0.256477
# Train Epoch: 4 [30/74]	loss: 0.177691
# Train Epoch: 4 [40/74]	loss: 0.179914
# Train Epoch: 4 [50/74]	loss: 0.256654
# Train Epoch: 4 [60/74]	loss: 0.196536
# Train Epoch: 4 [70/74]	loss: 0.202056
# [4]Validation Loss: 0.7496,Accuracy: 87.1622%
# Train Epoch: 5 [0/74]	loss: 0.116130
# Train Epoch: 5 [10/74]	loss: 0.110608
# Train Epoch: 5 [20/74]	loss: 0.110117
# Train Epoch: 5 [30/74]	loss: 0.104171
# Train Epoch: 5 [40/74]	loss: 0.155588
# Train Epoch: 5 [50/74]	loss: 0.109102
# Train Epoch: 5 [60/74]	loss: 0.114859
# Train Epoch: 5 [70/74]	loss: 0.112099
# [5]Validation Loss: 0.7142,Accuracy: 88.1757%
# Train Epoch: 6 [0/74]	loss: 0.066531
# Train Epoch: 6 [10/74]	loss: 0.074193
# Train Epoch: 6 [20/74]	loss: 0.071001
# Train Epoch: 6 [30/74]	loss: 0.090684
# Train Epoch: 6 [40/74]	loss: 0.068857
# Train Epoch: 6 [50/74]	loss: 0.073125
# Train Epoch: 6 [60/74]	loss: 0.064853
# Train Epoch: 6 [70/74]	loss: 0.056692
# [6]Validation Loss: 0.6626,Accuracy: 87.5000%
# Train Epoch: 7 [0/74]	loss: 0.074960
# Train Epoch: 7 [10/74]	loss: 0.043531
# Train Epoch: 7 [20/74]	loss: 0.076456
# Train Epoch: 7 [30/74]	loss: 0.050609
# Train Epoch: 7 [40/74]	loss: 0.049921
# Train Epoch: 7 [50/74]	loss: 0.041249
# Train Epoch: 7 [60/74]	loss: 0.049092
# Train Epoch: 7 [70/74]	loss: 0.032939
# [7]Validation Loss: 0.6381,Accuracy: 86.8243%
# Train Epoch: 8 [0/74]	loss: 0.034034
# Train Epoch: 8 [10/74]	loss: 0.068309
# Train Epoch: 8 [20/74]	loss: 0.046075
# Train Epoch: 8 [30/74]	loss: 0.055347
# Train Epoch: 8 [40/74]	loss: 0.026345
# Train Epoch: 8 [50/74]	loss: 0.036093
# Train Epoch: 8 [60/74]	loss: 0.035220
# Train Epoch: 8 [70/74]	loss: 0.050473
# [8]Validation Loss: 0.6167,Accuracy: 87.8378%
# Train Epoch: 9 [0/74]	loss: 0.032873
# Train Epoch: 9 [10/74]	loss: 0.028645
# Train Epoch: 9 [20/74]	loss: 0.036599
# Train Epoch: 9 [30/74]	loss: 0.039617
# Train Epoch: 9 [40/74]	loss: 0.031012
# Train Epoch: 9 [50/74]	loss: 0.031252
# Train Epoch: 9 [60/74]	loss: 0.034459
# Train Epoch: 9 [70/74]	loss: 0.024905
# [9]Validation Loss: 0.6078,Accuracy: 87.5000%
# Train Epoch: 10 [0/74]	loss: 0.023780
# Train Epoch: 10 [10/74]	loss: 0.024474
# Train Epoch: 10 [20/74]	loss: 0.025381
# Train Epoch: 10 [30/74]	loss: 0.022692
# Train Epoch: 10 [40/74]	loss: 0.023236
# Train Epoch: 10 [50/74]	loss: 0.024663
# Train Epoch: 10 [60/74]	loss: 0.025632
# Train Epoch: 10 [70/74]	loss: 0.022083
# [10]Validation Loss: 0.6002,Accuracy: 86.4865%
# Train Epoch: 11 [0/74]	loss: 0.017343
# Train Epoch: 11 [10/74]	loss: 0.016907
# Train Epoch: 11 [20/74]	loss: 0.014848
# Train Epoch: 11 [30/74]	loss: 0.016319
# Train Epoch: 11 [40/74]	loss: 0.023457
# Train Epoch: 11 [50/74]	loss: 0.015860
# Train Epoch: 11 [60/74]	loss: 0.017675
# Train Epoch: 11 [70/74]	loss: 0.022786
# [11]Validation Loss: 0.5841,Accuracy: 86.4865%
# Train Epoch: 12 [0/74]	loss: 0.019953
# Train Epoch: 12 [10/74]	loss: 0.022886
# Train Epoch: 12 [20/74]	loss: 0.016422
# Train Epoch: 12 [30/74]	loss: 0.018121
# Train Epoch: 12 [40/74]	loss: 0.020904
# Train Epoch: 12 [50/74]	loss: 0.014438
# Train Epoch: 12 [60/74]	loss: 0.014920
# Train Epoch: 12 [70/74]	loss: 0.016818
# [12]Validation Loss: 0.5864,Accuracy: 87.1622%
# Train Epoch: 13 [0/74]	loss: 0.019908
# Train Epoch: 13 [10/74]	loss: 0.012782
# Train Epoch: 13 [20/74]	loss: 0.017136
# Train Epoch: 13 [30/74]	loss: 0.011453
# Train Epoch: 13 [40/74]	loss: 0.012872
# Train Epoch: 13 [50/74]	loss: 0.010537
# Train Epoch: 13 [60/74]	loss: 0.017209
# Train Epoch: 13 [70/74]	loss: 0.011470
# [13]Validation Loss: 0.5682,Accuracy: 87.5000%
# Train Epoch: 14 [0/74]	loss: 0.014272
# Train Epoch: 14 [10/74]	loss: 0.018646
# Train Epoch: 14 [20/74]	loss: 0.011380
# Train Epoch: 14 [30/74]	loss: 0.013225
# Train Epoch: 14 [40/74]	loss: 0.012337
# Train Epoch: 14 [50/74]	loss: 0.011075
# Train Epoch: 14 [60/74]	loss: 0.012706
# Train Epoch: 14 [70/74]	loss: 0.010584
# [14]Validation Loss: 0.5869,Accuracy: 87.1622%
# Train Epoch: 15 [0/74]	loss: 0.010493
# Train Epoch: 15 [10/74]	loss: 0.008554
# Train Epoch: 15 [20/74]	loss: 0.014380
# Train Epoch: 15 [30/74]	loss: 0.012661
# Train Epoch: 15 [40/74]	loss: 0.008937
# Train Epoch: 15 [50/74]	loss: 0.009431
# Train Epoch: 15 [60/74]	loss: 0.010312
# Train Epoch: 15 [70/74]	loss: 0.011405
# [15]Validation Loss: 0.5792,Accuracy: 87.8378%
# Train Epoch: 16 [0/74]	loss: 0.013031
# Train Epoch: 16 [10/74]	loss: 0.006877
# Train Epoch: 16 [20/74]	loss: 0.011510
# Train Epoch: 16 [30/74]	loss: 0.009450
# Train Epoch: 16 [40/74]	loss: 0.011835
# Train Epoch: 16 [50/74]	loss: 0.007655
# Train Epoch: 16 [60/74]	loss: 0.011385
# Train Epoch: 16 [70/74]	loss: 0.007035
# [16]Validation Loss: 0.5763,Accuracy: 87.5000%
# Train Epoch: 17 [0/74]	loss: 0.010922
# Train Epoch: 17 [10/74]	loss: 0.010101
# Train Epoch: 17 [20/74]	loss: 0.009933
# Train Epoch: 17 [30/74]	loss: 0.010648
# Train Epoch: 17 [40/74]	loss: 0.008556
# Train Epoch: 17 [50/74]	loss: 0.007012
# Train Epoch: 17 [60/74]	loss: 0.013699
# Train Epoch: 17 [70/74]	loss: 0.009461
# [17]Validation Loss: 0.5646,Accuracy: 87.1622%
# Train Epoch: 18 [0/74]	loss: 0.006103
# Train Epoch: 18 [10/74]	loss: 0.007068
# Train Epoch: 18 [20/74]	loss: 0.009543
# Train Epoch: 18 [30/74]	loss: 0.007827
# Train Epoch: 18 [40/74]	loss: 0.010156
# Train Epoch: 18 [50/74]	loss: 0.006332
# Train Epoch: 18 [60/74]	loss: 0.009206
# Train Epoch: 18 [70/74]	loss: 0.007629
# [18]Validation Loss: 0.5606,Accuracy: 87.1622%
# Train Epoch: 19 [0/74]	loss: 0.008090
# Train Epoch: 19 [10/74]	loss: 0.010361
# Train Epoch: 19 [20/74]	loss: 0.006892
# Train Epoch: 19 [30/74]	loss: 0.007658
# Train Epoch: 19 [40/74]	loss: 0.006590
# Train Epoch: 19 [50/74]	loss: 0.006035
# Train Epoch: 19 [60/74]	loss: 0.005268
# Train Epoch: 19 [70/74]	loss: 0.006983
# [19]Validation Loss: 0.5645,Accuracy: 86.1486%
# Train Epoch: 20 [0/74]	loss: 0.009195
# Train Epoch: 20 [10/74]	loss: 0.006768
# Train Epoch: 20 [20/74]	loss: 0.006370
# Train Epoch: 20 [30/74]	loss: 0.004121
# Train Epoch: 20 [40/74]	loss: 0.006581
# Train Epoch: 20 [50/74]	loss: 0.004801
# Train Epoch: 20 [60/74]	loss: 0.011404
# Train Epoch: 20 [70/74]	loss: 0.004976
# [20]Validation Loss: 0.5671,Accuracy: 87.8378%
# Train Epoch: 21 [0/74]	loss: 0.004393
# Train Epoch: 21 [10/74]	loss: 0.004496
# Train Epoch: 21 [20/74]	loss: 0.003991
# Train Epoch: 21 [30/74]	loss: 0.005773
# Train Epoch: 21 [40/74]	loss: 0.006081
# Train Epoch: 21 [50/74]	loss: 0.006577
# Train Epoch: 21 [60/74]	loss: 0.004948
# Train Epoch: 21 [70/74]	loss: 0.005776
# [21]Validation Loss: 0.5624,Accuracy: 87.5000%
# Train Epoch: 22 [0/74]	loss: 0.005824
# Train Epoch: 22 [10/74]	loss: 0.003576
# Train Epoch: 22 [20/74]	loss: 0.006641
# Train Epoch: 22 [30/74]	loss: 0.005372
# Train Epoch: 22 [40/74]	loss: 0.004771
# Train Epoch: 22 [50/74]	loss: 0.005492
# Train Epoch: 22 [60/74]	loss: 0.004117
# Train Epoch: 22 [70/74]	loss: 0.011106
# [22]Validation Loss: 0.5553,Accuracy: 87.5000%
# Train Epoch: 23 [0/74]	loss: 0.005381
# Train Epoch: 23 [10/74]	loss: 0.006557
# Train Epoch: 23 [20/74]	loss: 0.004561
# Train Epoch: 23 [30/74]	loss: 0.006106
# Train Epoch: 23 [40/74]	loss: 0.004689
# Train Epoch: 23 [50/74]	loss: 0.004151
# Train Epoch: 23 [60/74]	loss: 0.006223
# Train Epoch: 23 [70/74]	loss: 0.004127
# [23]Validation Loss: 0.5507,Accuracy: 87.1622%
# Train Epoch: 24 [0/74]	loss: 0.004555
# Train Epoch: 24 [10/74]	loss: 0.004448
# Train Epoch: 24 [20/74]	loss: 0.003636
# Train Epoch: 24 [30/74]	loss: 0.004014
# Train Epoch: 24 [40/74]	loss: 0.003857
# Train Epoch: 24 [50/74]	loss: 0.003800
# Train Epoch: 24 [60/74]	loss: 0.004456
# Train Epoch: 24 [70/74]	loss: 0.002556
# [24]Validation Loss: 0.5544,Accuracy: 86.4865%
# Train Epoch: 25 [0/74]	loss: 0.004640
# Train Epoch: 25 [10/74]	loss: 0.004037
# Train Epoch: 25 [20/74]	loss: 0.002994
# Train Epoch: 25 [30/74]	loss: 0.004537
# Train Epoch: 25 [40/74]	loss: 0.005004
# Train Epoch: 25 [50/74]	loss: 0.006632
# Train Epoch: 25 [60/74]	loss: 0.003292
# Train Epoch: 25 [70/74]	loss: 0.002525
# [25]Validation Loss: 0.5473,Accuracy: 86.8243%
# Train Epoch: 26 [0/74]	loss: 0.004125
# Train Epoch: 26 [10/74]	loss: 0.004397
# Train Epoch: 26 [20/74]	loss: 0.003828
# Train Epoch: 26 [30/74]	loss: 0.003155
# Train Epoch: 26 [40/74]	loss: 0.007940
# Train Epoch: 26 [50/74]	loss: 0.003073
# Train Epoch: 26 [60/74]	loss: 0.003728
# Train Epoch: 26 [70/74]	loss: 0.003745
# [26]Validation Loss: 0.5480,Accuracy: 88.1757%
# Train Epoch: 27 [0/74]	loss: 0.004309
# Train Epoch: 27 [10/74]	loss: 0.003462
# Train Epoch: 27 [20/74]	loss: 0.003903
# Train Epoch: 27 [30/74]	loss: 0.003701
# Train Epoch: 27 [40/74]	loss: 0.004088
# Train Epoch: 27 [50/74]	loss: 0.003744
# Train Epoch: 27 [60/74]	loss: 0.003605
# Train Epoch: 27 [70/74]	loss: 0.003940
# [27]Validation Loss: 0.5461,Accuracy: 87.5000%
# Train Epoch: 28 [0/74]	loss: 0.003495
# Train Epoch: 28 [10/74]	loss: 0.003682
# Train Epoch: 28 [20/74]	loss: 0.002470
# Train Epoch: 28 [30/74]	loss: 0.005074
# Train Epoch: 28 [40/74]	loss: 0.002785
# Train Epoch: 28 [50/74]	loss: 0.003165
# Train Epoch: 28 [60/74]	loss: 0.003698
# Train Epoch: 28 [70/74]	loss: 0.002899
# [28]Validation Loss: 0.5433,Accuracy: 87.5000%
# Train Epoch: 29 [0/74]	loss: 0.004409
# Train Epoch: 29 [10/74]	loss: 0.002613
# Train Epoch: 29 [20/74]	loss: 0.002591
# Train Epoch: 29 [30/74]	loss: 0.002220
# Train Epoch: 29 [40/74]	loss: 0.001646
# Train Epoch: 29 [50/74]	loss: 0.002607
# Train Epoch: 29 [60/74]	loss: 0.003713
# Train Epoch: 29 [70/74]	loss: 0.002042
# [29]Validation Loss: 0.5428,Accuracy: 87.1622%
# [FINAL] Test Loss: 0.5267,Accuracy: 89.2617%
# Best Accuracy:  88.17567567567568
# Elasped Time: 0h, 17m, 58s
# time: 0h, 17m, 58s
