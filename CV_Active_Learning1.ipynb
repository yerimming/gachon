# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_Active_Learning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import time

import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image
#내가 추가
import re

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = re.sub(r'\([^)]*\)', '', label)
    label = int(label)
    return (img, label)

# %%
### Data Preprocessing ###

# 데이터 정규화 추가
# 정규화 변환 정의
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

transforms_train = transforms.Compose([transforms.Resize((448,448)),
                                       transforms.ToTensor(), normalize])
transforms_valtest = transforms.Compose([transforms.Resize((448,448)),
                                         transforms.ToTensor(), normalize])

BATCH_SIZE = 32
train_set = CUB2011(mode='train',
                    transform=transforms_train)
# transforms_train을 transforms_valtest로 변경
val_set = CUB2011(mode='valid',
                  transform=transforms_valtest)
test_set = CUB2011(mode='test',
                  transform=transforms_valtest)

print('Num of each dataset: ',len(train_set),len(val_set),len(test_set))

train_loader = DataLoader(train_set,batch_size=BATCH_SIZE,shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")

### Model / Optimizer ###
EPOCH = 30
lr = 0.001

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
model.to(DEVICE)

optimizer = optim.Adam(model.parameters(),lr=lr, betas=(0.9, 0.999), weight_decay=1e-5)

print("Created a learning model and optimizer")
# Out:
# Num of each dataset:  2362 296 298
# Loaded dataloader
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    # loss func을 어떤 것을 사용할 것인지?
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0
for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/74]	loss: 4.202305
# Train Epoch: 0 [10/74]	loss: 3.248092
# Train Epoch: 0 [20/74]	loss: 3.208231
# Train Epoch: 0 [30/74]	loss: 2.822748
# Train Epoch: 0 [40/74]	loss: 2.699890
# Train Epoch: 0 [50/74]	loss: 2.054615
# Train Epoch: 0 [60/74]	loss: 1.970354
# Train Epoch: 0 [70/74]	loss: 1.491642
# [0]Validation Loss: 2.0879,Accuracy: 44.5946%
# Train Epoch: 1 [0/74]	loss: 1.724189
# Train Epoch: 1 [10/74]	loss: 1.307065
# Train Epoch: 1 [20/74]	loss: 1.305282
# Train Epoch: 1 [30/74]	loss: 0.950566
# Train Epoch: 1 [40/74]	loss: 1.137810
# Train Epoch: 1 [50/74]	loss: 0.932382
# Train Epoch: 1 [60/74]	loss: 1.414320
# Train Epoch: 1 [70/74]	loss: 1.047638
# [1]Validation Loss: 3.7766,Accuracy: 27.7027%
# Train Epoch: 2 [0/74]	loss: 0.896178
# Train Epoch: 2 [10/74]	loss: 0.710879
# Train Epoch: 2 [20/74]	loss: 0.532706
# Train Epoch: 2 [30/74]	loss: 1.060739
# Train Epoch: 2 [40/74]	loss: 0.568966
# Train Epoch: 2 [50/74]	loss: 0.584962
# Train Epoch: 2 [60/74]	loss: 0.410898
# Train Epoch: 2 [70/74]	loss: 0.528438
# [2]Validation Loss: 1.7438,Accuracy: 60.1351%
# Train Epoch: 3 [0/74]	loss: 0.403811
# Train Epoch: 3 [10/74]	loss: 0.294378
# Train Epoch: 3 [20/74]	loss: 0.191680
# Train Epoch: 3 [30/74]	loss: 0.362543
# Train Epoch: 3 [40/74]	loss: 0.269002
# Train Epoch: 3 [50/74]	loss: 0.557094
# Train Epoch: 3 [60/74]	loss: 0.376056
# Train Epoch: 3 [70/74]	loss: 0.206984
# [3]Validation Loss: 1.4823,Accuracy: 61.1486%
# Train Epoch: 4 [0/74]	loss: 0.139616
# Train Epoch: 4 [10/74]	loss: 0.263207
# Train Epoch: 4 [20/74]	loss: 0.347084
# Train Epoch: 4 [30/74]	loss: 0.268229
# Train Epoch: 4 [40/74]	loss: 0.275313
# Train Epoch: 4 [50/74]	loss: 0.194369
# Train Epoch: 4 [60/74]	loss: 0.377470
# Train Epoch: 4 [70/74]	loss: 0.565745
# [4]Validation Loss: 1.2567,Accuracy: 64.5270%
# Train Epoch: 5 [0/74]	loss: 0.114072
# Train Epoch: 5 [10/74]	loss: 0.177519
# Train Epoch: 5 [20/74]	loss: 0.284350
# Train Epoch: 5 [30/74]	loss: 0.093144
# Train Epoch: 5 [40/74]	loss: 0.158301
# Train Epoch: 5 [50/74]	loss: 0.123831
# Train Epoch: 5 [60/74]	loss: 0.077999
# Train Epoch: 5 [70/74]	loss: 0.132660
# [5]Validation Loss: 0.8337,Accuracy: 75.6757%
# Train Epoch: 6 [0/74]	loss: 0.039928
# Train Epoch: 6 [10/74]	loss: 0.067997
# Train Epoch: 6 [20/74]	loss: 0.021755
# Train Epoch: 6 [30/74]	loss: 0.036587
# Train Epoch: 6 [40/74]	loss: 0.020763
# Train Epoch: 6 [50/74]	loss: 0.037919
# Train Epoch: 6 [60/74]	loss: 0.039331
# Train Epoch: 6 [70/74]	loss: 0.051892
# [6]Validation Loss: 0.7735,Accuracy: 77.7027%
# Train Epoch: 7 [0/74]	loss: 0.025763
# Train Epoch: 7 [10/74]	loss: 0.028699
# Train Epoch: 7 [20/74]	loss: 0.015830
# Train Epoch: 7 [30/74]	loss: 0.013907
# Train Epoch: 7 [40/74]	loss: 0.037814
# Train Epoch: 7 [50/74]	loss: 0.160168
# Train Epoch: 7 [60/74]	loss: 0.015254
# Train Epoch: 7 [70/74]	loss: 0.030141
# [7]Validation Loss: 0.7237,Accuracy: 80.7432%
# Train Epoch: 8 [0/74]	loss: 0.055200
# Train Epoch: 8 [10/74]	loss: 0.011496
# Train Epoch: 8 [20/74]	loss: 0.033910
# Train Epoch: 8 [30/74]	loss: 0.034505
# Train Epoch: 8 [40/74]	loss: 0.016713
# Train Epoch: 8 [50/74]	loss: 0.033479
# Train Epoch: 8 [60/74]	loss: 0.026510
# Train Epoch: 8 [70/74]	loss: 0.010933
# [8]Validation Loss: 0.7500,Accuracy: 80.7432%
# Train Epoch: 9 [0/74]	loss: 0.048509
# Train Epoch: 9 [10/74]	loss: 0.010072
# Train Epoch: 9 [20/74]	loss: 0.046679
# Train Epoch: 9 [30/74]	loss: 0.208953
# Train Epoch: 9 [40/74]	loss: 0.038479
# Train Epoch: 9 [50/74]	loss: 0.037663
# Train Epoch: 9 [60/74]	loss: 0.119769
# Train Epoch: 9 [70/74]	loss: 0.191960
# [9]Validation Loss: 1.4012,Accuracy: 66.5541%
# Train Epoch: 10 [0/74]	loss: 0.129168
# Train Epoch: 10 [10/74]	loss: 0.133442
# Train Epoch: 10 [20/74]	loss: 0.124991
# Train Epoch: 10 [30/74]	loss: 0.277396
# Train Epoch: 10 [40/74]	loss: 0.331567
# Train Epoch: 10 [50/74]	loss: 0.237446
# Train Epoch: 10 [60/74]	loss: 0.281067
# Train Epoch: 10 [70/74]	loss: 0.740095
# [10]Validation Loss: 2.5007,Accuracy: 45.9459%
# Train Epoch: 11 [0/74]	loss: 0.271243
# Train Epoch: 11 [10/74]	loss: 0.376685
# Train Epoch: 11 [20/74]	loss: 0.245316
# Train Epoch: 11 [30/74]	loss: 0.154966
# Train Epoch: 11 [40/74]	loss: 0.252473
# Train Epoch: 11 [50/74]	loss: 0.365966
# Train Epoch: 11 [60/74]	loss: 0.182051
# Train Epoch: 11 [70/74]	loss: 0.440728
# [11]Validation Loss: 1.5006,Accuracy: 62.5000%
# Train Epoch: 12 [0/74]	loss: 0.183294
# Train Epoch: 12 [10/74]	loss: 0.156862
# Train Epoch: 12 [20/74]	loss: 0.179011
# Train Epoch: 12 [30/74]	loss: 0.165739
# Train Epoch: 12 [40/74]	loss: 0.295380
# Train Epoch: 12 [50/74]	loss: 0.033981
# Train Epoch: 12 [60/74]	loss: 0.023643
# Train Epoch: 12 [70/74]	loss: 0.217856
# [12]Validation Loss: 1.2857,Accuracy: 67.5676%
# Train Epoch: 13 [0/74]	loss: 0.101696
# Train Epoch: 13 [10/74]	loss: 0.046242
# Train Epoch: 13 [20/74]	loss: 0.075658
# Train Epoch: 13 [30/74]	loss: 0.023327
# Train Epoch: 13 [40/74]	loss: 0.041765
# Train Epoch: 13 [50/74]	loss: 0.044684
# Train Epoch: 13 [60/74]	loss: 0.018208
# Train Epoch: 13 [70/74]	loss: 0.010473
# [13]Validation Loss: 0.8246,Accuracy: 79.0541%
# Train Epoch: 14 [0/74]	loss: 0.027653
# Train Epoch: 14 [10/74]	loss: 0.007213
# Train Epoch: 14 [20/74]	loss: 0.027911
# Train Epoch: 14 [30/74]	loss: 0.012630
# Train Epoch: 14 [40/74]	loss: 0.013303
# Train Epoch: 14 [50/74]	loss: 0.007628
# Train Epoch: 14 [60/74]	loss: 0.031386
# Train Epoch: 14 [70/74]	loss: 0.009524
# [14]Validation Loss: 0.7174,Accuracy: 83.4459%
# Train Epoch: 15 [0/74]	loss: 0.005826
# Train Epoch: 15 [10/74]	loss: 0.004556
# Train Epoch: 15 [20/74]	loss: 0.002894
# Train Epoch: 15 [30/74]	loss: 0.001874
# Train Epoch: 15 [40/74]	loss: 0.002706
# Train Epoch: 15 [50/74]	loss: 0.003423
# Train Epoch: 15 [60/74]	loss: 0.007627
# Train Epoch: 15 [70/74]	loss: 0.001681
# [15]Validation Loss: 0.6042,Accuracy: 85.8108%
# Train Epoch: 16 [0/74]	loss: 0.001155
# Train Epoch: 16 [10/74]	loss: 0.001501
# Train Epoch: 16 [20/74]	loss: 0.001319
# Train Epoch: 16 [30/74]	loss: 0.001493
# Train Epoch: 16 [40/74]	loss: 0.000837
# Train Epoch: 16 [50/74]	loss: 0.001304
# Train Epoch: 16 [60/74]	loss: 0.001254
# Train Epoch: 16 [70/74]	loss: 0.001478
# [16]Validation Loss: 0.5868,Accuracy: 86.8243%
# Train Epoch: 17 [0/74]	loss: 0.001086
# Train Epoch: 17 [10/74]	loss: 0.001777
# Train Epoch: 17 [20/74]	loss: 0.000962
# Train Epoch: 17 [30/74]	loss: 0.000752
# Train Epoch: 17 [40/74]	loss: 0.000649
# Train Epoch: 17 [50/74]	loss: 0.001433
# Train Epoch: 17 [60/74]	loss: 0.001171
# Train Epoch: 17 [70/74]	loss: 0.000702
# [17]Validation Loss: 0.5851,Accuracy: 87.1622%
# Train Epoch: 18 [0/74]	loss: 0.000822
# Train Epoch: 18 [10/74]	loss: 0.000678
# Train Epoch: 18 [20/74]	loss: 0.002941
# Train Epoch: 18 [30/74]	loss: 0.000566
# Train Epoch: 18 [40/74]	loss: 0.000960
# Train Epoch: 18 [50/74]	loss: 0.002035
# Train Epoch: 18 [60/74]	loss: 0.001342
# Train Epoch: 18 [70/74]	loss: 0.001279
# [18]Validation Loss: 0.5712,Accuracy: 87.1622%
# Train Epoch: 19 [0/74]	loss: 0.001353
# Train Epoch: 19 [10/74]	loss: 0.000569
# Train Epoch: 19 [20/74]	loss: 0.000504
# Train Epoch: 19 [30/74]	loss: 0.002538
# Train Epoch: 19 [40/74]	loss: 0.001369
# Train Epoch: 19 [50/74]	loss: 0.000588
# Train Epoch: 19 [60/74]	loss: 0.000629
# Train Epoch: 19 [70/74]	loss: 0.000783
# [19]Validation Loss: 0.5821,Accuracy: 86.4865%
# Train Epoch: 20 [0/74]	loss: 0.000903
# Train Epoch: 20 [10/74]	loss: 0.000386
# Train Epoch: 20 [20/74]	loss: 0.001151
# Train Epoch: 20 [30/74]	loss: 0.000473
# Train Epoch: 20 [40/74]	loss: 0.001010
# Train Epoch: 20 [50/74]	loss: 0.000492
# Train Epoch: 20 [60/74]	loss: 0.000657
# Train Epoch: 20 [70/74]	loss: 0.000185
# [20]Validation Loss: 0.5619,Accuracy: 87.8378%
# Train Epoch: 21 [0/74]	loss: 0.000382
# Train Epoch: 21 [10/74]	loss: 0.000467
# Train Epoch: 21 [20/74]	loss: 0.000594
# Train Epoch: 21 [30/74]	loss: 0.000444
# Train Epoch: 21 [40/74]	loss: 0.001119
# Train Epoch: 21 [50/74]	loss: 0.000540
# Train Epoch: 21 [60/74]	loss: 0.001088
# Train Epoch: 21 [70/74]	loss: 0.000511
# [21]Validation Loss: 0.5524,Accuracy: 87.1622%
# Train Epoch: 22 [0/74]	loss: 0.000807
# Train Epoch: 22 [10/74]	loss: 0.000520
# Train Epoch: 22 [20/74]	loss: 0.000845
# Train Epoch: 22 [30/74]	loss: 0.000296
# Train Epoch: 22 [40/74]	loss: 0.000261
# Train Epoch: 22 [50/74]	loss: 0.000807
# Train Epoch: 22 [60/74]	loss: 0.000747
# Train Epoch: 22 [70/74]	loss: 0.000406
# [22]Validation Loss: 0.5583,Accuracy: 87.1622%
# Train Epoch: 23 [0/74]	loss: 0.001926
# Train Epoch: 23 [10/74]	loss: 0.000401
# Train Epoch: 23 [20/74]	loss: 0.000561
# Train Epoch: 23 [30/74]	loss: 0.000217
# Train Epoch: 23 [40/74]	loss: 0.000561
# Train Epoch: 23 [50/74]	loss: 0.001991
# Train Epoch: 23 [60/74]	loss: 0.000279
# Train Epoch: 23 [70/74]	loss: 0.000865
# [23]Validation Loss: 0.5300,Accuracy: 87.8378%
# Train Epoch: 24 [0/74]	loss: 0.000442
# Train Epoch: 24 [10/74]	loss: 0.000542
# Train Epoch: 24 [20/74]	loss: 0.000298
# Train Epoch: 24 [30/74]	loss: 0.000680
# Train Epoch: 24 [40/74]	loss: 0.000279
# Train Epoch: 24 [50/74]	loss: 0.000445
# Train Epoch: 24 [60/74]	loss: 0.000257
# Train Epoch: 24 [70/74]	loss: 0.000958
# [24]Validation Loss: 0.5455,Accuracy: 87.5000%
# Train Epoch: 25 [0/74]	loss: 0.000475
# Train Epoch: 25 [10/74]	loss: 0.000413
# Train Epoch: 25 [20/74]	loss: 0.000598
# Train Epoch: 25 [30/74]	loss: 0.000485
# Train Epoch: 25 [40/74]	loss: 0.000326
# Train Epoch: 25 [50/74]	loss: 0.000287
# Train Epoch: 25 [60/74]	loss: 0.000496
# Train Epoch: 25 [70/74]	loss: 0.000565
# [25]Validation Loss: 0.5390,Accuracy: 88.1757%
# Train Epoch: 26 [0/74]	loss: 0.000328
# Train Epoch: 26 [10/74]	loss: 0.000581
# Train Epoch: 26 [20/74]	loss: 0.000178
# Train Epoch: 26 [30/74]	loss: 0.000479
# Train Epoch: 26 [40/74]	loss: 0.000324
# Train Epoch: 26 [50/74]	loss: 0.000377
# Train Epoch: 26 [60/74]	loss: 0.000356
# Train Epoch: 26 [70/74]	loss: 0.000390
# [26]Validation Loss: 0.5407,Accuracy: 86.8243%
# Train Epoch: 27 [0/74]	loss: 0.000400
# Train Epoch: 27 [10/74]	loss: 0.000435
# Train Epoch: 27 [20/74]	loss: 0.000502
# Train Epoch: 27 [30/74]	loss: 0.000379
# Train Epoch: 27 [40/74]	loss: 0.001812
# Train Epoch: 27 [50/74]	loss: 0.000404
# Train Epoch: 27 [60/74]	loss: 0.000400
# Train Epoch: 27 [70/74]	loss: 0.000333
# [27]Validation Loss: 0.5413,Accuracy: 87.8378%
# Train Epoch: 28 [0/74]	loss: 0.000273
# Train Epoch: 28 [10/74]	loss: 0.000274
# Train Epoch: 28 [20/74]	loss: 0.000379
# Train Epoch: 28 [30/74]	loss: 0.000255
# Train Epoch: 28 [40/74]	loss: 0.000364
# Train Epoch: 28 [50/74]	loss: 0.000292
# Train Epoch: 28 [60/74]	loss: 0.000361
# Train Epoch: 28 [70/74]	loss: 0.000421
# [28]Validation Loss: 0.5516,Accuracy: 87.5000%
# Train Epoch: 29 [0/74]	loss: 0.000312
# Train Epoch: 29 [10/74]	loss: 0.000613
# Train Epoch: 29 [20/74]	loss: 0.000354
# Train Epoch: 29 [30/74]	loss: 0.000371
# Train Epoch: 29 [40/74]	loss: 0.000518
# Train Epoch: 29 [50/74]	loss: 0.000610
# Train Epoch: 29 [60/74]	loss: 0.000272
# Train Epoch: 29 [70/74]	loss: 0.000397
# [29]Validation Loss: 0.5306,Accuracy: 87.8378%
# [FINAL] Test Loss: 0.5068,Accuracy: 87.9195%
# Best Accuracy:  88.17567567567568
# Elasped Time: 0h, 18m, 51s
# time: 0h, 18m, 51s
