# %% [markdown]
# <a href="https://colab.research.google.com/github/yerimming/gachon/blob/main/CV_final_test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   AdamP 사용
# *   lr = 0.0001
# *   batch = 32
# *   CosineAnnealingLR 사용

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip3 install adamp
# Out:
# Collecting adamp
#   Downloading adamp-0.3.0.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: adamp
#   Building wheel for adamp (setup.py) ... done
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5981 sha256=cf8816b72cc46aae11f5dedce96169a3384940e4fd7ff8cd94782c0e1680c615
#   Stored in directory: /root/.cache/pip/wheels/c7/ad/0f/b41b1c45b18c66e5eef5d2254415af8055c7e2b0934145157d
# Successfully built adamp
# Installing collected packages: adamp
# Successfully installed adamp-0.3.0

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor,Normalize, RandomHorizontalFlip, Resize
from torchvision.transforms import RandAugment
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image,ImageFilter,ImageEnhance

from torch.utils.data import ConcatDataset
from collections import Counter

from adamp import AdamP

# 스케줄러 사용
from torch.optim.lr_scheduler import CosineAnnealingLR

import re

# 랜덤 시드 설정 공통
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)
    label = img_path.split('_')[-1].split('.')[0]
    label = re.sub(r'\([^)]*\)', '', label)
    label = int(label)
    return (img, label)

# %%
# Geomentric transform + Visual corruptions
class AddGaussianNoise(object):
    def __init__(self, mean=0, std=1, p=0.5):
        self.mean = mean
        self.std = std
        self.p = p

    def __call__(self, img):
        if np.random.rand() < self.p:
            img_array = np.array(img)
            noise = np.random.normal(self.mean, self.std, img_array.shape)
            noisy_image = np.clip(img_array + noise, 0, 255)  # Clip values to the range [0, 255]
            return Image.fromarray(noisy_image.astype(np.uint8))
        else:
            return img

    def __repr__(self):
        return self.__class__.__name__ + f'(mean={self.mean}, std={self.std}, p={self.p})'


class AdjustContrast(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

class AdjustBrightness(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Brightness(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'


# Mix up
def mixup_data(x, y, alpha=1.0):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size, device=x.device, dtype=torch.long)  # GPU에 있는 x.device를 사용하여 인덱스를 GPU로 전송

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
### Data Preprocessing ###
transforms_train_origin = transforms.Compose([transforms.Resize((448,448), Image.BICUBIC),
                                       transforms.ToTensor()])
transforms_test = transforms.Compose([transforms.Resize((448,448), Image.BICUBIC),
                                       transforms.ToTensor()])

# Apply RandAugment
transforms_train_rand = transforms.Compose([
    transforms.Resize((448, 448), Image.BICUBIC),
    RandAugment(5,3),
    transforms.ToTensor()])

# Geomentric transform + Visual corruptions
transforms_train_g_v = transforms.Compose([
    transforms.Resize((448, 448), Image.BICUBIC),
    transforms.RandomResizedCrop(448),
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandomVerticalFlip(0.5),
    transforms.RandomRotation(30),
    AddGaussianNoise(mean=0, std=25, p=0.5),  # 가우시안 노이즈를 추가합니다.
    AdjustContrast(factor=2.0),  # 대비를 조절합니다.
    AdjustBrightness(factor=1.5),  # 밝기를 조절합니다.
    transforms.ToTensor()])


BATCH_SIZE = 32

train_set_origin = CUB2011(mode='train',
                    transform=transforms_train_origin)
val_set = CUB2011(mode='valid',
                  transform=transforms_test)
test_set = CUB2011(mode='test',
                  transform=transforms_test)

# 데이터 증강을 위해 원래 데이터를 복사하고 추가
train_set_augmented = CUB2011(mode='train', transform=transforms_train_rand)
train_set_augmented2 = CUB2011(mode='train',transform=transforms_train_g_v)

train_loader = DataLoader(train_set_origin,batch_size=BATCH_SIZE,shuffle=True)

# Mixup된 이미지를 train_loader에 추가
train_set_mixup = []
for input, target in train_loader:
    mixed_input, target_a, target_b, lam = mixup_data(input, target, alpha=1.0)
    train_set_mixup.append((mixed_input, target_a, target_b, lam))
train_set_mixup = transforms.Compose([transforms.Resize((448,448), Image.BICUBIC),
                                       transforms.ToTensor()
                                       ])
train_set_mixup = CUB2011(mode='train', transform=train_set_mixup)


# 각 클래스의 샘플 수를 계산
class_counts = Counter([label for _, label in train_set_origin])

# 가장 작은 클래스의 샘플 수를 찾아 minority_class_label로 지정
minority_class_label = min(class_counts, key=class_counts.get)

# Create a new dataset from replicated_data
replicated_data = CUB2011(mode='train', transform=transforms_train_rand)
replicated_data.image_folder = [data for data in train_set_origin.image_folder if data[1] == minority_class_label]



# 두 데이터셋을 연결하여 새로운 훈련 데이터셋 생성
train_set_combined = ConcatDataset([train_set_origin, replicated_data,
                                    train_set_augmented,train_set_augmented2,train_set_mixup])

print('Num of each dataset: ',len(train_set_combined),len(val_set),len(test_set))


#-----------------------------------------------------------------------
# Dataloader class는 bath기반의 딥러닝모델 학습을 위해서 mini batch를 만들어주는 역할을 한다
# dataloader를 통해 dataset의 전체 데이터가 batch size로 나뉘게 된다
train_loader = DataLoader(train_set_combined, batch_size=BATCH_SIZE, shuffle=True)
# train_loader = DataLoader(train_set_combined, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")
# Out:
# Num of each dataset:  9448 296 298
# Loaded dataloader

# %%
### Model / Optimizer ###
EPOCH = 15
lr = 0.0001

model = models.resnet18(pretrained=True)

### Tranfer Learning ###
num_features = model.fc.in_features
model.fc = nn.Linear(num_features,50)
model.to(DEVICE)

optimizer = AdamP(model.parameters(),lr=lr,betas=(0.9, 0.999))

# 스케줄러 초기화 (주기와 최소/최대 학습률 설정)
dataset_size = len(train_set_combined)  # 훈련 데이터셋 크기

T_max = dataset_size / BATCH_SIZE  # 한 주기의 에폭 수
scheduler = CosineAnnealingLR(optimizer, T_max=T_max, eta_min=0.001)

print("Created a learning model and optimizer")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 108MB/s]
# Created a learning model and optimizer

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()
    # loss func을 어떤 것을 사용할 것인지?
    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    # 스케줄러 업데이트
    scheduler.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
### Main ###
start = time.time()
best = 0

train_losses = []  # 훈련 손실을 저장할 목록
val_losses = []    # 검증 손실을 저장할 목록
val_accuracys = []

# 디렉토리 생성
os.makedirs('./best_model', exist_ok=True)

for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # 훈련 및 검증 손실을 목록에 추가
  train_losses.append(train_loss)
  val_losses.append(val_loss)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  val_accuracys.append(val_accuracy)
  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/296]	loss: 4.103332
# Train Epoch: 0 [10/296]	loss: 3.833236
# Train Epoch: 0 [20/296]	loss: 3.625753
# Train Epoch: 0 [30/296]	loss: 3.315295
# Train Epoch: 0 [40/296]	loss: 3.245986
# Train Epoch: 0 [50/296]	loss: 3.009757
# Train Epoch: 0 [60/296]	loss: 2.390154
# Train Epoch: 0 [70/296]	loss: 2.196922
# Train Epoch: 0 [80/296]	loss: 1.939966
# Train Epoch: 0 [90/296]	loss: 1.907143
# Train Epoch: 0 [100/296]	loss: 1.787975
# Train Epoch: 0 [110/296]	loss: 2.026104
# Train Epoch: 0 [120/296]	loss: 1.663953
# Train Epoch: 0 [130/296]	loss: 1.532953
# Train Epoch: 0 [140/296]	loss: 1.453710
# Train Epoch: 0 [150/296]	loss: 1.304576
# Train Epoch: 0 [160/296]	loss: 1.278252
# Train Epoch: 0 [170/296]	loss: 1.495173
# Train Epoch: 0 [180/296]	loss: 1.507025
# Train Epoch: 0 [190/296]	loss: 1.611238
# Train Epoch: 0 [200/296]	loss: 1.695583
# Train Epoch: 0 [210/296]	loss: 1.537270
# Train Epoch: 0 [220/296]	loss: 1.580382
# Train Epoch: 0 [230/296]	loss: 1.285128
# Train Epoch: 0 [240/296]	loss: 1.062266
# Train Epoch: 0 [250/296]	loss: 1.558044
# Train Epoch: 0 [260/296]	loss: 1.429256
# Train Epoch: 0 [270/296]	loss: 1.735015
# Train Epoch: 0 [280/296]	loss: 1.148442
# Train Epoch: 0 [290/296]	loss: 1.627413
# [0]Validation Loss: 2.7108,Accuracy: 39.8649%
# Train Epoch: 1 [0/296]	loss: 1.244012
# Train Epoch: 1 [10/296]	loss: 1.087121
# Train Epoch: 1 [20/296]	loss: 1.433548
# Train Epoch: 1 [30/296]	loss: 1.126247
# Train Epoch: 1 [40/296]	loss: 1.910130
# Train Epoch: 1 [50/296]	loss: 1.067255
# Train Epoch: 1 [60/296]	loss: 1.457778
# Train Epoch: 1 [70/296]	loss: 1.325254
# Train Epoch: 1 [80/296]	loss: 0.964112
# Train Epoch: 1 [90/296]	loss: 1.222469
# Train Epoch: 1 [100/296]	loss: 0.986279
# Train Epoch: 1 [110/296]	loss: 0.992932
# Train Epoch: 1 [120/296]	loss: 0.679162
# Train Epoch: 1 [130/296]	loss: 0.978493
# Train Epoch: 1 [140/296]	loss: 0.989650
# Train Epoch: 1 [150/296]	loss: 1.030309
# Train Epoch: 1 [160/296]	loss: 0.555588
# Train Epoch: 1 [170/296]	loss: 0.675629
# Train Epoch: 1 [180/296]	loss: 0.759959
# Train Epoch: 1 [190/296]	loss: 0.637341
# Train Epoch: 1 [200/296]	loss: 0.342448
# Train Epoch: 1 [210/296]	loss: 0.793349
# Train Epoch: 1 [220/296]	loss: 0.567918
# Train Epoch: 1 [230/296]	loss: 0.895632
# Train Epoch: 1 [240/296]	loss: 0.936205
# Train Epoch: 1 [250/296]	loss: 0.741279
# Train Epoch: 1 [260/296]	loss: 0.288523
# Train Epoch: 1 [270/296]	loss: 0.571174
# Train Epoch: 1 [280/296]	loss: 0.631089
# Train Epoch: 1 [290/296]	loss: 0.505265
# [1]Validation Loss: 0.5245,Accuracy: 85.4730%
# Train Epoch: 2 [0/296]	loss: 0.177524
# Train Epoch: 2 [10/296]	loss: 0.299723
# Train Epoch: 2 [20/296]	loss: 0.446887
# Train Epoch: 2 [30/296]	loss: 0.235656
# Train Epoch: 2 [40/296]	loss: 0.480427
# Train Epoch: 2 [50/296]	loss: 0.339199
# Train Epoch: 2 [60/296]	loss: 0.522581
# Train Epoch: 2 [70/296]	loss: 0.554949
# Train Epoch: 2 [80/296]	loss: 0.434988
# Train Epoch: 2 [90/296]	loss: 0.621596
# Train Epoch: 2 [100/296]	loss: 0.405361
# Train Epoch: 2 [110/296]	loss: 0.427640
# Train Epoch: 2 [120/296]	loss: 0.407838
# Train Epoch: 2 [130/296]	loss: 0.860605
# Train Epoch: 2 [140/296]	loss: 0.588557
# Train Epoch: 2 [150/296]	loss: 0.553481
# Train Epoch: 2 [160/296]	loss: 1.017426
# Train Epoch: 2 [170/296]	loss: 0.656034
# Train Epoch: 2 [180/296]	loss: 0.368863
# Train Epoch: 2 [190/296]	loss: 0.728143
# Train Epoch: 2 [200/296]	loss: 0.701673
# Train Epoch: 2 [210/296]	loss: 0.789778
# Train Epoch: 2 [220/296]	loss: 0.813685
# Train Epoch: 2 [230/296]	loss: 1.259639
# Train Epoch: 2 [240/296]	loss: 0.978446
# Train Epoch: 2 [250/296]	loss: 0.986539
# Train Epoch: 2 [260/296]	loss: 1.238617
# Train Epoch: 2 [270/296]	loss: 1.073620
# Train Epoch: 2 [280/296]	loss: 1.299321
# Train Epoch: 2 [290/296]	loss: 1.114164
# [2]Validation Loss: 2.2943,Accuracy: 46.9595%
# Train Epoch: 3 [0/296]	loss: 1.460749
# Train Epoch: 3 [10/296]	loss: 1.835869
# Train Epoch: 3 [20/296]	loss: 1.287500
# Train Epoch: 3 [30/296]	loss: 1.171662
# Train Epoch: 3 [40/296]	loss: 1.315730
# Train Epoch: 3 [50/296]	loss: 1.171250
# Train Epoch: 3 [60/296]	loss: 0.717454
# Train Epoch: 3 [70/296]	loss: 1.132670
# Train Epoch: 3 [80/296]	loss: 0.883640
# Train Epoch: 3 [90/296]	loss: 1.696012
# Train Epoch: 3 [100/296]	loss: 0.911395
# Train Epoch: 3 [110/296]	loss: 0.918053
# Train Epoch: 3 [120/296]	loss: 0.914613
# Train Epoch: 3 [130/296]	loss: 0.849173
# Train Epoch: 3 [140/296]	loss: 0.710597
# Train Epoch: 3 [150/296]	loss: 0.776307
# Train Epoch: 3 [160/296]	loss: 0.938478
# Train Epoch: 3 [170/296]	loss: 0.422465
# Train Epoch: 3 [180/296]	loss: 1.000579
# Train Epoch: 3 [190/296]	loss: 0.467396
# Train Epoch: 3 [200/296]	loss: 0.494870
# Train Epoch: 3 [210/296]	loss: 0.484028
# Train Epoch: 3 [220/296]	loss: 0.472509
# Train Epoch: 3 [230/296]	loss: 0.446989
# Train Epoch: 3 [240/296]	loss: 0.600512
# Train Epoch: 3 [250/296]	loss: 0.564153
# Train Epoch: 3 [260/296]	loss: 0.996840
# Train Epoch: 3 [270/296]	loss: 0.493266
# Train Epoch: 3 [280/296]	loss: 0.413140
# Train Epoch: 3 [290/296]	loss: 0.492983
# [3]Validation Loss: 0.5187,Accuracy: 86.4865%
# Train Epoch: 4 [0/296]	loss: 0.169573
# Train Epoch: 4 [10/296]	loss: 0.596053
# Train Epoch: 4 [20/296]	loss: 0.257707
# Train Epoch: 4 [30/296]	loss: 0.916250
# Train Epoch: 4 [40/296]	loss: 0.166087
# Train Epoch: 4 [50/296]	loss: 0.368633
# Train Epoch: 4 [60/296]	loss: 0.337927
# Train Epoch: 4 [70/296]	loss: 0.671071
# Train Epoch: 4 [80/296]	loss: 0.468574
# Train Epoch: 4 [90/296]	loss: 0.332303
# Train Epoch: 4 [100/296]	loss: 0.309060
# Train Epoch: 4 [110/296]	loss: 0.390663
# Train Epoch: 4 [120/296]	loss: 0.736262
# Train Epoch: 4 [130/296]	loss: 0.158764
# Train Epoch: 4 [140/296]	loss: 0.553878
# Train Epoch: 4 [150/296]	loss: 0.350102
# Train Epoch: 4 [160/296]	loss: 0.401641
# Train Epoch: 4 [170/296]	loss: 0.526107
# Train Epoch: 4 [180/296]	loss: 1.004860
# Train Epoch: 4 [190/296]	loss: 0.592937
# Train Epoch: 4 [200/296]	loss: 0.912763
# Train Epoch: 4 [210/296]	loss: 0.998425
# Train Epoch: 4 [220/296]	loss: 0.567253
# Train Epoch: 4 [230/296]	loss: 1.186428
# Train Epoch: 4 [240/296]	loss: 0.950657
# Train Epoch: 4 [250/296]	loss: 0.822983
# Train Epoch: 4 [260/296]	loss: 1.081249
# Train Epoch: 4 [270/296]	loss: 0.796238
# Train Epoch: 4 [280/296]	loss: 0.901563
# Train Epoch: 4 [290/296]	loss: 0.975075
# [4]Validation Loss: 1.4748,Accuracy: 63.8514%
# Train Epoch: 5 [0/296]	loss: 0.964570
# Train Epoch: 5 [10/296]	loss: 0.725504
# Train Epoch: 5 [20/296]	loss: 0.862182
# Train Epoch: 5 [30/296]	loss: 0.908702
# Train Epoch: 5 [40/296]	loss: 0.888527
# Train Epoch: 5 [50/296]	loss: 1.029641
# Train Epoch: 5 [60/296]	loss: 0.864118
# Train Epoch: 5 [70/296]	loss: 0.687730
# Train Epoch: 5 [80/296]	loss: 0.726919
# Train Epoch: 5 [90/296]	loss: 0.597348
# Train Epoch: 5 [100/296]	loss: 0.910200
# Train Epoch: 5 [110/296]	loss: 0.515241
# Train Epoch: 5 [120/296]	loss: 0.791319
# Train Epoch: 5 [130/296]	loss: 0.695646
# Train Epoch: 5 [140/296]	loss: 0.808744
# Train Epoch: 5 [150/296]	loss: 0.768112
# Train Epoch: 5 [160/296]	loss: 1.098030
# Train Epoch: 5 [170/296]	loss: 0.775716
# Train Epoch: 5 [180/296]	loss: 0.799175
# Train Epoch: 5 [190/296]	loss: 0.556792
# Train Epoch: 5 [200/296]	loss: 0.837297
# Train Epoch: 5 [210/296]	loss: 0.495466
# Train Epoch: 5 [220/296]	loss: 0.269877
# Train Epoch: 5 [230/296]	loss: 0.475680
# Train Epoch: 5 [240/296]	loss: 0.836471
# Train Epoch: 5 [250/296]	loss: 0.490961
# Train Epoch: 5 [260/296]	loss: 0.371027
# Train Epoch: 5 [270/296]	loss: 0.470027
# Train Epoch: 5 [280/296]	loss: 0.092488
# Train Epoch: 5 [290/296]	loss: 0.191205
# [5]Validation Loss: 0.5067,Accuracy: 86.4865%
# Train Epoch: 6 [0/296]	loss: 0.685756
# Train Epoch: 6 [10/296]	loss: 0.375857
# Train Epoch: 6 [20/296]	loss: 0.532584
# Train Epoch: 6 [30/296]	loss: 0.477656
# Train Epoch: 6 [40/296]	loss: 0.366060
# Train Epoch: 6 [50/296]	loss: 0.415066
# Train Epoch: 6 [60/296]	loss: 0.471300
# Train Epoch: 6 [70/296]	loss: 0.242056
# Train Epoch: 6 [80/296]	loss: 0.235351
# Train Epoch: 6 [90/296]	loss: 0.114383
# Train Epoch: 6 [100/296]	loss: 0.410620
# Train Epoch: 6 [110/296]	loss: 0.888190
# Train Epoch: 6 [120/296]	loss: 0.847257
# Train Epoch: 6 [130/296]	loss: 0.532921
# Train Epoch: 6 [140/296]	loss: 0.531334
# Train Epoch: 6 [150/296]	loss: 0.339463
# Train Epoch: 6 [160/296]	loss: 0.935399
# Train Epoch: 6 [170/296]	loss: 0.974173
# Train Epoch: 6 [180/296]	loss: 0.684108
# Train Epoch: 6 [190/296]	loss: 0.471574
# Train Epoch: 6 [200/296]	loss: 0.716082
# Train Epoch: 6 [210/296]	loss: 0.510917
# Train Epoch: 6 [220/296]	loss: 0.743456
# Train Epoch: 6 [230/296]	loss: 0.759687
# Train Epoch: 6 [240/296]	loss: 0.888680
# Train Epoch: 6 [250/296]	loss: 1.105804
# Train Epoch: 6 [260/296]	loss: 0.466940
# Train Epoch: 6 [270/296]	loss: 0.978826
# Train Epoch: 6 [280/296]	loss: 0.836731
# Train Epoch: 6 [290/296]	loss: 1.292416
# [6]Validation Loss: 1.9294,Accuracy: 59.4595%
# Train Epoch: 7 [0/296]	loss: 0.778768
# Train Epoch: 7 [10/296]	loss: 1.367795
# Train Epoch: 7 [20/296]	loss: 0.899899
# Train Epoch: 7 [30/296]	loss: 0.975413
# Train Epoch: 7 [40/296]	loss: 1.162362
# Train Epoch: 7 [50/296]	loss: 1.021019
# Train Epoch: 7 [60/296]	loss: 0.909143
# Train Epoch: 7 [70/296]	loss: 1.257778
# Train Epoch: 7 [80/296]	loss: 0.879784
# Train Epoch: 7 [90/296]	loss: 0.880695
# Train Epoch: 7 [100/296]	loss: 1.002524
# Train Epoch: 7 [110/296]	loss: 1.108907
# Train Epoch: 7 [120/296]	loss: 0.700643
# Train Epoch: 7 [130/296]	loss: 0.710423
# Train Epoch: 7 [140/296]	loss: 0.925528
# Train Epoch: 7 [150/296]	loss: 0.427021
# Train Epoch: 7 [160/296]	loss: 0.606599
# Train Epoch: 7 [170/296]	loss: 0.496059
# Train Epoch: 7 [180/296]	loss: 0.274916
# Train Epoch: 7 [190/296]	loss: 0.860445
# Train Epoch: 7 [200/296]	loss: 0.488380
# Train Epoch: 7 [210/296]	loss: 1.292793
# Train Epoch: 7 [220/296]	loss: 0.696469
# Train Epoch: 7 [230/296]	loss: 0.424569
# Train Epoch: 7 [240/296]	loss: 0.375781
# Train Epoch: 7 [250/296]	loss: 0.610326
# Train Epoch: 7 [260/296]	loss: 0.166264
# Train Epoch: 7 [270/296]	loss: 0.059818
# Train Epoch: 7 [280/296]	loss: 0.550980
# Train Epoch: 7 [290/296]	loss: 0.661598
# [7]Validation Loss: 0.5276,Accuracy: 87.1622%
# Train Epoch: 8 [0/296]	loss: 0.587506
# Train Epoch: 8 [10/296]	loss: 0.225597
# Train Epoch: 8 [20/296]	loss: 0.185960
# Train Epoch: 8 [30/296]	loss: 0.146810
# Train Epoch: 8 [40/296]	loss: 0.106507
# Train Epoch: 8 [50/296]	loss: 0.510332
# Train Epoch: 8 [60/296]	loss: 0.555661
# Train Epoch: 8 [70/296]	loss: 0.201751
# Train Epoch: 8 [80/296]	loss: 0.360915
# Train Epoch: 8 [90/296]	loss: 0.388658
# Train Epoch: 8 [100/296]	loss: 0.181728
# Train Epoch: 8 [110/296]	loss: 0.514696
# Train Epoch: 8 [120/296]	loss: 0.431208
# Train Epoch: 8 [130/296]	loss: 0.707062
# Train Epoch: 8 [140/296]	loss: 0.650606
# Train Epoch: 8 [150/296]	loss: 0.426884
# Train Epoch: 8 [160/296]	loss: 0.732801
# Train Epoch: 8 [170/296]	loss: 0.475795
# Train Epoch: 8 [180/296]	loss: 0.268034
# Train Epoch: 8 [190/296]	loss: 0.292126
# Train Epoch: 8 [200/296]	loss: 0.589246
# Train Epoch: 8 [210/296]	loss: 0.678512
# Train Epoch: 8 [220/296]	loss: 0.383993
# Train Epoch: 8 [230/296]	loss: 0.588462
# Train Epoch: 8 [240/296]	loss: 0.834068
# Train Epoch: 8 [250/296]	loss: 0.693284
# Train Epoch: 8 [260/296]	loss: 1.264251
# Train Epoch: 8 [270/296]	loss: 0.983448
# Train Epoch: 8 [280/296]	loss: 0.635139
# Train Epoch: 8 [290/296]	loss: 1.522161
# [8]Validation Loss: 2.3734,Accuracy: 53.3784%
# Train Epoch: 9 [0/296]	loss: 0.776222
# Train Epoch: 9 [10/296]	loss: 1.440589
# Train Epoch: 9 [20/296]	loss: 1.629398
# Train Epoch: 9 [30/296]	loss: 1.112440
# Train Epoch: 9 [40/296]	loss: 1.417530
# Train Epoch: 9 [50/296]	loss: 0.816644
# Train Epoch: 9 [60/296]	loss: 1.120921
# Train Epoch: 9 [70/296]	loss: 0.777567
# Train Epoch: 9 [80/296]	loss: 0.769807
# Train Epoch: 9 [90/296]	loss: 0.998296
# Train Epoch: 9 [100/296]	loss: 0.881465
# Train Epoch: 9 [110/296]	loss: 0.553115
# Train Epoch: 9 [120/296]	loss: 0.746964
# Train Epoch: 9 [130/296]	loss: 0.431211
# Train Epoch: 9 [140/296]	loss: 0.649529
# Train Epoch: 9 [150/296]	loss: 0.481065
# Train Epoch: 9 [160/296]	loss: 0.678901
# Train Epoch: 9 [170/296]	loss: 0.626275
# Train Epoch: 9 [180/296]	loss: 0.419253
# Train Epoch: 9 [190/296]	loss: 0.356196
# Train Epoch: 9 [200/296]	loss: 0.167003
# Train Epoch: 9 [210/296]	loss: 0.451365
# Train Epoch: 9 [220/296]	loss: 0.388759
# Train Epoch: 9 [230/296]	loss: 0.272601
# Train Epoch: 9 [240/296]	loss: 0.292249
# Train Epoch: 9 [250/296]	loss: 0.469265
# Train Epoch: 9 [260/296]	loss: 0.157342
# Train Epoch: 9 [270/296]	loss: 0.584663
# Train Epoch: 9 [280/296]	loss: 0.408366
# Train Epoch: 9 [290/296]	loss: 0.435564
# [9]Validation Loss: 0.5512,Accuracy: 85.4730%
# Train Epoch: 10 [0/296]	loss: 0.097631
# Train Epoch: 10 [10/296]	loss: 0.075015
# Train Epoch: 10 [20/296]	loss: 0.363637
# Train Epoch: 10 [30/296]	loss: 0.336620
# Train Epoch: 10 [40/296]	loss: 0.546452
# Train Epoch: 10 [50/296]	loss: 0.148585
# Train Epoch: 10 [60/296]	loss: 0.352163
# Train Epoch: 10 [70/296]	loss: 0.330425
# Train Epoch: 10 [80/296]	loss: 0.260969
# Train Epoch: 10 [90/296]	loss: 0.304916
# Train Epoch: 10 [100/296]	loss: 0.228898
# Train Epoch: 10 [110/296]	loss: 0.772559
# Train Epoch: 10 [120/296]	loss: 0.394694
# Train Epoch: 10 [130/296]	loss: 0.686063
# Train Epoch: 10 [140/296]	loss: 0.719668
# Train Epoch: 10 [150/296]	loss: 0.175889
# Train Epoch: 10 [160/296]	loss: 1.074888
# Train Epoch: 10 [170/296]	loss: 0.288335
# Train Epoch: 10 [180/296]	loss: 0.658597
# Train Epoch: 10 [190/296]	loss: 0.492557
# Train Epoch: 10 [200/296]	loss: 0.377250
# Train Epoch: 10 [210/296]	loss: 1.088444
# Train Epoch: 10 [220/296]	loss: 0.911644
# Train Epoch: 10 [230/296]	loss: 0.659684
# Train Epoch: 10 [240/296]	loss: 1.035277
# Train Epoch: 10 [250/296]	loss: 0.752337
# Train Epoch: 10 [260/296]	loss: 1.304272
# Train Epoch: 10 [270/296]	loss: 1.511580
# Train Epoch: 10 [280/296]	loss: 1.205810
# Train Epoch: 10 [290/296]	loss: 1.151785
# [10]Validation Loss: 1.9967,Accuracy: 54.7297%
# Train Epoch: 11 [0/296]	loss: 1.179622
# Train Epoch: 11 [10/296]	loss: 0.959185
# Train Epoch: 11 [20/296]	loss: 1.024400
# Train Epoch: 11 [30/296]	loss: 0.813524
# Train Epoch: 11 [40/296]	loss: 0.556084
# Train Epoch: 11 [50/296]	loss: 0.720097
# Train Epoch: 11 [60/296]	loss: 1.101430
# Train Epoch: 11 [70/296]	loss: 0.995728
# Train Epoch: 11 [80/296]	loss: 0.806344
# Train Epoch: 11 [90/296]	loss: 0.597672
# Train Epoch: 11 [100/296]	loss: 0.614238
# Train Epoch: 11 [110/296]	loss: 0.941537
# Train Epoch: 11 [120/296]	loss: 1.056472
# Train Epoch: 11 [130/296]	loss: 0.739247
# Train Epoch: 11 [140/296]	loss: 0.436828
# Train Epoch: 11 [150/296]	loss: 0.780250
# Train Epoch: 11 [160/296]	loss: 0.454680
# Train Epoch: 11 [170/296]	loss: 0.642140
# Train Epoch: 11 [180/296]	loss: 0.782895
# Train Epoch: 11 [190/296]	loss: 0.512258
# Train Epoch: 11 [200/296]	loss: 0.295707
# Train Epoch: 11 [210/296]	loss: 0.670358
# Train Epoch: 11 [220/296]	loss: 0.301203
# Train Epoch: 11 [230/296]	loss: 0.158045
# Train Epoch: 11 [240/296]	loss: 0.090718
# Train Epoch: 11 [250/296]	loss: 0.354016
# Train Epoch: 11 [260/296]	loss: 0.722917
# Train Epoch: 11 [270/296]	loss: 0.601801
# Train Epoch: 11 [280/296]	loss: 0.857983
# Train Epoch: 11 [290/296]	loss: 0.354571
# [11]Validation Loss: 0.4892,Accuracy: 86.8243%
# Train Epoch: 12 [0/296]	loss: 0.279422
# Train Epoch: 12 [10/296]	loss: 0.196517
# Train Epoch: 12 [20/296]	loss: 0.304707
# Train Epoch: 12 [30/296]	loss: 0.514034
# Train Epoch: 12 [40/296]	loss: 0.219426
# Train Epoch: 12 [50/296]	loss: 0.601418
# Train Epoch: 12 [60/296]	loss: 0.466338
# Train Epoch: 12 [70/296]	loss: 0.449414
# Train Epoch: 12 [80/296]	loss: 0.412310
# Train Epoch: 12 [90/296]	loss: 0.504876
# Train Epoch: 12 [100/296]	loss: 0.511187
# Train Epoch: 12 [110/296]	loss: 0.325101
# Train Epoch: 12 [120/296]	loss: 0.730484
# Train Epoch: 12 [130/296]	loss: 0.816631
# Train Epoch: 12 [140/296]	loss: 0.379309
# Train Epoch: 12 [150/296]	loss: 0.636092
# Train Epoch: 12 [160/296]	loss: 0.751833
# Train Epoch: 12 [170/296]	loss: 0.689810
# Train Epoch: 12 [180/296]	loss: 0.349051
# Train Epoch: 12 [190/296]	loss: 0.329244
# Train Epoch: 12 [200/296]	loss: 0.622238
# Train Epoch: 12 [210/296]	loss: 0.603785
# Train Epoch: 12 [220/296]	loss: 0.889693
# Train Epoch: 12 [230/296]	loss: 1.181080
# Train Epoch: 12 [240/296]	loss: 0.649696
# Train Epoch: 12 [250/296]	loss: 0.635866
# Train Epoch: 12 [260/296]	loss: 0.534097
# Train Epoch: 12 [270/296]	loss: 0.736933
# Train Epoch: 12 [280/296]	loss: 1.001627
# Train Epoch: 12 [290/296]	loss: 0.818184
# [12]Validation Loss: 1.5891,Accuracy: 65.8784%
# Train Epoch: 13 [0/296]	loss: 0.942046
# Train Epoch: 13 [10/296]	loss: 1.254146
# Train Epoch: 13 [20/296]	loss: 1.357631
# Train Epoch: 13 [30/296]	loss: 0.592087
# Train Epoch: 13 [40/296]	loss: 1.132465
# Train Epoch: 13 [50/296]	loss: 0.788102
# Train Epoch: 13 [60/296]	loss: 0.798935
# Train Epoch: 13 [70/296]	loss: 0.517876
# Train Epoch: 13 [80/296]	loss: 1.326766
# Train Epoch: 13 [90/296]	loss: 0.537908
# Train Epoch: 13 [100/296]	loss: 0.918627
# Train Epoch: 13 [110/296]	loss: 0.441747
# Train Epoch: 13 [120/296]	loss: 0.646531
# Train Epoch: 13 [130/296]	loss: 0.529941
# Train Epoch: 13 [140/296]	loss: 0.510501
# Train Epoch: 13 [150/296]	loss: 0.321277
# Train Epoch: 13 [160/296]	loss: 0.278877
# Train Epoch: 13 [170/296]	loss: 0.306459
# Train Epoch: 13 [180/296]	loss: 0.501753
# Train Epoch: 13 [190/296]	loss: 0.623923
# Train Epoch: 13 [200/296]	loss: 0.645026
# Train Epoch: 13 [210/296]	loss: 0.317062
# Train Epoch: 13 [220/296]	loss: 0.603643
# Train Epoch: 13 [230/296]	loss: 0.237753
# Train Epoch: 13 [240/296]	loss: 0.579844
# Train Epoch: 13 [250/296]	loss: 0.573220
# Train Epoch: 13 [260/296]	loss: 0.313868
# Train Epoch: 13 [270/296]	loss: 0.230598
# Train Epoch: 13 [280/296]	loss: 0.423367
# Train Epoch: 13 [290/296]	loss: 0.365401
# [13]Validation Loss: 0.5840,Accuracy: 84.7973%
# Train Epoch: 14 [0/296]	loss: 0.195988
# Train Epoch: 14 [10/296]	loss: 0.411419
# Train Epoch: 14 [20/296]	loss: 0.169672
# Train Epoch: 14 [30/296]	loss: 0.332727
# Train Epoch: 14 [40/296]	loss: 0.693336
# Train Epoch: 14 [50/296]	loss: 0.530933
# Train Epoch: 14 [60/296]	loss: 0.410302
# Train Epoch: 14 [70/296]	loss: 0.223246
# Train Epoch: 14 [80/296]	loss: 0.411704
# Train Epoch: 14 [90/296]	loss: 0.772148
# Train Epoch: 14 [100/296]	loss: 0.318582
# Train Epoch: 14 [110/296]	loss: 0.482356
# Train Epoch: 14 [120/296]	loss: 0.527342
# Train Epoch: 14 [130/296]	loss: 0.207204
# Train Epoch: 14 [140/296]	loss: 0.341714
# Train Epoch: 14 [150/296]	loss: 0.274693
# Train Epoch: 14 [160/296]	loss: 0.253464
# Train Epoch: 14 [170/296]	loss: 0.715531
# Train Epoch: 14 [180/296]	loss: 0.364097
# Train Epoch: 14 [190/296]	loss: 0.434071
# Train Epoch: 14 [200/296]	loss: 0.685739
# Train Epoch: 14 [210/296]	loss: 0.948609
# Train Epoch: 14 [220/296]	loss: 0.261850
# Train Epoch: 14 [230/296]	loss: 0.624180
# Train Epoch: 14 [240/296]	loss: 1.189201
# Train Epoch: 14 [250/296]	loss: 0.985121
# Train Epoch: 14 [260/296]	loss: 1.170311
# Train Epoch: 14 [270/296]	loss: 1.223640
# Train Epoch: 14 [280/296]	loss: 0.350556
# Train Epoch: 14 [290/296]	loss: 0.535079
# [14]Validation Loss: 1.7338,Accuracy: 58.1081%
# [FINAL] Test Loss: 1.8294,Accuracy: 54.3624%
# Best Accuracy:  87.16216216216216
# Elasped Time: 1h, 81m, 33s
# time: 1h, 81m, 33s

# %%
# 이제 손실 값을 플로팅합니다.
import matplotlib.pyplot as plt

# train_loss와 val_loss 텐서를 CPU로 이동하고 NumPy 배열로 변환
train_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in train_losses]
val_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), train_losses, label='train_loss', marker='o')
plt.plot(range(1, EPOCH + 1), val_losses, label='val_loss', marker='o')
plt.title('Training and Validation Loss Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()


val_accuracys = [acc.cpu().detach().numpy() if isinstance(acc, torch.Tensor) else acc for acc in val_accuracys]
plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), val_accuracys, label='val_accuracy', marker='o')
plt.title('Validation Accuracy Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
